# %% [markdown]
# # Deep ensemble for ENSO-forecasting
#
# In this tutorial you learn how to use a neural network model called Deep Ensemble (DE) for the ENSO forecasting. This network architecture was initially developed [Lakshminarayanan et al. (2017)](https://papers.nips.cc/paper/7219-simple-and-scalable-predictive-uncertainty-estimation-using-deep-ensembles.pdf).
#
# DEs are feed foreword neural networks that predict the mean and the standard deviation of a Gaussian. Hence, their predicion comes with an uncertainty estimation which is a valuable feature for ENSO-forecasting.

# %% [markdown]
# ## Create a data pipe line
#
# At first, we define a data pipeline. This is in general quite useful to keep your code clean and also to reuse the pipeline for later purpose.
#
# The data pipeline generates returns:
#
# 1. The feature array
#
# 2. The label array
#
# 3. The time  array corresponding to the time of the label
#
# NOTE (again): Lead time is defined as the time that passed between the last observed and the first date of the target season. Hence, negative appear, e.g. if you compare the DJF season with the target season JFM, you have a lead time of -2 month (Last observed date: Feburary 28/29, First date of the target season January 1).

# %%
from ninolearn.IO.read_processed import data_reader
from ninolearn.IO.read_raw import ZC_simple_read
import numpy as np
import pandas as pd

oneyear= pd.Timedelta(365, 'D')

# %%
version = 'mu28'
leadtime = 24

# t_start is defined using a funky timedelta because the starting date of the network analysis data is the last month
# of its start year which is 1951-12 therefore the time must start in 1952 with some months added for values lost in 
# interpolation. TODO: fix this by backwards interpolating the first values of the year and finding out what is happening 
# with the nms
times = np.unique(ZC_simple_read(version)['time'])

t_start = times[0] + pd.Timedelta((2*365 + 90),'D')
t_end = times[-1] - pd.Timedelta(90,'D')

print(f'tstart = {t_start} and tend = {t_end}')
# Out:
# tstart = 1952-04-15 04:35:00 and tend = 1981-11-27 01:20:00

# %%
from ninolearn.IO.read_raw import ZC_raw, ZC_h, ZC_oni
from ninolearn.preprocess.prepare import prep_nms
from ninolearn.plot.ZC_dem_plots import nms_plots
## read raw ZC data and save to 1x1 grid file in processeddir
## also makes field of h and sst
ZC_raw(version)

## calculates monthly averaged (?) fields of thermocline height within region 
## of interest. cacluate ONI in region of interest. calculate network metrics 
## from sst (Henk's suggestion) or thermocline height (like Paul)
ZC_h(version) 
ZC_oni(version)
prep_nms(version, 0.99, t_start, t_end)

# make plots
nms_plots(version)
# Out:
# using dimensions ('lat', 'lon') from data variable temperature as the horizontal dimensions for this dataset.
# /home/ivo/anaconda3/envs/ninolearn/lib/python3.6/site-packages/xesmf/frontend.py:524: FutureWarning: ``output_sizes`` should be given in the ``dask_gufunc_kwargs`` parameter. It will be removed as direct parameter in a future version.
#   keep_attrs=keep_attrs
# /home/ivo/anaconda3/envs/ninolearn/lib/python3.6/site-packages/xesmf/smm.py:93: UserWarning: Input array is not C_CONTIGUOUS. Will affect performance.
#   warnings.warn("Input array is not C_CONTIGUOUS. "
# - Read sst climatetology
# using dimensions ('lat', 'lon') from data variable temperature as the horizontal dimensions for this dataset.
# /home/ivo/anaconda3/envs/ninolearn/lib/python3.6/site-packages/xesmf/frontend.py:524: FutureWarning: ``output_sizes`` should be given in the ``dask_gufunc_kwargs`` parameter. It will be removed as direct parameter in a future version.
#   keep_attrs=keep_attrs
# WARNING:Wrong input for computation of hamming distance.
# WARNING:Wrong input for computation of corrected hamming distance.
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!

# %%
reader = data_reader(startdate=(t_start + pd.Timedelta(365,'D')) , enddate=(t_end - pd.Timedelta(365, 'D')) , lon_min = 124, lon_max = 280,
                         lat_min = -19, lat_max = 19)

oni = reader.read_csv(('oni_ZC_' +version))
h = reader.read_csv(('h_mean_ZC_' + version))

network_ssh = reader.read_statistic('network_metrics', variable='sst', dataset=('ZC_25x25_' + version), processed="anom")
c2 = network_ssh['fraction_clusters_size_2']
H = network_ssh['corrected_hamming_distance']

# %%
if h.shape[0] + c2.shape[0] - H.shape[0] - oni.shape[0] == 0:
    print('All datasets are of equal length')
# Out:
# All datasets are of equal length

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler

from ninolearn.utils import include_time_lag
from ninolearn.IO.read_processed import data_reader


def pipeline(lead_time):
    """
    Data pipeline for the processing of the data before the Deep Ensemble
    is trained.

    :type lead_time: int
    :param lead_time: The lead time in month.

    :returns: The feature "X" (at observation time), the label "y" (at lead
    time), the target season "timey" (least month)
    """
#     reader = data_reader(startdate='1952-01', enddate='1992-12', lon_min = 124, lon_max = 280,
#                          lat_min = -19, lat_max = 19)
    reader = data_reader(startdate=(t_start + oneyear), enddate=(t_end - oneyear), lon_min = 124, lon_max = 280,
                         lat_min = -19, lat_max = 19)

    # indeces
    oni = reader.read_csv(('oni_ZC_' +version))
    h = reader.read_csv(('h_mean_ZC_' + version))
    #IOD unavailable in ZC87 model 
    
    # seasonal cycle
    sc = np.cos(np.arange(len(oni))/12*2*np.pi)

    # network metrics
    network_ssh = reader.read_statistic('network_metrics', variable='sst', dataset=('ZC_25x25_'+version), processed="anom")
    c2 = network_ssh['fraction_clusters_size_2']
    H = network_ssh['corrected_hamming_distance']

    # time lag
    time_lag = 12

    # shift such that lead time corresponds to the definition of lead time
    shift = 3

    # process features
    feature_unscaled = np.stack((oni, h,
                                 c2, H), axis=1)

    # scale each feature
    scalerX = StandardScaler()
    Xorg = scalerX.fit_transform(feature_unscaled)

    # set nans to 0.
    Xorg = np.nan_to_num(Xorg)

    # arange the feature array
    X = Xorg[:-lead_time-shift,:]
#     X = include_time_lag(X, max_lag=time_lag)
    X = include_time_lag(X, n_lags =12) 


    # arange label
    yorg = oni.values
    y = yorg[lead_time + time_lag + shift:]

    # get the time axis of the label
    timey = oni.index[lead_time + time_lag + shift:]

    return X, y, timey

# %% [markdown]
# ## Split the data set
#
# For the training and testing of machine learning models it is crucial to split the data set into:
#
# 1. __Train data set__ which is used to train the weights of the neural network
#
# 2. __Validation data set__ which is used to check for overfitting (e.g. when using early stopping) and to optimize the hyperparameters
#
# 3. __Test data set__ which is used to to evaluate the trained model.
#
# __NOTE:__ It is important to understand that hyperparamters must be tuned so that the result is best for the Validation data set and __not__ for the test data set. Otherwise you can not rule out the case that the specific hyperparameter setting just works good for the specific test data set but is not generally a good hyperparameter setting.
#
# In the following cell the train and the validation data set are still one data set, because this array will be later splitted into two arrays when th model is fitted.

# %%
import keras.backend as K
from ninolearn.learn.models.dem import DEM

# clear memory from previous sessions
K.clear_session()

# define the lead time
lead_time = leadtime

# get the features (X), the label (y) and 
# the time axis of the label (timey)
X, y, timey = pipeline(lead_time)

# split the data set into 
# test_indeces = (timey>='1987-01-01') & (timey<='1993-12-01')
test_indeces = (timey>=t_end - pd.Timedelta(5*365, 'D')) & (timey<=t_end)

train_val_indeces = np.invert(test_indeces)

train_val_X, train_val_y, train_val_timey = X[train_val_indeces,:], y[train_val_indeces], timey[train_val_indeces]
testX, testy, testtimey = X[test_indeces,:], y[test_indeces], timey[test_indeces]

# %% [markdown]
# ## Fit the model
#
# Now it is time to train the model! For this a random search is used for all keyword arguments that are passed in a *list* to the DEM.set_parameters() method.

# %%
# initiated an instance of the DEM (Deep Ensemble Model) class
model = DEM()

# Set parameters
model.set_hyperparameters(searchtype='linear', layers=1, neurons=16, dropout=[0.1, 0.5], noise_in=[0.1,0.5], noise_sigma=[0.1,0.5],
                     noise_mu=[0.1,0.5], l1_hidden=[0.0, 0.2], l2_hidden=[0., 0.2],
                     l1_mu=[0.0, 0.2], l2_mu=[0.0, 0.2], l1_sigma=[0.0, 0.2],
                     l2_sigma=[0.0, 0.2], lr=[0.0001,0.01], batch_size=100, epochs=500, n_segments=5,
                     n_members_segment=1, patience=30, verbose=0, pdf='normal', activation = 'relu')

# Use a random search to find the optimal hyperparameters

model.fit_RandomizedSearch(train_val_X, train_val_y, train_val_timey, n_iter=20)
# Out:
# Search iteration Nr 1/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00072: early stopping
# 2/2 [==============================] - 0s 7ms/step - loss: 4.4692 - nll_gaussian: 0.7910
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00031: early stopping
# 2/2 [==============================] - 0s 1ms/step - loss: 3.9308 - nll_gaussian: 1.6312
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00207: early stopping
# 2/2 [==============================] - 0s 5ms/step - loss: 8.7379 - nll_gaussian: 0.7111
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00104: early stopping
# 2/2 [==============================] - 0s 3ms/step - loss: 4.5460 - nll_gaussian: 0.5601
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00147: early stopping
# 2/2 [==============================] - 0s 4ms/step - loss: 6.7596 - nll_gaussian: 1.5926
# Loss: 1.057203459739685
# Computation time: 99.0s
# New best hyperparameters
# Mean loss: 1.057203459739685
# {'layers': 1, 'neurons': 16, 'dropout': 0.453613553778928, 'noise_in': 0.37477359993994563, 'noise_sigma': 0.45502264823690053, 'noise_mu': 0.14491819402918948, 'l1_hidden': 0.11115024465318393, 'l2_hidden': 0.16284071212836623, 'l1_mu': 0.07282694930166234, 'l2_mu': 0.06434090993861515, 'l1_sigma': 0.10695251830156756, 'l2_sigma': 0.034746389784826914, 'lr': 0.005088263065662251, 'batch_size': 100, 'epochs': 500, 'n_segments': 5, 'n_members_segment': 1, 'patience': 30, 'verbose': 0, 'pdf': 'normal', 'activation': 'relu', 'n_members': 5}
# Search iteration Nr 2/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00188: early stopping
# 2/2 [==============================] - 0s 3ms/step - loss: 0.9648 - nll_gaussian: 0.4587
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00213: early stopping
# 2/2 [==============================] - 0s 4ms/step - loss: 0.8220 - nll_gaussian: 0.2823
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00263: early stopping
# 2/2 [==============================] - 0s 3ms/step - loss: 1.2644 - nll_gaussian: 1.0382
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00128: early stopping
# 2/2 [==============================] - 0s 3ms/step - loss: 1.0146 - nll_gaussian: 0.4265
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00137: early stopping
# 2/2 [==============================] - 0s 7ms/step - loss: 1.3044 - nll_gaussian: 0.6657
# Loss: 0.574252313375473
# Computation time: 185.7s
# New best hyperparameters
# Mean loss: 0.574252313375473
# {'layers': 1, 'neurons': 16, 'dropout': 0.1340955875990797, 'noise_in': 0.1823997577273645, 'noise_sigma': 0.1364582823919861, 'noise_mu': 0.1288310428012266, 'l1_hidden': 0.19577651416098335, 'l2_hidden': 0.05816617659029262, 'l1_mu': 0.19402385466243058, 'l2_mu': 0.05900562936040399, 'l1_sigma': 0.1269964031922209, 'l2_sigma': 0.15663247048239048, 'lr': 0.00611551552185008, 'batch_size': 100, 'epochs': 500, 'n_segments': 5, 'n_members_segment': 1, 'patience': 30, 'verbose': 0, 'pdf': 'normal', 'activation': 'relu', 'n_members': 5}
# Search iteration Nr 3/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00061: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 6.9562 - nll_gaussian: 1.1757
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00092: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 9.0206 - nll_gaussian: 0.2001
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00105: early stopping
# 2/2 [==============================] - 0s 4ms/step - loss: 8.1649 - nll_gaussian: 1.2369
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00033: early stopping
# 2/2 [==============================] - 0s 3ms/step - loss: 4.0603 - nll_gaussian: 1.1969
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00063: early stopping
# 2/2 [==============================] - 0s 5ms/step - loss: 7.5294 - nll_gaussian: 0.7497
# Loss: 0.9118782758712769
# Computation time: 91.2s
# Search iteration Nr 4/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00270: early stopping
# 2/2 [==============================] - 0s 5ms/step - loss: 2.2021 - nll_gaussian: 0.5531
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00278: early stopping
# 2/2 [==============================] - 0s 1ms/step - loss: 1.9420 - nll_gaussian: 0.1371
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00269: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 2.7229 - nll_gaussian: 0.5118
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00164: early stopping
# 2/2 [==============================] - 0s 9ms/step - loss: 2.4705 - nll_gaussian: 0.7095
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00157: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 1.7605 - nll_gaussian: 0.7227
# Loss: 0.5268537878990174
# Computation time: 246.5s
# New best hyperparameters
# Mean loss: 0.5268537878990174
# {'layers': 1, 'neurons': 16, 'dropout': 0.3708831374255399, 'noise_in': 0.36467083271572165, 'noise_sigma': 0.22705469417166868, 'noise_mu': 0.16184914257621363, 'l1_hidden': 0.07149904986133904, 'l2_hidden': 0.07877108973447591, 'l1_mu': 0.1996761353159457, 'l2_mu': 0.1566716756788803, 'l1_sigma': 0.14871950551510102, 'l2_sigma': 0.07399239090641514, 'lr': 0.0016449644356238465, 'batch_size': 100, 'epochs': 500, 'n_segments': 5, 'n_members_segment': 1, 'patience': 30, 'verbose': 0, 'pdf': 'normal', 'activation': 'relu', 'n_members': 5}
# Search iteration Nr 5/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00056: early stopping
# 2/2 [==============================] - 0s 3ms/step - loss: 0.7258 - nll_gaussian: 0.2057
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00062: early stopping
# 2/2 [==============================] - 0s 8ms/step - loss: 0.5258 - nll_gaussian: -0.0998
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00043: early stopping
# 2/2 [==============================] - 0s 3ms/step - loss: 1.2866 - nll_gaussian: 0.4844
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00050: early stopping
# 2/2 [==============================] - 0s 7ms/step - loss: 0.9506 - nll_gaussian: 0.2578
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00101: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 0.8756 - nll_gaussian: 0.3250
# Loss: 0.23462945520877837
# Computation time: 82.5s
# New best hyperparameters
# Mean loss: 0.23462945520877837
# {'layers': 1, 'neurons': 16, 'dropout': 0.3980020665273978, 'noise_in': 0.36163098995659604, 'noise_sigma': 0.1371575410655564, 'noise_mu': 0.440630782679289, 'l1_hidden': 0.033240161348692586, 'l2_hidden': 0.05366280558923764, 'l1_mu': 0.041317842625227356, 'l2_mu': 0.074019168259824, 'l1_sigma': 0.14767613022657702, 'l2_sigma': 0.19649813047010256, 'lr': 0.006615664838692649, 'batch_size': 100, 'epochs': 500, 'n_segments': 5, 'n_members_segment': 1, 'patience': 30, 'verbose': 0, 'pdf': 'normal', 'activation': 'relu', 'n_members': 5}
# Search iteration Nr 6/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00032: early stopping
# 2/2 [==============================] - 0s 5ms/step - loss: 3.4238 - nll_gaussian: 1.7032
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00035: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 3.1503 - nll_gaussian: 1.3780
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00045: early stopping
# 2/2 [==============================] - 0s 11ms/step - loss: 4.4672 - nll_gaussian: 2.0841
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00119: early stopping
# 2/2 [==============================] - 0s 7ms/step - loss: 3.7184 - nll_gaussian: 0.7849
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00219: early stopping
# 2/2 [==============================] - 0s 10ms/step - loss: 4.7025 - nll_gaussian: 0.7026
# Loss: 1.3305643558502198
# Computation time: 124.1s
# Search iteration Nr 7/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00031: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 4.5236 - nll_gaussian: 1.7587
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00044: early stopping
# 2/2 [==============================] - 0s 28ms/step - loss: 6.4988 - nll_gaussian: 0.4970
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00067: early stopping
# 2/2 [==============================] - 0s 7ms/step - loss: 8.0943 - nll_gaussian: 0.5720
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00047: early stopping
# 2/2 [==============================] - 0s 6ms/step - loss: 5.9789 - nll_gaussian: 0.7619
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00084: early stopping
# 2/2 [==============================] - 0s 9ms/step - loss: 9.4275 - nll_gaussian: 0.7998
# Loss: 0.8778800785541534
# Computation time: 100.7s
# Search iteration Nr 8/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00063: early stopping
# 2/2 [==============================] - 0s 8ms/step - loss: 0.8726 - nll_gaussian: 0.2461
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00057: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 0.7691 - nll_gaussian: 0.0627
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00063: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 1.1540 - nll_gaussian: 0.4960
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00063: early stopping
# 2/2 [==============================] - 0s 15ms/step - loss: 0.9418 - nll_gaussian: 0.1457
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00073: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 1.1007 - nll_gaussian: 0.4367
# Loss: 0.2774272203445435
# Computation time: 107.2s
# Search iteration Nr 9/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00210: early stopping
# 2/2 [==============================] - 0s 3ms/step - loss: 4.1769 - nll_gaussian: 0.6538
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00162: early stopping
# 2/2 [==============================] - 0s 5ms/step - loss: 2.7700 - nll_gaussian: 0.2482
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00136: early stopping
# 2/2 [==============================] - 0s 1ms/step - loss: 3.7185 - nll_gaussian: 0.7735
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00166: early stopping
# 2/2 [==============================] - 0s 6ms/step - loss: 3.3324 - nll_gaussian: 0.4516
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00101: early stopping
# 2/2 [==============================] - 0s 16ms/step - loss: 5.0241 - nll_gaussian: 1.3756
# Loss: 0.7005374163389206
# Computation time: 178.9s
# Search iteration Nr 10/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00076: early stopping
# 2/2 [==============================] - 0s 5ms/step - loss: 1.8225 - nll_gaussian: 1.5184
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00031: early stopping
# 2/2 [==============================] - 0s 5ms/step - loss: 1.7659 - nll_gaussian: 1.5674
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00189: early stopping
# 2/2 [==============================] - 0s 8ms/step - loss: 2.8218 - nll_gaussian: 2.1326
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00190: early stopping
# 2/2 [==============================] - 0s 3ms/step - loss: 1.2936 - nll_gaussian: 0.8937
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00032: early stopping
# 2/2 [==============================] - 0s 3ms/step - loss: 3.1484 - nll_gaussian: 2.6026
# Loss: 1.7429389238357544
# Computation time: 156.6s
# Search iteration Nr 11/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00117: early stopping
# 2/2 [==============================] - 0s 9ms/step - loss: 6.4351 - nll_gaussian: 1.3372
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00194: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 6.7976 - nll_gaussian: 0.6747
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00051: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 6.4046 - nll_gaussian: 2.4879
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00031: early stopping
# 2/2 [==============================] - 0s 11ms/step - loss: 4.3359 - nll_gaussian: 1.2165
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00113: early stopping
# 2/2 [==============================] - 0s 21ms/step - loss: 7.4087 - nll_gaussian: 1.8770
# Loss: 1.5186651349067688
# Computation time: 136.8s
# Search iteration Nr 12/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00051: early stopping
# 2/2 [==============================] - 0s 6ms/step - loss: 2.1047 - nll_gaussian: 1.3555
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00079: early stopping
# 2/2 [==============================] - 0s 3ms/step - loss: 1.8421 - nll_gaussian: 0.9533
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00049: early stopping
# 2/2 [==============================] - 0s 18ms/step - loss: 2.9292 - nll_gaussian: 1.8968
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00079: early stopping
# 2/2 [==============================] - 0s 5ms/step - loss: 1.5817 - nll_gaussian: 0.4861
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00031: early stopping
# 2/2 [==============================] - 0s 6ms/step - loss: 3.3451 - nll_gaussian: 2.5859
# Loss: 1.4555190563201905
# Computation time: 98.3s
# Search iteration Nr 13/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00047: early stopping
# 2/2 [==============================] - 0s 1ms/step - loss: 2.3759 - nll_gaussian: 1.2481
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00064: early stopping
# 2/2 [==============================] - 0s 8ms/step - loss: 1.8155 - nll_gaussian: 0.0949
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00070: early stopping
# 2/2 [==============================] - 0s 6ms/step - loss: 3.1701 - nll_gaussian: 1.3369
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00043: early stopping
# 2/2 [==============================] - 0s 3ms/step - loss: 1.9968 - nll_gaussian: 0.9106
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00136: early stopping
# 2/2 [==============================] - 0s 6ms/step - loss: 3.3365 - nll_gaussian: 0.9424
# Loss: 0.9065862953662872
# Computation time: 120.7s
# Search iteration Nr 14/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00176: early stopping
# 2/2 [==============================] - 0s 15ms/step - loss: 1.9325 - nll_gaussian: 1.3084
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00147: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 1.6734 - nll_gaussian: 0.8346
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00065: early stopping
# 2/2 [==============================] - 0s 4ms/step - loss: 2.9152 - nll_gaussian: 2.2408
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00086: early stopping
# 2/2 [==============================] - 0s 4ms/step - loss: 1.4124 - nll_gaussian: 0.9252
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00123: early stopping
# 2/2 [==============================] - 0s 27ms/step - loss: 2.3350 - nll_gaussian: 1.6488
# Loss: 1.3915569305419921
# Computation time: 173.6s
# Search iteration Nr 15/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00038: early stopping
# 2/2 [==============================] - 0s 7ms/step - loss: 5.1161 - nll_gaussian: 1.7725
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00061: early stopping
# 2/2 [==============================] - 0s 6ms/step - loss: 4.6865 - nll_gaussian: 1.5510
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00032: early stopping
# 2/2 [==============================] - 0s 6ms/step - loss: 6.2093 - nll_gaussian: 2.4503
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00042: early stopping
# 2/2 [==============================] - 0s 6ms/step - loss: 4.4986 - nll_gaussian: 1.1773
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00031: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 6.3308 - nll_gaussian: 2.6161
# Loss: 1.913422179222107
# Computation time: 77.3s
# Search iteration Nr 16/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00090: early stopping
# 2/2 [==============================] - 0s 3ms/step - loss: 6.0631 - nll_gaussian: 1.0917
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00072: early stopping
# 2/2 [==============================] - 0s 9ms/step - loss: 5.8670 - nll_gaussian: 1.5052
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00099: early stopping
# 2/2 [==============================] - 0s 4ms/step - loss: 6.4305 - nll_gaussian: 1.6280
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00087: early stopping
# 2/2 [==============================] - 0s 3ms/step - loss: 6.6458 - nll_gaussian: 0.7616
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00140: early stopping
# 2/2 [==============================] - 0s 3ms/step - loss: 7.1228 - nll_gaussian: 1.7694
# Loss: 1.3511801481246948
# Computation time: 144.3s
# Search iteration Nr 17/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00070: early stopping
# 2/2 [==============================] - 0s 47ms/step - loss: 3.0684 - nll_gaussian: 0.3385
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00069: early stopping
# 2/2 [==============================] - 0s 5ms/step - loss: 4.8170 - nll_gaussian: 0.4967
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00082: early stopping
# 2/2 [==============================] - 0s 9ms/step - loss: 2.8350 - nll_gaussian: 0.7505
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00077: early stopping
# 2/2 [==============================] - 0s 6ms/step - loss: 3.8099 - nll_gaussian: 0.4007
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00048: early stopping
# 2/2 [==============================] - 0s 4ms/step - loss: 2.3809 - nll_gaussian: 0.6429
# Loss: 0.5258723080158234
# Computation time: 103.6s
# Search iteration Nr 18/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00133: early stopping
# 2/2 [==============================] - 0s 1ms/step - loss: 9.6181 - nll_gaussian: 0.5197
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00151: early stopping
# 2/2 [==============================] - 0s 7ms/step - loss: 8.0515 - nll_gaussian: 0.1981
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00076: early stopping
# 2/2 [==============================] - 0s 3ms/step - loss: 6.8725 - nll_gaussian: 1.7340
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00072: early stopping
# 2/2 [==============================] - 0s 3ms/step - loss: 6.2874 - nll_gaussian: 0.3566
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00128: early stopping
# 2/2 [==============================] - 0s 3ms/step - loss: 7.8604 - nll_gaussian: 0.7147
# Loss: 0.704623818397522
# Computation time: 128.0s
# Search iteration Nr 19/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00077: early stopping
# 2/2 [==============================] - 0s 11ms/step - loss: 1.6044 - nll_gaussian: 0.4421
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00176: early stopping
# 2/2 [==============================] - 0s 22ms/step - loss: 0.7180 - nll_gaussian: 0.0227
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00135: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 1.2930 - nll_gaussian: 0.4497
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00091: early stopping
# 2/2 [==============================] - 0s 10ms/step - loss: 1.1570 - nll_gaussian: 0.1978
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00122: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 1.2499 - nll_gaussian: 0.4630
# Loss: 0.31504842787981036
# Computation time: 132.2s
# Search iteration Nr 20/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00077: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 2.1845 - nll_gaussian: 0.2138
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00134: early stopping
# 2/2 [==============================] - 0s 8ms/step - loss: 3.7890 - nll_gaussian: 0.0987
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00076: early stopping
# 2/2 [==============================] - 0s 15ms/step - loss: 2.1560 - nll_gaussian: 0.4461
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00069: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 2.6677 - nll_gaussian: 0.3425
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00082: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 3.8406 - nll_gaussian: 0.3861
# Loss: 0.2974348276853561
# Computation time: 96.1s
# Refit the model with best hyperparamters
# {'layers': 1, 'neurons': 16, 'dropout': 0.3980020665273978, 'noise_in': 0.36163098995659604, 'noise_sigma': 0.1371575410655564, 'noise_mu': 0.440630782679289, 'l1_hidden': 0.033240161348692586, 'l2_hidden': 0.05366280558923764, 'l1_mu': 0.041317842625227356, 'l2_mu': 0.074019168259824, 'l1_sigma': 0.14767613022657702, 'l2_sigma': 0.19649813047010256, 'lr': 0.006615664838692649, 'batch_size': 100, 'epochs': 500, 'n_segments': 5, 'n_members_segment': 1, 'patience': 30, 'verbose': 0, 'pdf': 'normal', 'activation': 'relu', 'n_members': 5}
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00065: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 0.7332 - nll_gaussian: 0.2484
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00064: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 0.5227 - nll_gaussian: -0.0968
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00051: early stopping
# 2/2 [==============================] - 0s 1ms/step - loss: 1.1435 - nll_gaussian: 0.5044
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00049: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 1.0083 - nll_gaussian: 0.2433
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00064: early stopping
# 2/2 [==============================] - 0s 7ms/step - loss: 0.9132 - nll_gaussian: 0.2975
# Loss: 0.23934984505176543
# Computation time: 77.1s
# best loss search: 0.23462945520877837
# loss refitting : 0.23934984505176543

# %% [markdown]
# ## Make predictions for the test data set
# Now we can use the trained models to make predicitons on the test data set to evaluate how good the model perfoms on a data set that it never saw before.

# %%
pred_mean, pred_std = model.predict(testX)

# %% [markdown]
# ## Plot the prediction
# Let's see how the predicion is looking like

# %%
import matplotlib.pyplot as plt
from ninolearn.plot.prediction import plot_prediction
import pandas as pd
from ninolearn.pathes import plotdir

from os.path import join


plt.subplots(figsize=(15,3.5))
plt.axhspan(-0.5,
            -6,
            facecolor='blue',
            alpha=0.1,zorder=0)

plt.axhspan(0.5,
            6,
            facecolor='red',
            alpha=0.1,zorder=0)

plt.xlim(testtimey[0], testtimey[-1])
plt.ylim(-3,3)

# plot the prediction
plot_prediction(testtimey, pred_mean, std=pred_std, facecolor='royalblue', line_color='navy')

# plot the observation
plt.plot(timey, y, "r", label = 'observation')
plt.legend()

plt.savefig(join(plotdir, f'predicVSobs_{version}_{lead_time}lead'), transparent=False)

plt.show()

# %% [markdown]
# ## Evaluate the model
#
# We can evaluate the model a bit more quantitatively using the loss function that was used to train the model, namely the negative-log-likelihood of the Gaussian and the correlation between the predicted mean and the observed ONI index.

# %%
from ninolearn.plot.evaluation import plot_correlation

loss = model.evaluate(testy, pred_mean, pred_std)
print(f"Loss (Negative-Log-Likelihood): {loss}")

# make a plot of the seasonal correaltion
# note: - pd.tseries.offsets.MonthBegin(1) appears to ensure that the correlations are plotted
# agains the correct season
plot_correlation(testy, pred_mean, testtimey - pd.tseries.offsets.MonthBegin(1), title="")

plt.savefig(join(plotdir, f'correlation_{version}_{lead_time}lead'))
# Out:
# Loss (Negative-Log-Likelihood): 0.4640675952757647
