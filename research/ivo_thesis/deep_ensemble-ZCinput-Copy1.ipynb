# %% [markdown]
# # Deep ensemble for ENSO-forecasting
#
# In this tutorial you learn how to use a neural network model called Deep Ensemble (DE) for the ENSO forecasting. This network architecture was initially developed [Lakshminarayanan et al. (2017)](https://papers.nips.cc/paper/7219-simple-and-scalable-predictive-uncertainty-estimation-using-deep-ensembles.pdf).
#
# DEs are feed foreword neural networks that predict the mean and the standard deviation of a Gaussian. Hence, their predicion comes with an uncertainty estimation which is a valuable feature for ENSO-forecasting.

# %% [markdown]
# ## Create a data pipe line
#
# At first, we define a data pipeline. This is in general quite useful to keep your code clean and also to reuse the pipeline for later purpose.
#
# The data pipeline generates returns:
#
# 1. The feature array
#
# 2. The label array
#
# 3. The time  array corresponding to the time of the label
#
# NOTE (again): Lead time is defined as the time that passed between the last observed and the first date of the target season. Hence, negative appear, e.g. if you compare the DJF season with the target season JFM, you have a lead time of -2 month (Last observed date: Feburary 28/29, First date of the target season January 1).

# %%
from ninolearn.IO.read_processed import data_reader
from ninolearn.IO.read_raw import ZC_simple_read
import numpy as np
import pandas as pd

oneyear= pd.Timedelta(365, 'D')

# %%
version = 'mu25v2'
leadtime = 12

# t_start is defined using a funky timedelta because the starting date of the network analysis data is the last month
# of its start year which is 1951-12 therefore the time must start in 1952 with some months added for values lost in 
# interpolation. TODO: fix this by backwards interpolating the first values of the year and finding out what is happening 
# with the nms
times = np.unique(ZC_simple_read(version)['time'])

t_start = times[0] + pd.Timedelta((2*365 + 90),'D')
t_end = times[-1] - pd.Timedelta(90,'D')

print(f'tstart = {t_start} and tend = {t_end}')
# Out:
# tstart = 1952-04-15 04:35:00 and tend = 1994-08-19 04:53:20

# %%
from ninolearn.IO.read_raw import ZC_raw, ZC_h, ZC_oni
from ninolearn.preprocess.prepare import prep_nms
from ninolearn.plot.ZC_dem_plots import nms_plots
## read raw ZC data and save to 1x1 grid file in processeddir
## also makes field of h and sst
ZC_raw(version)

## calculates monthly averaged (?) fields of thermocline height within region 
## of interest. cacluate ONI in region of interest. calculate network metrics 
## from sst (Henk's suggestion) or thermocline height (like Paul)
ZC_h(version) 
ZC_oni(version)
prep_nms(version, 0.99, t_start, t_end)

# make plots
nms_plots(version)
# Out:
# using dimensions ('lat', 'lon') from data variable temperature as the horizontal dimensions for this dataset.
# /home/ivo/anaconda3/envs/ninolearn/lib/python3.6/site-packages/xesmf/frontend.py:524: FutureWarning: ``output_sizes`` should be given in the ``dask_gufunc_kwargs`` parameter. It will be removed as direct parameter in a future version.
#   keep_attrs=keep_attrs
# /home/ivo/anaconda3/envs/ninolearn/lib/python3.6/site-packages/xesmf/smm.py:93: UserWarning: Input array is not C_CONTIGUOUS. Will affect performance.
#   warnings.warn("Input array is not C_CONTIGUOUS. "
# - Read sst climatetology
# using dimensions ('lat', 'lon') from data variable temperature as the horizontal dimensions for this dataset.
# /home/ivo/anaconda3/envs/ninolearn/lib/python3.6/site-packages/xesmf/frontend.py:524: FutureWarning: ``output_sizes`` should be given in the ``dask_gufunc_kwargs`` parameter. It will be removed as direct parameter in a future version.
#   keep_attrs=keep_attrs
# WARNING:Wrong input for computation of hamming distance.
# WARNING:Wrong input for computation of corrected hamming distance.
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!

# %%
reader = data_reader(startdate=(t_start + pd.Timedelta(365,'D')) , enddate=(t_end - pd.Timedelta(2*365, 'D')) , lon_min = 124, lon_max = 280,
                         lat_min = -19, lat_max = 19)

oni = reader.read_csv(('oni_ZC_' +version))
h = reader.read_csv(('h_mean_ZC_' + version))

network_ssh = reader.read_statistic('network_metrics', variable='sst', dataset=('ZC_25x25_' + version), processed="anom")
c2 = network_ssh['fraction_clusters_size_2']
H = network_ssh['corrected_hamming_distance']

# %%
if h.shape[0] + c2.shape[0] - H.shape[0] - oni.shape[0] == 0:
    print('All datasets are of equal length')
# Out:
# All datasets are of equal length

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler

from ninolearn.utils import include_time_lag
from ninolearn.IO.read_processed import data_reader


def pipeline(lead_time):
    """
    Data pipeline for the processing of the data before the Deep Ensemble
    is trained.

    :type lead_time: int
    :param lead_time: The lead time in month.

    :returns: The feature "X" (at observation time), the label "y" (at lead
    time), the target season "timey" (least month)
    """
#     reader = data_reader(startdate='1952-01', enddate='1992-12', lon_min = 124, lon_max = 280,
#                          lat_min = -19, lat_max = 19)
    reader = data_reader(startdate=(t_start + oneyear), enddate=(t_end - 2 *oneyear), lon_min = 124, lon_max = 280,
                         lat_min = -19, lat_max = 19)

    # indeces
    oni = reader.read_csv(('oni_ZC_' +version))
    h = reader.read_csv(('h_mean_ZC_' + version))
    #IOD unavailable in ZC87 model 
    
    # seasonal cycle
    sc = np.cos(np.arange(len(oni))/12*2*np.pi)

    # network metrics
    network_ssh = reader.read_statistic('network_metrics', variable='sst', dataset=('ZC_25x25_'+version), processed="anom")
    c2 = network_ssh['fraction_clusters_size_2']
    H = network_ssh['corrected_hamming_distance']

    # time lag
    time_lag = 12

    # shift such that lead time corresponds to the definition of lead time
    shift = 3

    # process features
    feature_unscaled = np.stack((oni, h,
                                 c2, H), axis=1)

    # scale each feature
    scalerX = StandardScaler()
    Xorg = scalerX.fit_transform(feature_unscaled)

    # set nans to 0.
    Xorg = np.nan_to_num(Xorg)

    # arange the feature array
    X = Xorg[:-lead_time-shift,:]
#     X = include_time_lag(X, max_lag=time_lag)
    X = include_time_lag(X, n_lags =12) 


    # arange label
    yorg = oni.values
    y = yorg[lead_time + time_lag + shift:]

    # get the time axis of the label
    timey = oni.index[lead_time + time_lag + shift:]

    return X, y, timey

# %% [markdown]
# ## Split the data set
#
# For the training and testing of machine learning models it is crucial to split the data set into:
#
# 1. __Train data set__ which is used to train the weights of the neural network
#
# 2. __Validation data set__ which is used to check for overfitting (e.g. when using early stopping) and to optimize the hyperparameters
#
# 3. __Test data set__ which is used to to evaluate the trained model.
#
# __NOTE:__ It is important to understand that hyperparamters must be tuned so that the result is best for the Validation data set and __not__ for the test data set. Otherwise you can not rule out the case that the specific hyperparameter setting just works good for the specific test data set but is not generally a good hyperparameter setting.
#
# In the following cell the train and the validation data set are still one data set, because this array will be later splitted into two arrays when th model is fitted.

# %%
import keras.backend as K
from ninolearn.learn.models.dem import DEM

# clear memory from previous sessions
K.clear_session()

# define the lead time
lead_time = leadtime

# get the features (X), the label (y) and 
# the time axis of the label (timey)
X, y, timey = pipeline(lead_time)

# split the data set into 
# test_indeces = (timey>='1987-01-01') & (timey<='1993-12-01')
test_indeces = (timey>=t_end - pd.Timedelta(5*365, 'D')) & (timey<=t_end)

train_val_indeces = np.invert(test_indeces)

train_val_X, train_val_y, train_val_timey = X[train_val_indeces,:], y[train_val_indeces], timey[train_val_indeces]
testX, testy, testtimey = X[test_indeces,:], y[test_indeces], timey[test_indeces]

# %% [markdown]
# ## Fit the model
#
# Now it is time to train the model! For this a random search is used for all keyword arguments that are passed in a *list* to the DEM.set_parameters() method.

# %%
# initiated an instance of the DEM (Deep Ensemble Model) class
model = DEM()

# Set parameters
model.set_hyperparameters(searchtype='linear', layers=1, neurons=16, dropout=[0.1, 0.5], noise_in=[0.1,0.5], noise_sigma=[0.1,0.5],
                     noise_mu=[0.1,0.5], l1_hidden=[0.0, 0.2], l2_hidden=[0., 0.2],
                     l1_mu=[0.0, 0.2], l2_mu=[0.0, 0.2], l1_sigma=[0.0, 0.2],
                     l2_sigma=[0.0, 0.2], lr=[0.0001,0.01], batch_size=100, epochs=500, n_segments=5,
                     n_members_segment=1, patience=30, verbose=0, pdf='normal', activation = 'relu')

# Use a random search to find the optimal hyperparameters

model.fit_RandomizedSearch(train_val_X, train_val_y, train_val_timey, n_iter=20)
# Out:
# Search iteration Nr 1/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00041: early stopping
# 3/3 [==============================] - 0s 6ms/step - loss: 1.3281 - nll_gaussian: 0.5111
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00044: early stopping
# 3/3 [==============================] - 0s 5ms/step - loss: 1.4790 - nll_gaussian: 0.7684
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00086: early stopping
# 3/3 [==============================] - 0s 9ms/step - loss: 1.1927 - nll_gaussian: 0.4125
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00184: early stopping
# 3/3 [==============================] - 0s 2ms/step - loss: 1.0565 - nll_gaussian: 0.5583
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00047: early stopping
# 3/3 [==============================] - 0s 3ms/step - loss: 1.3500 - nll_gaussian: 0.8280
# Loss: 0.6156593501567841
# Computation time: 76.3s
# New best hyperparameters
# Mean loss: 0.6156593501567841
# {'layers': 1, 'neurons': 16, 'dropout': 0.11099450198100885, 'noise_in': 0.37768645279197444, 'noise_sigma': 0.16304556719668964, 'noise_mu': 0.3801959089822585, 'l1_hidden': 0.12372418404094157, 'l2_hidden': 0.1745664976123299, 'l1_mu': 0.1910255597371154, 'l2_mu': 0.1349538175199582, 'l1_sigma': 0.047925611644894485, 'l2_sigma': 0.1475485135003311, 'lr': 0.0048729540570421805, 'batch_size': 100, 'epochs': 500, 'n_segments': 5, 'n_members_segment': 1, 'patience': 30, 'verbose': 0, 'pdf': 'normal', 'activation': 'relu', 'n_members': 5}
# Search iteration Nr 2/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00100: early stopping
# 3/3 [==============================] - 0s 6ms/step - loss: 0.9453 - nll_gaussian: 0.5214
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00068: early stopping
# 3/3 [==============================] - 0s 5ms/step - loss: 1.2303 - nll_gaussian: 0.5349
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00086: early stopping
# 3/3 [==============================] - 0s 19ms/step - loss: 1.1665 - nll_gaussian: 0.7066
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00082: early stopping
# 3/3 [==============================] - 0s 2ms/step - loss: 1.2580 - nll_gaussian: 0.5223
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00039: early stopping
# 3/3 [==============================] - 0s 5ms/step - loss: 1.5189 - nll_gaussian: 0.9260
# Loss: 0.6422307252883911
# Computation time: 66.3s
# Search iteration Nr 3/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00055: early stopping
# 3/3 [==============================] - 0s 10ms/step - loss: 2.9318 - nll_gaussian: 1.3966
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00047: early stopping
# 3/3 [==============================] - 0s 4ms/step - loss: 3.4467 - nll_gaussian: 1.6858
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00227: early stopping
# 3/3 [==============================] - 0s 9ms/step - loss: 3.5074 - nll_gaussian: 0.8036
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00304: early stopping
# 3/3 [==============================] - 0s 4ms/step - loss: 3.9541 - nll_gaussian: 1.1283
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00071: early stopping
# 3/3 [==============================] - 0s 4ms/step - loss: 3.6480 - nll_gaussian: 1.8815
# Loss: 1.3791645646095276
# Computation time: 147.6s
# Search iteration Nr 4/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00097: early stopping
# 3/3 [==============================] - 0s 3ms/step - loss: 3.6949 - nll_gaussian: 1.4724
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00060: early stopping
# 3/3 [==============================] - 0s 2ms/step - loss: 4.2637 - nll_gaussian: 1.8509
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00069: early stopping
# 3/3 [==============================] - 0s 5ms/step - loss: 4.3148 - nll_gaussian: 2.0336
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00075: early stopping
# 3/3 [==============================] - 0s 3ms/step - loss: 4.9047 - nll_gaussian: 2.4861
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00113: early stopping
# 3/3 [==============================] - 0s 3ms/step - loss: 4.4833 - nll_gaussian: 2.0780
# Loss: 1.9841981887817384
# Computation time: 91.5s
# Search iteration Nr 5/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00060: early stopping
# 3/3 [==============================] - 0s 7ms/step - loss: 3.2824 - nll_gaussian: 1.5262
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00031: early stopping
# 3/3 [==============================] - 0s 5ms/step - loss: 3.9801 - nll_gaussian: 1.9907
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00052: early stopping
# 3/3 [==============================] - 0s 5ms/step - loss: 3.8307 - nll_gaussian: 2.0764
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00077: early stopping
# 3/3 [==============================] - 0s 3ms/step - loss: 4.5185 - nll_gaussian: 2.7228
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00036: early stopping
# 3/3 [==============================] - 0s 3ms/step - loss: 3.9846 - nll_gaussian: 2.1516
# Loss: 2.093523049354553
# Computation time: 63.7s
# Search iteration Nr 6/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00079: early stopping
# 3/3 [==============================] - 0s 2ms/step - loss: 2.8334 - nll_gaussian: 1.5990
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00144: early stopping
# 3/3 [==============================] - 0s 7ms/step - loss: 3.3925 - nll_gaussian: 1.9345
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00198: early stopping
# 3/3 [==============================] - 0s 7ms/step - loss: 3.1803 - nll_gaussian: 1.9522
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00079: early stopping
# 3/3 [==============================] - 0s 3ms/step - loss: 3.8611 - nll_gaussian: 2.5606
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00080: early stopping
# 3/3 [==============================] - 0s 5ms/step - loss: 3.4374 - nll_gaussian: 2.1201
# Loss: 2.0332801818847654
# Computation time: 128.2s
# Search iteration Nr 7/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00103: early stopping
# 3/3 [==============================] - 0s 2ms/step - loss: 1.0400 - nll_gaussian: 0.5772
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00383: early stopping
# 3/3 [==============================] - 0s 1ms/step - loss: 0.9598 - nll_gaussian: 0.4783
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00301: early stopping
# 3/3 [==============================] - 0s 4ms/step - loss: 1.0249 - nll_gaussian: 0.4098
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00122: early stopping
# 3/3 [==============================] - 0s 3ms/step - loss: 1.3218 - nll_gaussian: 1.0042
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00184: early stopping
# 3/3 [==============================] - 0s 12ms/step - loss: 1.1363 - nll_gaussian: 0.8613
# Loss: 0.6661541342735291
# Computation time: 214.0s
# Search iteration Nr 8/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00094: early stopping
# 3/3 [==============================] - 0s 5ms/step - loss: 5.4300 - nll_gaussian: 1.0046
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00045: early stopping
# 3/3 [==============================] - 0s 13ms/step - loss: 5.3754 - nll_gaussian: 1.7360
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00051: early stopping
# 3/3 [==============================] - 0s 6ms/step - loss: 5.4194 - nll_gaussian: 1.5488
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00037: early stopping
# 3/3 [==============================] - 0s 3ms/step - loss: 5.7831 - nll_gaussian: 2.6490
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00040: early stopping
# 3/3 [==============================] - 0s 3ms/step - loss: 5.3794 - nll_gaussian: 2.0437
# Loss: 1.7964099645614624
# Computation time: 64.0s
# Search iteration Nr 9/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00048: early stopping
# 3/3 [==============================] - 0s 1ms/step - loss: 1.5015 - nll_gaussian: 0.1191
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00081: early stopping
# 3/3 [==============================] - 0s 3ms/step - loss: 1.3407 - nll_gaussian: 0.4555
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00049: early stopping
# 3/3 [==============================] - 0s 3ms/step - loss: 1.2565 - nll_gaussian: 0.3234
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00058: early stopping
# 3/3 [==============================] - 0s 3ms/step - loss: 1.3263 - nll_gaussian: 0.2805
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00050: early stopping
# 3/3 [==============================] - 0s 2ms/step - loss: 1.1607 - nll_gaussian: 0.2555
# Loss: 0.28680832833051684
# Computation time: 66.5s
# New best hyperparameters
# Mean loss: 0.28680832833051684
# {'layers': 1, 'neurons': 16, 'dropout': 0.40068596882425, 'noise_in': 0.46940374160772214, 'noise_sigma': 0.22310799027774744, 'noise_mu': 0.4458913276103962, 'l1_hidden': 0.03494298637521216, 'l2_hidden': 0.13495300785424463, 'l1_mu': 0.11371596582757391, 'l2_mu': 0.19338694210272867, 'l1_sigma': 0.15663625401679698, 'l2_sigma': 0.07122045733315273, 'lr': 0.0062190911973918515, 'batch_size': 100, 'epochs': 500, 'n_segments': 5, 'n_members_segment': 1, 'patience': 30, 'verbose': 0, 'pdf': 'normal', 'activation': 'relu', 'n_members': 5}
# Search iteration Nr 10/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00057: early stopping
# 3/3 [==============================] - 0s 3ms/step - loss: 2.2980 - nll_gaussian: 0.4839
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00080: early stopping
# 3/3 [==============================] - 0s 2ms/step - loss: 3.2484 - nll_gaussian: 0.3351
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00094: early stopping
# 3/3 [==============================] - 0s 2ms/step - loss: 2.8637 - nll_gaussian: 0.3613
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00205: early stopping
# 3/3 [==============================] - 0s 3ms/step - loss: 3.2907 - nll_gaussian: 0.4357
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00054: early stopping
# 3/3 [==============================] - 0s 2ms/step - loss: 2.6988 - nll_gaussian: 0.9317
# Loss: 0.5095341145992279
# Computation time: 108.7s
# Search iteration Nr 11/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00054: early stopping
# 3/3 [==============================] - 0s 5ms/step - loss: 4.7757 - nll_gaussian: 0.6353
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00100: early stopping
# 3/3 [==============================] - 0s 4ms/step - loss: 6.8485 - nll_gaussian: 1.4055
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00039: early stopping
# 3/3 [==============================] - 0s 5ms/step - loss: 5.2178 - nll_gaussian: 1.7168
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00031: early stopping
# 3/3 [==============================] - 0s 3ms/step - loss: 5.2528 - nll_gaussian: 2.4849
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00086: early stopping
# 3/3 [==============================] - 0s 3ms/step - loss: 6.3042 - nll_gaussian: 0.5645
# Loss: 1.3613997459411622
# Computation time: 77.3s
# Search iteration Nr 12/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00099: early stopping
# 3/3 [==============================] - 0s 3ms/step - loss: 4.6898 - nll_gaussian: 0.2480
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00126: early stopping
# 3/3 [==============================] - 0s 2ms/step - loss: 5.9694 - nll_gaussian: 0.2344
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00063: early stopping
# 3/3 [==============================] - 0s 6ms/step - loss: 4.6998 - nll_gaussian: 0.3727
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00079: early stopping
# 3/3 [==============================] - 0s 2ms/step - loss: 5.4772 - nll_gaussian: 1.3477
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00057: early stopping
# 3/3 [==============================] - 0s 6ms/step - loss: 5.5317 - nll_gaussian: 1.4165
# Loss: 0.7238613724708557
# Computation time: 94.8s
# Search iteration Nr 13/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00227: early stopping
# 3/3 [==============================] - 0s 2ms/step - loss: 3.8864 - nll_gaussian: 0.5154
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00128: early stopping
# 3/3 [==============================] - 0s 1ms/step - loss: 3.0396 - nll_gaussian: 0.6604
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00097: early stopping
# 3/3 [==============================] - 0s 3ms/step - loss: 3.6371 - nll_gaussian: 0.7428
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00082: early stopping
# 3/3 [==============================] - 0s 2ms/step - loss: 1.9083 - nll_gaussian: 1.0253
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00150: early stopping
# 3/3 [==============================] - 0s 1ms/step - loss: 2.0440 - nll_gaussian: 0.5125
# Loss: 0.6912889003753662
# Computation time: 138.3s
# Search iteration Nr 14/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00051: early stopping
# 3/3 [==============================] - 0s 7ms/step - loss: 3.1473 - nll_gaussian: 0.6100
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00033: early stopping
# 3/3 [==============================] - 0s 5ms/step - loss: 3.1795 - nll_gaussian: 1.6802
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00067: early stopping
# 3/3 [==============================] - 0s 3ms/step - loss: 3.8837 - nll_gaussian: 1.0193
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00041: early stopping
# 3/3 [==============================] - 0s 2ms/step - loss: 2.7540 - nll_gaussian: 0.7165
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00043: early stopping
# 3/3 [==============================] - 0s 3ms/step - loss: 2.4708 - nll_gaussian: 0.0795
# Loss: 0.8210758209228516
# Computation time: 67.8s
# Search iteration Nr 15/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00031: early stopping
# 3/3 [==============================] - 0s 3ms/step - loss: 3.9122 - nll_gaussian: 1.4887
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00075: early stopping
# 3/3 [==============================] - 0s 3ms/step - loss: 8.2488 - nll_gaussian: 0.7071
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00038: early stopping
# 3/3 [==============================] - 0s 4ms/step - loss: 6.0529 - nll_gaussian: 1.3558
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00063: early stopping
# 3/3 [==============================] - 0s 2ms/step - loss: 6.8528 - nll_gaussian: 0.6875
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00061: early stopping
# 3/3 [==============================] - 0s 3ms/step - loss: 6.9497 - nll_gaussian: 0.7491
# Loss: 0.9976457118988037
# Computation time: 67.8s
# Search iteration Nr 16/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00077: early stopping
# 3/3 [==============================] - 0s 3ms/step - loss: 6.0023 - nll_gaussian: 0.2396
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00055: early stopping
# 3/3 [==============================] - 0s 2ms/step - loss: 7.8825 - nll_gaussian: 0.4887
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00057: early stopping
# 3/3 [==============================] - 0s 2ms/step - loss: 7.5316 - nll_gaussian: 0.4569
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00086: early stopping
# 3/3 [==============================] - 0s 1ms/step - loss: 10.9450 - nll_gaussian: 0.5052
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00049: early stopping
# 3/3 [==============================] - 0s 4ms/step - loss: 3.8672 - nll_gaussian: 0.3669
# Loss: 0.4114809662103653
# Computation time: 76.5s
# Search iteration Nr 17/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00046: early stopping
# 3/3 [==============================] - 0s 9ms/step - loss: 8.4705 - nll_gaussian: 1.0018
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00034: early stopping
# 3/3 [==============================] - 0s 3ms/step - loss: 6.3117 - nll_gaussian: 1.2696
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00101: early stopping
# 3/3 [==============================] - 0s 6ms/step - loss: 12.0095 - nll_gaussian: 0.6144
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00045: early stopping
# 3/3 [==============================] - 0s 5ms/step - loss: 11.0169 - nll_gaussian: 2.5337
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00060: early stopping
# 3/3 [==============================] - 0s 7ms/step - loss: 10.3215 - nll_gaussian: 1.3796
# Loss: 1.359808373451233
# Computation time: 74.0s
# Search iteration Nr 18/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# 3/3 [==============================] - 0s 4ms/step - loss: 0.8653 - nll_gaussian: 0.3561
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# 3/3 [==============================] - 0s 3ms/step - loss: 1.0089 - nll_gaussian: 0.5365
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00471: early stopping
# 3/3 [==============================] - 0s 4ms/step - loss: 1.0315 - nll_gaussian: 0.4619
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00257: early stopping
# 3/3 [==============================] - 0s 3ms/step - loss: 1.2675 - nll_gaussian: 0.7330
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# 3/3 [==============================] - 0s 5ms/step - loss: 0.9997 - nll_gaussian: 0.4631
# Loss: 0.5101141154766082
# Computation time: 414.1s
# Search iteration Nr 19/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00039: early stopping
# 3/3 [==============================] - 0s 5ms/step - loss: 1.3059 - nll_gaussian: 0.6123
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00040: early stopping
# 3/3 [==============================] - 0s 2ms/step - loss: 1.4902 - nll_gaussian: 0.8504
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00044: early stopping
# 3/3 [==============================] - 0s 3ms/step - loss: 1.3627 - nll_gaussian: 0.8736
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00040: early stopping
# 3/3 [==============================] - 0s 2ms/step - loss: 1.6136 - nll_gaussian: 1.0147
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00040: early stopping
# 3/3 [==============================] - 0s 3ms/step - loss: 1.4827 - nll_gaussian: 0.8942
# Loss: 0.8490374207496643
# Computation time: 53.1s
# Search iteration Nr 20/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00067: early stopping
# 3/3 [==============================] - 0s 1ms/step - loss: 1.5856 - nll_gaussian: 0.5717
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00087: early stopping
# 3/3 [==============================] - 0s 4ms/step - loss: 2.2059 - nll_gaussian: 0.9719
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00050: early stopping
# 3/3 [==============================] - 0s 10ms/step - loss: 1.8387 - nll_gaussian: 0.9042
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00094: early stopping
# 3/3 [==============================] - 0s 3ms/step - loss: 2.0050 - nll_gaussian: 0.1017
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00032: early stopping
# 3/3 [==============================] - 0s 3ms/step - loss: 2.7559 - nll_gaussian: 2.1171
# Loss: 0.9333102062344552
# Computation time: 74.4s
# Refit the model with best hyperparamters
# {'layers': 1, 'neurons': 16, 'dropout': 0.40068596882425, 'noise_in': 0.46940374160772214, 'noise_sigma': 0.22310799027774744, 'noise_mu': 0.4458913276103962, 'l1_hidden': 0.03494298637521216, 'l2_hidden': 0.13495300785424463, 'l1_mu': 0.11371596582757391, 'l2_mu': 0.19338694210272867, 'l1_sigma': 0.15663625401679698, 'l2_sigma': 0.07122045733315273, 'lr': 0.0062190911973918515, 'batch_size': 100, 'epochs': 500, 'n_segments': 5, 'n_members_segment': 1, 'patience': 30, 'verbose': 0, 'pdf': 'normal', 'activation': 'relu', 'n_members': 5}
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00057: early stopping
# 3/3 [==============================] - 0s 2ms/step - loss: 0.9903 - nll_gaussian: 0.2035
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00060: early stopping
# 3/3 [==============================] - 0s 2ms/step - loss: 1.6705 - nll_gaussian: 0.5463
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00065: early stopping
# 3/3 [==============================] - 0s 2ms/step - loss: 1.4988 - nll_gaussian: 0.2920
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00068: early stopping
# 3/3 [==============================] - 0s 3ms/step - loss: 1.7504 - nll_gaussian: 0.3664
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00056: early stopping
# 3/3 [==============================] - 0s 3ms/step - loss: 1.4280 - nll_gaussian: 0.2398
# Loss: 0.3296097606420517
# Computation time: 74.4s
# best loss search: 0.28680832833051684
# loss refitting : 0.3296097606420517

# %% [markdown]
# ## Make predictions for the test data set
# Now we can use the trained models to make predicitons on the test data set to evaluate how good the model perfoms on a data set that it never saw before.

# %%
pred_mean, pred_std = model.predict(testX)

# %%
# from ninolearn.learn.fit import cross_hindcast_dem, cross_hindcast
# cross_hindcast(model, pipeline, 'DEM')
# # cross_hindcast_dem(model, pipeline, 'DEM')

# %% [markdown]
# ## Plot the prediction
# Let's see how the predicion is looking like

# %%
import matplotlib.pyplot as plt
from ninolearn.plot.prediction import plot_prediction
import pandas as pd
from ninolearn.pathes import plotdir

from os.path import join


plt.subplots(figsize=(15,3.5))
plt.axhspan(-0.5,
            -6,
            facecolor='blue',
            alpha=0.1,zorder=0)

plt.axhspan(0.5,
            6,
            facecolor='red',
            alpha=0.1,zorder=0)

plt.xlim(testtimey[0], testtimey[-1])
plt.ylim(-3,3)

# plot the prediction
plot_prediction(testtimey, pred_mean, std=pred_std, facecolor='royalblue', line_color='navy')

# plot the observation
plt.plot(timey, y, "r", label = 'observation')
plt.legend()

plt.savefig(join(plotdir, f'predicVSobs_{version}_{lead_time}lead'))

plt.show()

# %% [markdown]
# ## Evaluate the model
#
# We can evaluate the model a bit more quantitatively using the loss function that was used to train the model, namely the negative-log-likelihood of the Gaussian and the correlation between the predicted mean and the observed ONI index.

# %%
from ninolearn.plot.evaluation import plot_correlation, plot_confMat, plot_seasonal_skill

loss = model.evaluate(testy, pred_mean, pred_std)
print(f"Loss (Negative-Log-Likelihood): {loss}")

# make a plot of the seasonal correaltion
# note: - pd.tseries.offsets.MonthBegin(1) appears to ensure that the correlations are plotted
# agains the correct season
plot_correlation(testy, pred_mean, testtimey - pd.tseries.offsets.MonthBegin(1), title="")

# plot_seasonal_skill(leadtime, r_seas)

# plt.savefig(join(plotdir, f'correlation_{version}_{lead_time}lead'))
# Out:
# Loss (Negative-Log-Likelihood): 0.21670062002951598

# %%
from ninolearn.learn.fit import n_decades, lead_times, decade_color, decade_name
from ninolearn.learn.evaluation import evaluation_correlation, evaluation_decadal_correlation, evaluation_seasonal_correlation
from ninolearn.learn.fit import cross_hindcast_dem

cross_hindcast_dem(model, pipeline, 'DEM')

r_seas, p_seas = evaluation_seasonal_correlation('DEM', variable_name='prediction')

plot_seasonal_skill(lead_times, r_seas,  vmin=0, vmax=1)
plt.contour(np.arange(1,13),lead_times, p_seas, levels=[0.01, 0.05, 0.1], linestyles=['solid', 'dashed', 'dotted'], colors='k')
plt.title('Correlation skill')
plt.tight_layout()
# Out:
# Traceback (most recent call last):
#
#   File "/home/ivo/anaconda3/envs/ninolearn/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3343, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-13-08bf7f8c5693>", line 1, in <module>
#     from ninolearn.learn.fit import n_decades, lead_times, decade_color, decade_name
#
#   File "/home/ivo/Documents/GitHub/ninolearn/ninolearn/learn/fit.py", line 3
#     """
#
# ^
# SyntaxError: invalid syntax
