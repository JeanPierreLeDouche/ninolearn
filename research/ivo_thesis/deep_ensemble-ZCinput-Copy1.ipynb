# %% [markdown]
# # Deep ensemble for ENSO-forecasting
#
# In this tutorial you learn how to use a neural network model called Deep Ensemble (DE) for the ENSO forecasting. This network architecture was initially developed [Lakshminarayanan et al. (2017)](https://papers.nips.cc/paper/7219-simple-and-scalable-predictive-uncertainty-estimation-using-deep-ensembles.pdf).
#
# DEs are feed foreword neural networks that predict the mean and the standard deviation of a Gaussian. Hence, their predicion comes with an uncertainty estimation which is a valuable feature for ENSO-forecasting.

# %% [markdown]
# ## Create a data pipe line
#
# At first, we define a data pipeline. This is in general quite useful to keep your code clean and also to reuse the pipeline for later purpose.
#
# The data pipeline generates returns:
#
# 1. The feature array
#
# 2. The label array
#
# 3. The time  array corresponding to the time of the label
#
# NOTE (again): Lead time is defined as the time that passed between the last observed and the first date of the target season. Hence, negative appear, e.g. if you compare the DJF season with the target season JFM, you have a lead time of -2 month (Last observed date: Feburary 28/29, First date of the target season January 1).

# %%
from ninolearn.IO.read_processed import data_reader
from ninolearn.IO.read_raw import ZC_simple_read
import numpy as np
import pandas as pd

oneyear= pd.Timedelta(365, 'D')

# %%
version = 'mu11v3'
leadtime = 12

# t_start is defined using a funky timedelta because the starting date of the network analysis data is the last month
# of its start year which is 1951-12 therefore the time must start in 1952 with some months added for values lost in 
# interpolation. TODO: fix this by backwards interpolating the first values of the year and finding out what is happening 
# with the nms
times = np.unique(ZC_simple_read(version)['time'])

t_start = times[0] + pd.Timedelta((2*365 + 90),'D')
t_end = times[-1] - pd.Timedelta(90,'D')

print(f'tstart = {t_start} and tend = {t_end}')
# Out:
# tstart = 1952-04-07 14:17:30 and tend = 1962-06-17 20:33:20

# %%
from ninolearn.IO.read_raw import ZC_raw, ZC_h, ZC_oni
from ninolearn.preprocess.prepare import prep_nms
from ninolearn.plot.ZC_dem_plots import nms_plots
## read raw ZC data and save to 1x1 grid file in processeddir
## also makes field of h and sst
ZC_raw(version)

## calculates monthly averaged (?) fields of thermocline height within region 
## of interest. cacluate ONI in region of interest. calculate network metrics 
## from sst (Henk's suggestion) or thermocline height (like Paul)
ZC_h(version) 
ZC_oni(version)
prep_nms(version, 0.99, t_start, t_end)

# make plots
nms_plots(version)
# Out:
# using dimensions ('lat', 'lon') from data variable temperature as the horizontal dimensions for this dataset.
# /home/ivo/anaconda3/envs/ninolearn/lib/python3.6/site-packages/xesmf/frontend.py:524: FutureWarning: ``output_sizes`` should be given in the ``dask_gufunc_kwargs`` parameter. It will be removed as direct parameter in a future version.
#   keep_attrs=keep_attrs
# /home/ivo/anaconda3/envs/ninolearn/lib/python3.6/site-packages/xesmf/smm.py:93: UserWarning: Input array is not C_CONTIGUOUS. Will affect performance.
#   warnings.warn("Input array is not C_CONTIGUOUS. "
# - Read sst climatetology
# using dimensions ('lat', 'lon') from data variable temperature as the horizontal dimensions for this dataset.
# /home/ivo/anaconda3/envs/ninolearn/lib/python3.6/site-packages/xesmf/frontend.py:524: FutureWarning: ``output_sizes`` should be given in the ``dask_gufunc_kwargs`` parameter. It will be removed as direct parameter in a future version.
#   keep_attrs=keep_attrs
# WARNING:c2 variable equal to 0!
# WARNING:Wrong input for computation of hamming distance.
# WARNING:Wrong input for computation of corrected hamming distance.
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!

# %%
reader = data_reader(startdate=(t_start + pd.Timedelta(365,'D')) , enddate=(t_end - pd.Timedelta(2*365, 'D')) , lon_min = 124, lon_max = 280,
                         lat_min = -19, lat_max = 19)

oni = reader.read_csv(('oni_ZC_' +version))
h = reader.read_csv(('h_mean_ZC_' + version))

network_ssh = reader.read_statistic('network_metrics', variable='sst', dataset=('ZC_25x25_' + version), processed="anom")
c2 = network_ssh['fraction_clusters_size_2']
H = network_ssh['corrected_hamming_distance']

# %%
if h.shape[0] + c2.shape[0] - H.shape[0] - oni.shape[0] == 0:
    print('All datasets are of equal length')
# Out:
# All datasets are of equal length

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler

from ninolearn.utils import include_time_lag
from ninolearn.IO.read_processed import data_reader


def pipeline(lead_time):
    """
    Data pipeline for the processing of the data before the Deep Ensemble
    is trained.

    :type lead_time: int
    :param lead_time: The lead time in month.

    :returns: The feature "X" (at observation time), the label "y" (at lead
    time), the target season "timey" (least month)
    """
#     reader = data_reader(startdate='1952-01', enddate='1992-12', lon_min = 124, lon_max = 280,
#                          lat_min = -19, lat_max = 19)
    reader = data_reader(startdate=(t_start + oneyear), enddate=(t_end - 2*oneyear), lon_min = 124, lon_max = 280,
                         lat_min = -19, lat_max = 19)

    # indeces
    oni = reader.read_csv(('oni_ZC_' +version))
    h = reader.read_csv(('h_mean_ZC_' + version))
    #IOD unavailable in ZC87 model 
    
    # seasonal cycle
    sc = np.cos(np.arange(len(oni))/12*2*np.pi)

    # network metrics
    network_ssh = reader.read_statistic('network_metrics', variable='sst', dataset=('ZC_25x25_'+version), processed="anom")
    c2 = network_ssh['fraction_clusters_size_2']
    H = network_ssh['corrected_hamming_distance']

    # time lag
    time_lag = 12

    # shift such that lead time corresponds to the definition of lead time
    shift = 3

    # process features
    feature_unscaled = np.stack((oni, h,
                                 c2, H), axis=1)

    # scale each feature
    scalerX = StandardScaler()
    Xorg = scalerX.fit_transform(feature_unscaled)

    # set nans to 0.
    Xorg = np.nan_to_num(Xorg)

    # arange the feature array
    X = Xorg[:-lead_time-shift,:] # this chops of a bit at the end because matching labels will be offset by 
    # this amount. e.g. if our data runs until 2012 we need to remove X values for 2012 because we will use december 2011
    # to predict december 2012 
    
#     X = include_time_lag(X, max_lag=time_lag)
    X = include_time_lag(X, n_lags =time_lag)  # staggers the data with 1 month shifts so at each moment of input also
    # nlags amount of months before is available to the AI

    # arange label
    yorg = oni.values
    y = yorg[lead_time + time_lag + shift:] # labels offset by lead_time to predict into the future and time_lag 
    # because the include_time_lag function shifts X values forward by an amount n_lags=time_lag

    # get the time axis of the label
    timey = oni.index[lead_time + time_lag + shift:]

    return X, y, timey

# %% [markdown]
# ## Split the data set
#
# For the training and testing of machine learning models it is crucial to split the data set into:
#
# 1. __Train data set__ which is used to train the weights of the neural network
#
# 2. __Validation data set__ which is used to check for overfitting (e.g. when using early stopping) and to optimize the hyperparameters
#
# 3. __Test data set__ which is used to to evaluate the trained model.
#
# __NOTE:__ It is important to understand that hyperparamters must be tuned so that the result is best for the Validation data set and __not__ for the test data set. Otherwise you can not rule out the case that the specific hyperparameter setting just works good for the specific test data set but is not generally a good hyperparameter setting.
#
# In the following cell the train and the validation data set are still one data set, because this array will be later splitted into two arrays when th model is fitted.

# %%
import keras.backend as K
from ninolearn.learn.models.dem import DEM

# clear memory from previous sessions
K.clear_session()

# define the lead time
lead_time = leadtime

# get the features (X), the label (y) and 
# the time axis of the label (timey)
X, y, timey = pipeline(lead_time)

# split the data set into 
# test_indeces = (timey>='1987-01-01') & (timey<='1993-12-01')
test_indeces = (timey>=t_end - pd.Timedelta(5*365, 'D')) & (timey<=t_end)

train_val_indeces = np.invert(test_indeces)

train_val_X, train_val_y, train_val_timey = X[train_val_indeces,:], y[train_val_indeces], timey[train_val_indeces]
testX, testy, testtimey = X[test_indeces,:], y[test_indeces], timey[test_indeces]

# %%
print(y.shape, X.shape, timey.shape)
print('shapes of the data, labels and time axis is predictable, since there are now 4 features and 12 lags \
    making for 48 columns. The labels are offset from the input data by the lead time ')
# Out:
# (59,) (59, 48) (59,)
# shapes of the data, labels and time axis is predictable, since there are now 4 features and 12 lags     making for 48 columns. The labels are offset from the input data by the lead time

# %% [markdown]
# ## Fit the model
#
# Now it is time to train the model! For this a random search is used for all keyword arguments that are passed in a *list* to the DEM.set_parameters() method.

# %%
# initiated an instance of the DEM (Deep Ensemble Model) class
model = DEM()

# Set parameters
model.set_hyperparameters(searchtype='linear', layers=1, neurons=16, dropout=[0.1, 0.5], noise_in=[0.1,0.5], noise_sigma=[0.1,0.5],
                     noise_mu=[0.1,0.5], l1_hidden=[0.0, 0.2], l2_hidden=[0., 0.2],
                     l1_mu=[0.0, 0.2], l2_mu=[0.0, 0.2], l1_sigma=[0.0, 0.2],
                     l2_sigma=[0.0, 0.2], lr=[0.0001,0.01], batch_size=100, epochs=500, n_segments=5,
                     n_members_segment=1, patience=30, verbose=0, pdf='normal', activation = 'relu')

# Use a random search to find the optimal hyperparameters

model.fit_RandomizedSearch(train_val_X, train_val_y, train_val_timey, n_iter=20)
# Out:
# Search iteration Nr 1/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00255: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 1.9362 - nll_gaussian: 1.4152
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00221: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 0.5598 - nll_gaussian: -0.1101
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00184: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 0.5944 - nll_gaussian: -0.1462
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00202: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 1.0883 - nll_gaussian: 0.4300
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00137: early stopping
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6654 - nll_gaussian: -0.0687
# Loss: 0.30403328835964205
# Computation time: 174.8s
# New best hyperparameters
# Mean loss: 0.30403328835964205
# {'layers': 1, 'neurons': 16, 'dropout': 0.42906762674247, 'noise_in': 0.32309054310425867, 'noise_sigma': 0.1235623639464924, 'noise_mu': 0.2665093127294712, 'l1_hidden': 0.14760118365927513, 'l2_hidden': 0.007251018783834851, 'l1_mu': 0.12110204802937355, 'l2_mu': 0.041140258027727875, 'l1_sigma': 0.17693769180813615, 'l2_sigma': 0.07795175010924185, 'lr': 0.005307174593967908, 'batch_size': 100, 'epochs': 500, 'n_segments': 5, 'n_members_segment': 1, 'patience': 30, 'verbose': 0, 'pdf': 'normal', 'activation': 'relu', 'n_members': 5}
# Search iteration Nr 2/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00106: early stopping
# 1/1 [==============================] - 0s 3ms/step - loss: 3.1561 - nll_gaussian: 1.1156
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00093: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 3.7380 - nll_gaussian: 0.1215
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00048: early stopping
# 1/1 [==============================] - 0s 2ms/step - loss: 2.7598 - nll_gaussian: 0.3558
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00240: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 3.4211 - nll_gaussian: 0.0397
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00080: early stopping
# 1/1 [==============================] - 0s 2ms/step - loss: 4.0479 - nll_gaussian: 0.2695
# Loss: 0.3804187968373299
# Computation time: 100.5s
# Search iteration Nr 3/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00046: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 6.9987 - nll_gaussian: 3.5757
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00094: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 3.0441 - nll_gaussian: 0.2860
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00147: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 4.3415 - nll_gaussian: 0.2486
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00103: early stopping
# 1/1 [==============================] - 0s 2ms/step - loss: 7.1960 - nll_gaussian: 0.6603
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00086: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 1.4597 - nll_gaussian: 0.0192
# Loss: 0.9579706706106663
# Computation time: 89.3s
# Search iteration Nr 4/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00166: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 2.1706 - nll_gaussian: 1.5576
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00194: early stopping
# 1/1 [==============================] - 0s 3ms/step - loss: 0.5805 - nll_gaussian: -0.0659
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00223: early stopping
# 1/1 [==============================] - 0s 991us/step - loss: 0.5030 - nll_gaussian: -0.1247
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00207: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 1.0700 - nll_gaussian: 0.4544
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00120: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 0.7497 - nll_gaussian: -0.0356
# Loss: 0.35714280903339385
# Computation time: 164.9s
# Search iteration Nr 5/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00205: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 4.7187 - nll_gaussian: 3.3648
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00309: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 1.3749 - nll_gaussian: 0.0364
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00212: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 1.4006 - nll_gaussian: 0.1255
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00258: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 2.5245 - nll_gaussian: 1.4480
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00244: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 0.9643 - nll_gaussian: -0.0726
# Loss: 0.9804197072982788
# Computation time: 212.3s
# Search iteration Nr 6/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00137: early stopping
# 1/1 [==============================] - 0s 3ms/step - loss: 2.1328 - nll_gaussian: 1.4046
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00114: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 1.0448 - nll_gaussian: 0.0434
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00150: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 0.8333 - nll_gaussian: -0.0608
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00145: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 1.3079 - nll_gaussian: 0.6145
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00102: early stopping
# 1/1 [==============================] - 0s 3ms/step - loss: 1.0137 - nll_gaussian: -0.1218
# Loss: 0.3759811282157898
# Computation time: 112.4s
# Search iteration Nr 7/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00075: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 7.1837 - nll_gaussian: 1.7139
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00105: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 7.5659 - nll_gaussian: 0.7167
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00098: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 7.0101 - nll_gaussian: 0.3187
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00067: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 7.0424 - nll_gaussian: 1.7925
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00088: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 5.3825 - nll_gaussian: -0.1882
# Loss: 0.8707135140895843
# Computation time: 56.1s
# Search iteration Nr 8/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00042: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 11.8003 - nll_gaussian: 8.6166
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00095: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 6.3964 - nll_gaussian: 3.1583
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00078: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 6.2751 - nll_gaussian: 3.1069
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00037: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 8.1974 - nll_gaussian: 4.9299
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00130: early stopping
# 1/1 [==============================] - 0s 4ms/step - loss: 3.8007 - nll_gaussian: 0.7522
# Loss: 4.112766408920288
# Computation time: 50.6s
# Search iteration Nr 9/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00202: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 3.9231 - nll_gaussian: -0.1959
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00288: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 3.7831 - nll_gaussian: -0.2269
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00055: early stopping
# 1/1 [==============================] - 0s 2ms/step - loss: 3.2074 - nll_gaussian: 0.4671
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00094: early stopping
# 1/1 [==============================] - 0s 2ms/step - loss: 6.0058 - nll_gaussian: 2.5061
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00097: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 2.9777 - nll_gaussian: 0.1423
# Loss: 0.538529634475708
# Computation time: 89.5s
# Search iteration Nr 10/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00101: early stopping
# 1/1 [==============================] - 0s 2ms/step - loss: 3.4021 - nll_gaussian: 2.3206
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00112: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 4.3252 - nll_gaussian: 0.2087
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00123: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 1.3202 - nll_gaussian: 0.2572
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00142: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 3.1346 - nll_gaussian: 0.3584
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00076: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 1.9601 - nll_gaussian: 0.0239
# Loss: 0.6337782502174377
# Computation time: 67.7s
# Search iteration Nr 11/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00099: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 3.4414 - nll_gaussian: 0.9387
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00118: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 2.2064 - nll_gaussian: -0.0101
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00067: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 5.2023 - nll_gaussian: 0.5983
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00147: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 5.7190 - nll_gaussian: 0.2455
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00051: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 3.1087 - nll_gaussian: 0.0539
# Loss: 0.36526445858180523
# Computation time: 59.1s
# Search iteration Nr 12/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00036: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 9.8287 - nll_gaussian: 8.3257
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00146: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 4.0797 - nll_gaussian: 2.6206
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00070: early stopping
# 1/1 [==============================] - 0s 3ms/step - loss: 4.2584 - nll_gaussian: 2.8317
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00047: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 6.3371 - nll_gaussian: 4.8712
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00117: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 2.3486 - nll_gaussian: 0.7728
# Loss: 3.884398913383484
# Computation time: 87.4s
# Search iteration Nr 13/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00063: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 9.4915 - nll_gaussian: 7.1236
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00264: early stopping
# 1/1 [==============================] - 0s 3ms/step - loss: 3.8080 - nll_gaussian: 0.4604
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00179: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 4.0112 - nll_gaussian: 0.5995
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00207: early stopping
# 1/1 [==============================] - 0s 3ms/step - loss: 4.0165 - nll_gaussian: 0.5716
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00137: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 3.2882 - nll_gaussian: 0.4874
# Loss: 1.8485193610191346
# Computation time: 186.2s
# Search iteration Nr 14/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00077: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 9.8094 - nll_gaussian: 8.0558
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00106: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 5.2630 - nll_gaussian: 3.1759
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00089: early stopping
# 1/1 [==============================] - 0s 998us/step - loss: 5.0063 - nll_gaussian: 2.9252
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00270: early stopping
# 1/1 [==============================] - 0s 3ms/step - loss: 6.1311 - nll_gaussian: 3.8943
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00106: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 3.0112 - nll_gaussian: 0.6716
# Loss: 3.7445478081703185
# Computation time: 162.7s
# Search iteration Nr 15/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00090: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 11.3479 - nll_gaussian: 6.4405
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00091: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 5.6290 - nll_gaussian: 0.2676
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00140: early stopping
# 1/1 [==============================] - 0s 4ms/step - loss: 5.3666 - nll_gaussian: -0.7504
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00129: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 6.4107 - nll_gaussian: 0.3715
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00061: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 4.1059 - nll_gaussian: 0.4200
# Loss: 1.3498262405395507
# Computation time: 136.7s
# Search iteration Nr 16/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00078: early stopping
# 1/1 [==============================] - 0s 2ms/step - loss: 7.7338 - nll_gaussian: 3.2162
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00128: early stopping
# 1/1 [==============================] - 0s 3ms/step - loss: 3.4823 - nll_gaussian: 0.5657
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00105: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 3.7404 - nll_gaussian: 0.3553
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00112: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 10.8646 - nll_gaussian: 0.8634
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00050: early stopping
# 1/1 [==============================] - 0s 6ms/step - loss: 3.9760 - nll_gaussian: 0.3404
# Loss: 1.0682262539863587
# Computation time: 137.0s
# Search iteration Nr 17/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00103: early stopping
# 1/1 [==============================] - 0s 2ms/step - loss: 8.6131 - nll_gaussian: 6.6186
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00082: early stopping
# 1/1 [==============================] - 0s 1000us/step - loss: 4.0506 - nll_gaussian: 2.4419
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00210: early stopping
# 1/1 [==============================] - 0s 3ms/step - loss: 3.4985 - nll_gaussian: 0.9516
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00139: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 6.0953 - nll_gaussian: 3.6602
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00105: early stopping
# 1/1 [==============================] - 0s 3ms/step - loss: 2.4434 - nll_gaussian: 0.6370
# Loss: 2.861875128746033
# Computation time: 178.2s
# Search iteration Nr 18/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00116: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 3.9565 - nll_gaussian: 1.8701
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00107: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 2.0713 - nll_gaussian: 0.3457
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00206: early stopping
# 1/1 [==============================] - 0s 3ms/step - loss: 1.2697 - nll_gaussian: 0.1544
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00140: early stopping
# 1/1 [==============================] - 0s 2ms/step - loss: 1.8120 - nll_gaussian: 0.8541
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00113: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 1.9331 - nll_gaussian: -0.0571
# Loss: 0.6334659188985825
# Computation time: 171.0s
# Search iteration Nr 19/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00187: early stopping
# 1/1 [==============================] - 0s 3ms/step - loss: 1.8497 - nll_gaussian: 1.5165
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00171: early stopping
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2287 - nll_gaussian: -0.1963
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00203: early stopping
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0660 - nll_gaussian: -0.3243
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00182: early stopping
# 1/1 [==============================] - 0s 2ms/step - loss: 0.6925 - nll_gaussian: 0.3528
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00216: early stopping
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1418 - nll_gaussian: -0.2926
# Loss: 0.21123339235782623
# Computation time: 224.1s
# New best hyperparameters
# Mean loss: 0.21123339235782623
# {'layers': 1, 'neurons': 16, 'dropout': 0.1830311489020433, 'noise_in': 0.23782261413122355, 'noise_sigma': 0.10824046169375628, 'noise_mu': 0.278293099845091, 'l1_hidden': 0.06933573038349357, 'l2_hidden': 0.1716538067035315, 'l1_mu': 0.007675790983790365, 'l2_mu': 0.012030734667862043, 'l1_sigma': 0.1881910498844119, 'l2_sigma': 0.1444954130849465, 'lr': 0.0027917734144513994, 'batch_size': 100, 'epochs': 500, 'n_segments': 5, 'n_members_segment': 1, 'patience': 30, 'verbose': 0, 'pdf': 'normal', 'activation': 'relu', 'n_members': 5}
# Search iteration Nr 20/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00095: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 4.8154 - nll_gaussian: 0.1349
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00053: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 5.1380 - nll_gaussian: 0.4924
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00075: early stopping
# 1/1 [==============================] - 0s 3ms/step - loss: 6.8674 - nll_gaussian: 0.7981
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00095: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 6.8945 - nll_gaussian: 0.1920
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00083: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 6.6157 - nll_gaussian: -0.0719
# Loss: 0.30909082740545274
# Computation time: 109.3s
# Refit the model with best hyperparamters
# {'layers': 1, 'neurons': 16, 'dropout': 0.1830311489020433, 'noise_in': 0.23782261413122355, 'noise_sigma': 0.10824046169375628, 'noise_mu': 0.278293099845091, 'l1_hidden': 0.06933573038349357, 'l2_hidden': 0.1716538067035315, 'l1_mu': 0.007675790983790365, 'l2_mu': 0.012030734667862043, 'l1_sigma': 0.1881910498844119, 'l2_sigma': 0.1444954130849465, 'lr': 0.0027917734144513994, 'batch_size': 100, 'epochs': 500, 'n_segments': 5, 'n_members_segment': 1, 'patience': 30, 'verbose': 0, 'pdf': 'normal', 'activation': 'relu', 'n_members': 5}
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00172: early stopping
# 1/1 [==============================] - 0s 3ms/step - loss: 1.7812 - nll_gaussian: 1.3421
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00207: early stopping
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1663 - nll_gaussian: -0.1921
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00224: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0628 - nll_gaussian: -0.2988
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00223: early stopping
# 1/1 [==============================] - 0s 2ms/step - loss: 0.4747 - nll_gaussian: 0.1751
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00220: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1015 - nll_gaussian: -0.2797
# Loss: 0.14932256937026978
# Computation time: 244.9s
# best loss search: 0.21123339235782623
# loss refitting : 0.14932256937026978

# %% [markdown]
# ## Make predictions for the test data set
# Now we can use the trained models to make predicitons on the test data set to evaluate how good the model perfoms on a data set that it never saw before.

# %%
# IG:  saving models in order to do cross hindcasts later

from ninolearn.pathes import modeldir 
model.save(location=modeldir)

# %%
pred_mean, pred_std = model.predict(testX)

# %%
# from ninolearn.learn.fit import cross_hindcast_dem, cross_hindcast
# cross_hindcast(model, pipeline, 'DEM')
# # cross_hindcast_dem(model, pipeline, 'DEM')

# %% [markdown]
# ## Plot the prediction
# Let's see how the predicion is looking like

# %%
import matplotlib.pyplot as plt
from ninolearn.plot.prediction import plot_prediction
import pandas as pd
from ninolearn.pathes import plotdir

from os.path import join


plt.subplots(figsize=(15,3.5))
plt.axhspan(-0.5,
            -6,
            facecolor='blue',
            alpha=0.1,zorder=0)

plt.axhspan(0.5,
            6,
            facecolor='red',
            alpha=0.1,zorder=0)

plt.xlim(testtimey[0], testtimey[-1])
plt.ylim(-3,3)

# plot the prediction
plot_prediction(testtimey, pred_mean, std=pred_std, facecolor='royalblue', line_color='navy')

# plot the observation
plt.plot(timey, y, "r", label = 'observation')
plt.legend()

plt.savefig(join(plotdir, f'predicVSobs_{version}_{lead_time}lead'))

plt.show()

# %% [markdown]
# ## Evaluate the model
#
# We can evaluate the model a bit more quantitatively using the loss function that was used to train the model, namely the negative-log-likelihood of the Gaussian and the correlation between the predicted mean and the observed ONI index.

# %%
from ninolearn.plot.evaluation import plot_correlation, plot_confMat, plot_seasonal_skill

loss = model.evaluate(testy, pred_mean, pred_std)
print(f"Loss (Negative-Log-Likelihood): {loss}")

# make a plot of the seasonal correaltion
# note: - pd.tseries.offsets.MonthBegin(1) appears to ensure that the correlations are plotted
# agains the correct season
plot_correlation(testy, pred_mean, testtimey - pd.tseries.offsets.MonthBegin(1), title="")

# plot_seasonal_skill(leadtime, r_seas)

# plt.savefig(join(plotdir, f'correlation_{version}_{lead_time}lead'))
# Out:
# Loss (Negative-Log-Likelihood): 1.5766603274801112

# %%
# %load_ext autoreload

# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from ninolearn.learn.fit import cross_hindcast_dem

cross_hindcast_dem(model, pipeline, 'DEM')
# Out:
# updated code #2 (!)
#
# ##################################################################
# Lead time: 0 months
# ##################################################################
#
# Predict: 1963-01-01 till 1971-12-01
# --------------------------------------
# []
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-59-852a7ba4b2e1> in <module>
#       1 from ninolearn.learn.fit import cross_hindcast_dem
#       2
# ----> 3 cross_hindcast_dem(model, pipeline, 'DEM')
#
# ~/Documents/GitHub/ninolearn/ninolearn/learn/fit.py in cross_hindcast_dem(model, pipeline, model_name)
#     163     """
#     164     print("updated code #2 (!)")
# --> 165     cross_hindcast(model, pipeline, model_name)
#     166
#     167     std_estimate = xr.open_dataarray(join(processeddir, f'{model_name}_std_estimate.nc'))
#
# ~/Documents/GitHub/ninolearn/ninolearn/learn/fit.py in cross_hindcast(model, pipeline, model_name, **kwargs)
#     103
#     104             m = model#(**kwargs)
# --> 105             m.load(location=modeldir, dir_name=f'{model_name}_decade{decades[j]}_lead{lead_time}')
#     106
#     107             # allocate arrays and variables for which the model must be loaded
#
# ~/Documents/GitHub/ninolearn/ninolearn/learn/models/dem.py in load(self, location, dir_name)
#     415             self.ensemble.append(load_model(file_path))
#     416         print(self.ensemble)
# --> 417         output_neurons = self.ensemble[0].get_output_shape_at(0)[1]
#     418
#     419         if output_neurons==2:
#
# IndexError: list index out of range

# %%
from ninolearn.learn.fit import n_decades, lead_times, decade_color, decade_name
from ninolearn.learn.evaluation import evaluation_correlation, evaluation_decadal_correlation, evaluation_seasonal_correlation
from ninolearn.learn.fit import cross_hindcast_dem

cross_hindcast_dem(model, pipeline, 'DEM')

r_seas, p_seas = evaluation_seasonal_correlation('DEM', variable_name='prediction')

plot_seasonal_skill(lead_times, r_seas,  vmin=0, vmax=1)
plt.contour(np.arange(1,13),lead_times, p_seas, levels=[0.01, 0.05, 0.1], linestyles=['solid', 'dashed', 'dotted'], colors='k')
plt.title('Correlation skill')
plt.tight_layout()
