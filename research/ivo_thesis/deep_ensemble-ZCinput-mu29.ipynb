# %% [markdown]
# # Deep ensemble for ENSO-forecasting
#
# In this tutorial you learn how to use a neural network model called Deep Ensemble (DE) for the ENSO forecasting. This network architecture was initially developed [Lakshminarayanan et al. (2017)](https://papers.nips.cc/paper/7219-simple-and-scalable-predictive-uncertainty-estimation-using-deep-ensembles.pdf).
#
# DEs are feed foreword neural networks that predict the mean and the standard deviation of a Gaussian. Hence, their predicion comes with an uncertainty estimation which is a valuable feature for ENSO-forecasting.

# %% [markdown]
# ## Create a data pipe line
#
# At first, we define a data pipeline. This is in general quite useful to keep your code clean and also to reuse the pipeline for later purpose.
#
# The data pipeline generates returns:
#
# 1. The feature array
#
# 2. The label array
#
# 3. The time  array corresponding to the time of the label
#
# NOTE (again): Lead time is defined as the time that passed between the last observed and the first date of the target season. Hence, negative appear, e.g. if you compare the DJF season with the target season JFM, you have a lead time of -2 month (Last observed date: Feburary 28/29, First date of the target season January 1).

# %%
from ninolearn.IO.read_processed import data_reader
from ninolearn.IO.read_raw import ZC_simple_read
import numpy as np
import pandas as pd

oneyear= pd.Timedelta(365, 'D')

# %%
version = 'mu29'
leadtime = 24

# t_start is defined using a funky timedelta because the starting date of the network analysis data is the last month
# of its start year which is 1951-12 therefore the time must start in 1952 with some months added for values lost in 
# interpolation. TODO: fix this by backwards interpolating the first values of the year and finding out what is happening 
# with the nms
times = np.unique(ZC_simple_read(version)['time'])

t_start = times[0] + pd.Timedelta((2*365 + 90),'D')
t_end = times[-1] - pd.Timedelta(90,'D')

print(f'tstart = {t_start} and tend = {t_end}')
# Out:
# tstart = 1952-04-15 04:35:00 and tend = 1969-09-04 12:06:40

# %%
from ninolearn.IO.read_raw import ZC_raw, ZC_h, ZC_oni
from ninolearn.preprocess.prepare import prep_nms
from ninolearn.plot.ZC_dem_plots import nms_plots
## read raw ZC data and save to 1x1 grid file in processeddir
## also makes field of h and sst
ZC_raw(version)

## calculates monthly averaged (?) fields of thermocline height within region 
## of interest. cacluate ONI in region of interest. calculate network metrics 
## from sst (Henk's suggestion) or thermocline height (like Paul)
ZC_h(version) 
ZC_oni(version)
prep_nms(version, 0.99, t_start, t_end)

# make plots
nms_plots(version)
# Out:
# using dimensions ('lat', 'lon') from data variable temperature as the horizontal dimensions for this dataset.
# /home/ivo/anaconda3/envs/ninolearn/lib/python3.6/site-packages/xesmf/frontend.py:524: FutureWarning: ``output_sizes`` should be given in the ``dask_gufunc_kwargs`` parameter. It will be removed as direct parameter in a future version.
#   keep_attrs=keep_attrs
# /home/ivo/anaconda3/envs/ninolearn/lib/python3.6/site-packages/xesmf/smm.py:93: UserWarning: Input array is not C_CONTIGUOUS. Will affect performance.
#   warnings.warn("Input array is not C_CONTIGUOUS. "
# - Read sst climatetology
# using dimensions ('lat', 'lon') from data variable temperature as the horizontal dimensions for this dataset.
# /home/ivo/anaconda3/envs/ninolearn/lib/python3.6/site-packages/xesmf/frontend.py:524: FutureWarning: ``output_sizes`` should be given in the ``dask_gufunc_kwargs`` parameter. It will be removed as direct parameter in a future version.
#   keep_attrs=keep_attrs
# WARNING:Wrong input for computation of hamming distance.
# WARNING:Wrong input for computation of corrected hamming distance.
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!

# %%
reader = data_reader(startdate=(t_start + pd.Timedelta(365,'D')) , enddate=(t_end - pd.Timedelta(365, 'D')) , lon_min = 124, lon_max = 280,
                         lat_min = -19, lat_max = 19)

oni = reader.read_csv(('oni_ZC_' +version))
h = reader.read_csv(('h_mean_ZC_' + version))

network_ssh = reader.read_statistic('network_metrics', variable='sst', dataset=('ZC_25x25_' + version), processed="anom")
c2 = network_ssh['fraction_clusters_size_2']
H = network_ssh['corrected_hamming_distance']

# %%
if h.shape[0] + c2.shape[0] - H.shape[0] - oni.shape[0] == 0:
    print('All datasets are of equal length')
# Out:
# All datasets are of equal length

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler

from ninolearn.utils import include_time_lag
from ninolearn.IO.read_processed import data_reader


def pipeline(lead_time):
    """
    Data pipeline for the processing of the data before the Deep Ensemble
    is trained.

    :type lead_time: int
    :param lead_time: The lead time in month.

    :returns: The feature "X" (at observation time), the label "y" (at lead
    time), the target season "timey" (least month)
    """
#     reader = data_reader(startdate='1952-01', enddate='1992-12', lon_min = 124, lon_max = 280,
#                          lat_min = -19, lat_max = 19)
    reader = data_reader(startdate=(t_start + oneyear), enddate=(t_end - oneyear), lon_min = 124, lon_max = 280,
                         lat_min = -19, lat_max = 19)

    # indeces
    oni = reader.read_csv(('oni_ZC_' +version))
    h = reader.read_csv(('h_mean_ZC_' + version))
    #IOD unavailable in ZC87 model 
    
    # seasonal cycle
    sc = np.cos(np.arange(len(oni))/12*2*np.pi)

    # network metrics
    network_ssh = reader.read_statistic('network_metrics', variable='sst', dataset=('ZC_25x25_'+version), processed="anom")
    c2 = network_ssh['fraction_clusters_size_2']
    H = network_ssh['corrected_hamming_distance']

    # time lag
    time_lag = 12

    # shift such that lead time corresponds to the definition of lead time
    shift = 3

    # process features
    feature_unscaled = np.stack((oni, h,
                                 c2, H), axis=1)

    # scale each feature
    scalerX = StandardScaler()
    Xorg = scalerX.fit_transform(feature_unscaled)

    # set nans to 0.
    Xorg = np.nan_to_num(Xorg)

    # arange the feature array
    X = Xorg[:-lead_time-shift,:]
#     X = include_time_lag(X, max_lag=time_lag)
    X = include_time_lag(X, n_lags =12) 


    # arange label
    yorg = oni.values
    y = yorg[lead_time + time_lag + shift:]

    # get the time axis of the label
    timey = oni.index[lead_time + time_lag + shift:]

    return X, y, timey

# %% [markdown]
# ## Split the data set
#
# For the training and testing of machine learning models it is crucial to split the data set into:
#
# 1. __Train data set__ which is used to train the weights of the neural network
#
# 2. __Validation data set__ which is used to check for overfitting (e.g. when using early stopping) and to optimize the hyperparameters
#
# 3. __Test data set__ which is used to to evaluate the trained model.
#
# __NOTE:__ It is important to understand that hyperparamters must be tuned so that the result is best for the Validation data set and __not__ for the test data set. Otherwise you can not rule out the case that the specific hyperparameter setting just works good for the specific test data set but is not generally a good hyperparameter setting.
#
# In the following cell the train and the validation data set are still one data set, because this array will be later splitted into two arrays when th model is fitted.

# %%
import keras.backend as K
from ninolearn.learn.models.dem import DEM

# clear memory from previous sessions
K.clear_session()

# define the lead time
lead_time = leadtime

# get the features (X), the label (y) and 
# the time axis of the label (timey)
X, y, timey = pipeline(lead_time)

# split the data set into 
# test_indeces = (timey>='1987-01-01') & (timey<='1993-12-01')
test_indeces = (timey>=t_end - pd.Timedelta(5*365, 'D')) & (timey<=t_end)

train_val_indeces = np.invert(test_indeces)

train_val_X, train_val_y, train_val_timey = X[train_val_indeces,:], y[train_val_indeces], timey[train_val_indeces]
testX, testy, testtimey = X[test_indeces,:], y[test_indeces], timey[test_indeces]

# %% [markdown]
# ## Fit the model
#
# Now it is time to train the model! For this a random search is used for all keyword arguments that are passed in a *list* to the DEM.set_parameters() method.

# %%
# initiated an instance of the DEM (Deep Ensemble Model) class
model = DEM()

# Set parameters
model.set_hyperparameters(searchtype='linear', layers=1, neurons=16, dropout=[0.1, 0.5], noise_in=[0.1,0.5], noise_sigma=[0.1,0.5],
                     noise_mu=[0.1,0.5], l1_hidden=[0.0, 0.2], l2_hidden=[0., 0.2],
                     l1_mu=[0.0, 0.2], l2_mu=[0.0, 0.2], l1_sigma=[0.0, 0.2],
                     l2_sigma=[0.0, 0.2], lr=[0.0001,0.01], batch_size=100, epochs=500, n_segments=5,
                     n_members_segment=1, patience=30, verbose=0, pdf='normal', activation = 'relu')

# Use a random search to find the optimal hyperparameters

model.fit_RandomizedSearch(train_val_X, train_val_y, train_val_timey, n_iter=20)
# Out:
# Search iteration Nr 1/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00264: early stopping
# 1/1 [==============================] - 0s 3ms/step - loss: 3.0808 - nll_gaussian: 0.0356
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00154: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 2.9785 - nll_gaussian: 1.0390
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00132: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 2.9534 - nll_gaussian: 0.7822
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00031: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 3.8590 - nll_gaussian: 2.1360
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00108: early stopping
# 1/1 [==============================] - 0s 2ms/step - loss: 2.9248 - nll_gaussian: 1.0376
# Loss: 1.0060711733996868
# Computation time: 121.3s
# New best hyperparameters
# Mean loss: 1.0060711733996868
# {'layers': 1, 'neurons': 16, 'dropout': 0.13051531994150667, 'noise_in': 0.39421146439564103, 'noise_sigma': 0.2950398037028248, 'noise_mu': 0.3895687059376477, 'l1_hidden': 0.09593796116250308, 'l2_hidden': 0.032105308748164044, 'l1_mu': 0.029589384178582367, 'l2_mu': 0.18341050982992363, 'l1_sigma': 0.027755591381040737, 'l2_sigma': 0.17711646972675088, 'lr': 0.002332524532762331, 'batch_size': 100, 'epochs': 500, 'n_segments': 5, 'n_members_segment': 1, 'patience': 30, 'verbose': 0, 'pdf': 'normal', 'activation': 'relu', 'n_members': 5}
# Search iteration Nr 2/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00228: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 5.8315 - nll_gaussian: 0.1797
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00201: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 9.4549 - nll_gaussian: 1.6790
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00142: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 5.9620 - nll_gaussian: 0.4489
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00161: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 5.7915 - nll_gaussian: 0.6067
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00256: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 7.0484 - nll_gaussian: 0.0441
# Loss: 0.5916754506528378
# Computation time: 152.9s
# New best hyperparameters
# Mean loss: 0.5916754506528378
# {'layers': 1, 'neurons': 16, 'dropout': 0.19491461233585353, 'noise_in': 0.1663272293239057, 'noise_sigma': 0.28228833999578906, 'noise_mu': 0.19409527427495657, 'l1_hidden': 0.19556836825108176, 'l2_hidden': 0.1327410672698426, 'l1_mu': 0.1864316818497673, 'l2_mu': 0.1741036961699997, 'l1_sigma': 0.12599435771253883, 'l2_sigma': 0.15064809496990528, 'lr': 0.004266899044223538, 'batch_size': 100, 'epochs': 500, 'n_segments': 5, 'n_members_segment': 1, 'patience': 30, 'verbose': 0, 'pdf': 'normal', 'activation': 'relu', 'n_members': 5}
# Search iteration Nr 3/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00097: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 3.0851 - nll_gaussian: 0.3800
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00063: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 4.2561 - nll_gaussian: 2.0048
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00165: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 4.6682 - nll_gaussian: 0.7842
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00033: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 3.7605 - nll_gaussian: 1.9921
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00032: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 3.0643 - nll_gaussian: 1.3585
# Loss: 1.3039230823516845
# Computation time: 72.0s
# Search iteration Nr 4/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00319: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 0.3991 - nll_gaussian: -0.3761
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00223: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 1.2059 - nll_gaussian: 0.6417
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00263: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 0.4015 - nll_gaussian: -0.2475
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00271: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 0.9943 - nll_gaussian: 0.4452
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00241: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 0.4476 - nll_gaussian: -0.2077
# Loss: 0.051116743683815004
# Computation time: 215.4s
# New best hyperparameters
# Mean loss: 0.051116743683815004
# {'layers': 1, 'neurons': 16, 'dropout': 0.3115800783838901, 'noise_in': 0.4254990730330461, 'noise_sigma': 0.12037425754350012, 'noise_mu': 0.11143412315465567, 'l1_hidden': 0.1022745969404872, 'l2_hidden': 0.1440114334008774, 'l1_mu': 0.06050252574125843, 'l2_mu': 0.06617777578415543, 'l1_sigma': 0.13618261835417075, 'l2_sigma': 0.0018530589707266066, 'lr': 0.0033372910002052196, 'batch_size': 100, 'epochs': 500, 'n_segments': 5, 'n_members_segment': 1, 'patience': 30, 'verbose': 0, 'pdf': 'normal', 'activation': 'relu', 'n_members': 5}
# Search iteration Nr 5/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00184: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 0.3793 - nll_gaussian: -0.2517
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00216: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 1.2211 - nll_gaussian: 0.5823
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00148: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 0.5725 - nll_gaussian: -0.0909
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00104: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 1.1969 - nll_gaussian: 0.5583
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00195: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 0.6161 - nll_gaussian: -0.1499
# Loss: 0.1296335831284523
# Computation time: 90.5s
# Search iteration Nr 6/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00084: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 3.2536 - nll_gaussian: 0.7898
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00075: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 4.8457 - nll_gaussian: 2.3383
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00125: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 3.5838 - nll_gaussian: 1.1749
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00031: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 4.5906 - nll_gaussian: 2.0634
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00104: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 3.7501 - nll_gaussian: 1.2191
# Loss: 1.51709885597229
# Computation time: 59.6s
# Search iteration Nr 7/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00068: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 3.1201 - nll_gaussian: 0.2136
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00122: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 3.8657 - nll_gaussian: 0.2976
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00043: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 2.8969 - nll_gaussian: 0.6574
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00076: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 5.1898 - nll_gaussian: 1.3031
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00036: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 2.8002 - nll_gaussian: 1.2027
# Loss: 0.734866800904274
# Computation time: 72.5s
# Search iteration Nr 8/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00200: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 4.0643 - nll_gaussian: -0.2869
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00032: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 5.2237 - nll_gaussian: 2.5138
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00031: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 4.1621 - nll_gaussian: 1.3099
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00033: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 4.4476 - nll_gaussian: 2.0806
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00107: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 3.8678 - nll_gaussian: 0.8764
# Loss: 1.298755705356598
# Computation time: 100.6s
# Search iteration Nr 9/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00038: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 1.7406 - nll_gaussian: 0.7340
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00031: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 3.3320 - nll_gaussian: 2.4189
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00112: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 2.0669 - nll_gaussian: 0.4130
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00087: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 2.9746 - nll_gaussian: 1.3015
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00048: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 1.9780 - nll_gaussian: 0.7715
# Loss: 1.1277615964412688
# Computation time: 81.1s
# Search iteration Nr 10/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00071: early stopping
# 1/1 [==============================] - 0s 4ms/step - loss: 4.2142 - nll_gaussian: 0.0842
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00270: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 8.4419 - nll_gaussian: 1.8272
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00045: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 4.3105 - nll_gaussian: 1.1084
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00070: early stopping
# 1/1 [==============================] - 0s 3ms/step - loss: 5.4844 - nll_gaussian: 1.9856
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00257: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 6.3656 - nll_gaussian: 0.2779
# Loss: 1.0566663339734077
# Computation time: 148.9s
# Search iteration Nr 11/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00243: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 1.0055 - nll_gaussian: -0.1174
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00227: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 1.7094 - nll_gaussian: 0.6487
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00429: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 1.1565 - nll_gaussian: 0.1394
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00081: early stopping
# 1/1 [==============================] - 0s 2ms/step - loss: 2.5591 - nll_gaussian: 1.5423
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00043: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 2.3834 - nll_gaussian: 1.4117
# Loss: 0.7249262496829033
# Computation time: 214.7s
# Search iteration Nr 12/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00099: early stopping
# 1/1 [==============================] - 0s 3ms/step - loss: 6.0891 - nll_gaussian: 0.3991
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00031: early stopping
# 1/1 [==============================] - 0s 2ms/step - loss: 6.1509 - nll_gaussian: 2.5561
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00096: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 6.4410 - nll_gaussian: 0.6016
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00198: early stopping
# 1/1 [==============================] - 0s 9ms/step - loss: 8.0595 - nll_gaussian: 0.8878
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00062: early stopping
# 1/1 [==============================] - 0s 3ms/step - loss: 6.1412 - nll_gaussian: 1.2656
# Loss: 1.1420616149902343
# Computation time: 102.6s
# Search iteration Nr 13/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00075: early stopping
# 1/1 [==============================] - 0s 2ms/step - loss: 1.1924 - nll_gaussian: -0.1650
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00031: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 3.0488 - nll_gaussian: 2.5796
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00156: early stopping
# 1/1 [==============================] - 0s 3ms/step - loss: 1.9019 - nll_gaussian: 0.2665
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00084: early stopping
# 1/1 [==============================] - 0s 2ms/step - loss: 2.4142 - nll_gaussian: 0.9151
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00154: early stopping
# 1/1 [==============================] - 0s 2ms/step - loss: 2.3823 - nll_gaussian: 0.2987
# Loss: 0.7789825826883316
# Computation time: 145.2s
# Search iteration Nr 14/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00139: early stopping
# 1/1 [==============================] - 0s 2ms/step - loss: 3.8969 - nll_gaussian: 0.0817
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00246: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 3.9365 - nll_gaussian: 0.5237
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00111: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 3.5407 - nll_gaussian: -0.0604
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00064: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 3.2460 - nll_gaussian: 0.6377
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00099: early stopping
# 1/1 [==============================] - 0s 2ms/step - loss: 3.3347 - nll_gaussian: 0.3869
# Loss: 0.31391003876924517
# Computation time: 160.0s
# Search iteration Nr 15/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00338: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 0.9202 - nll_gaussian: -0.0721
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00257: early stopping
# 1/1 [==============================] - 0s 2ms/step - loss: 2.0822 - nll_gaussian: 0.8223
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00315: early stopping
# 1/1 [==============================] - 0s 2ms/step - loss: 1.9122 - nll_gaussian: 0.3655
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00058: early stopping
# 1/1 [==============================] - 0s 5ms/step - loss: 2.4408 - nll_gaussian: 1.5579
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00315: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 1.0218 - nll_gaussian: 0.0426
# Loss: 0.5432393014431
# Computation time: 293.9s
# Search iteration Nr 16/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00099: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 1.8475 - nll_gaussian: 0.7606
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00035: early stopping
# 1/1 [==============================] - 0s 2ms/step - loss: 3.3483 - nll_gaussian: 2.5174
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00113: early stopping
# 1/1 [==============================] - 0s 4ms/step - loss: 2.1042 - nll_gaussian: 0.8146
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00031: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 2.8740 - nll_gaussian: 2.0305
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00081: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 2.3772 - nll_gaussian: 1.2753
# Loss: 1.4796807646751404
# Computation time: 107.6s
# Search iteration Nr 17/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00107: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 4.7396 - nll_gaussian: -0.0231
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00100: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 6.6391 - nll_gaussian: 1.6700
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00102: early stopping
# 1/1 [==============================] - 0s 5ms/step - loss: 6.7571 - nll_gaussian: 0.6021
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00031: early stopping
# 1/1 [==============================] - 0s 9ms/step - loss: 4.5432 - nll_gaussian: 2.2181
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00062: early stopping
# 1/1 [==============================] - 0s 2ms/step - loss: 4.4857 - nll_gaussian: 0.3907
# Loss: 0.9715563513338565
# Computation time: 120.3s
# Search iteration Nr 18/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00119: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 0.5968 - nll_gaussian: -0.0350
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00185: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 0.9996 - nll_gaussian: 0.3901
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00146: early stopping
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6893 - nll_gaussian: 0.0082
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00081: early stopping
# 1/1 [==============================] - 0s 2ms/step - loss: 1.3627 - nll_gaussian: 0.7772
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00250: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 0.7354 - nll_gaussian: 0.0269
# Loss: 0.23346702195703983
# Computation time: 209.0s
# Search iteration Nr 19/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00031: early stopping
# 1/1 [==============================] - 0s 7ms/step - loss: 2.5083 - nll_gaussian: 0.8547
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00082: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 3.5504 - nll_gaussian: 1.1816
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00101: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 3.6070 - nll_gaussian: 1.1268
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00031: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 3.7306 - nll_gaussian: 2.0498
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00174: early stopping
# 1/1 [==============================] - 0s 3ms/step - loss: 3.6906 - nll_gaussian: 0.9861
# Loss: 1.2397990465164184
# Computation time: 132.1s
# Search iteration Nr 20/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00100: early stopping
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1206 - nll_gaussian: -0.6146
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00078: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 0.9132 - nll_gaussian: 0.2426
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00129: early stopping
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1131 - nll_gaussian: -0.6230
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00104: early stopping
# 1/1 [==============================] - 0s 2ms/step - loss: 0.5435 - nll_gaussian: -0.1160
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00097: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1948 - nll_gaussian: -0.5256
# Loss: -0.3273352816700935
# Computation time: 139.5s
# New best hyperparameters
# Mean loss: -0.3273352816700935
# {'layers': 1, 'neurons': 16, 'dropout': 0.1742999273909217, 'noise_in': 0.16377014688413172, 'noise_sigma': 0.1134923906332268, 'noise_mu': 0.10938594217787055, 'l1_hidden': 0.04710828272581036, 'l2_hidden': 0.0865468568987974, 'l1_mu': 0.06662415814133607, 'l2_mu': 0.08284488271391433, 'l1_sigma': 0.13279739515498568, 'l2_sigma': 0.05595644290869544, 'lr': 0.009881435166551064, 'batch_size': 100, 'epochs': 500, 'n_segments': 5, 'n_members_segment': 1, 'patience': 30, 'verbose': 0, 'pdf': 'normal', 'activation': 'relu', 'n_members': 5}
# Refit the model with best hyperparamters
# {'layers': 1, 'neurons': 16, 'dropout': 0.1742999273909217, 'noise_in': 0.16377014688413172, 'noise_sigma': 0.1134923906332268, 'noise_mu': 0.10938594217787055, 'l1_hidden': 0.04710828272581036, 'l2_hidden': 0.0865468568987974, 'l1_mu': 0.06662415814133607, 'l2_mu': 0.08284488271391433, 'l1_sigma': 0.13279739515498568, 'l2_sigma': 0.05595644290869544, 'lr': 0.009881435166551064, 'batch_size': 100, 'epochs': 500, 'n_segments': 5, 'n_members_segment': 1, 'patience': 30, 'verbose': 0, 'pdf': 'normal', 'activation': 'relu', 'n_members': 5}
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00099: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1557 - nll_gaussian: -0.5664
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00082: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 1.0097 - nll_gaussian: 0.3435
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00095: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0991 - nll_gaussian: -0.6844
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00105: early stopping
# 1/1 [==============================] - 0s 5ms/step - loss: 0.4782 - nll_gaussian: -0.2519
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00099: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1016 - nll_gaussian: -0.6358
# Loss: -0.3590160012245178
# Computation time: 140.0s
# best loss search: -0.3273352816700935
# loss refitting : -0.3590160012245178

# %% [markdown]
# ## Make predictions for the test data set
# Now we can use the trained models to make predicitons on the test data set to evaluate how good the model perfoms on a data set that it never saw before.

# %%
pred_mean, pred_std = model.predict(testX)

# %% [markdown]
# ## Plot the prediction
# Let's see how the predicion is looking like

# %%
import matplotlib.pyplot as plt
from ninolearn.plot.prediction import plot_prediction
import pandas as pd
from ninolearn.pathes import plotdir

from os.path import join


plt.subplots(figsize=(15,3.5))
plt.axhspan(-0.5,
            -6,
            facecolor='blue',
            alpha=0.1,zorder=0)

plt.axhspan(0.5,
            6,
            facecolor='red',
            alpha=0.1,zorder=0)

plt.xlim(testtimey[0], testtimey[-1])
plt.ylim(-3,3)

# plot the prediction
plot_prediction(testtimey, pred_mean, std=pred_std, facecolor='royalblue', line_color='navy')

# plot the observation
plt.plot(timey, y, "r", label = 'observation')
plt.legend()

plt.savefig(join(plotdir, f'predicVSobs_{version}_{lead_time}lead'))

plt.show()

# %% [markdown]
# ## Evaluate the model
#
# We can evaluate the model a bit more quantitatively using the loss function that was used to train the model, namely the negative-log-likelihood of the Gaussian and the correlation between the predicted mean and the observed ONI index.

# %%
from ninolearn.plot.evaluation import plot_correlation

loss = model.evaluate(testy, pred_mean, pred_std)
print(f"Loss (Negative-Log-Likelihood): {loss}")

# make a plot of the seasonal correaltion
# note: - pd.tseries.offsets.MonthBegin(1) appears to ensure that the correlations are plotted
# agains the correct season
plot_correlation(testy, pred_mean, testtimey - pd.tseries.offsets.MonthBegin(1), title="")

plt.savefig(join(plotdir, f'correlation_{version}_{lead_time}lead'))
# Out:
# Loss (Negative-Log-Likelihood): 0.8387699223280082
