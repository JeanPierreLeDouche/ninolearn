# %% [markdown]
# # Deep ensemble for ENSO-forecasting
#
# In this tutorial you learn how to use a neural network model called Deep Ensemble (DE) for the ENSO forecasting. This network architecture was initially developed [Lakshminarayanan et al. (2017)](https://papers.nips.cc/paper/7219-simple-and-scalable-predictive-uncertainty-estimation-using-deep-ensembles.pdf).
#
# DEs are feed foreword neural networks that predict the mean and the standard deviation of a Gaussian. Hence, their predicion comes with an uncertainty estimation which is a valuable feature for ENSO-forecasting.

# %% [markdown]
# ## Create a data pipe line
#
# At first, we define a data pipeline. This is in general quite useful to keep your code clean and also to reuse the pipeline for later purpose.
#
# The data pipeline generates returns:
#
# 1. The feature array
#
# 2. The label array
#
# 3. The time  array corresponding to the time of the label
#
# NOTE (again): Lead time is defined as the time that passed between the last observed and the first date of the target season. Hence, negative appear, e.g. if you compare the DJF season with the target season JFM, you have a lead time of -2 month (Last observed date: Feburary 28/29, First date of the target season January 1).

# %%
from ninolearn.IO.read_processed import data_reader
from ninolearn.IO.read_raw import ZC_simple_read
import numpy as np
import pandas as pd

oneyear= pd.Timedelta(365, 'D')

# %%
version = 'mu28v2'
leadtime = 24

# t_start is defined using a funky timedelta because the starting date of the network analysis data is the last month
# of its start year which is 1951-12 therefore the time must start in 1952 with some months added for values lost in 
# interpolation. TODO: fix this by backwards interpolating the first values of the year and finding out what is happening 
# with the nms
times = np.unique(ZC_simple_read(version)['time'])

t_start = times[0] + pd.Timedelta((2*365 + 90),'D')
t_end = times[-1] - pd.Timedelta(90,'D')

print(f'tstart = {t_start} and tend = {t_end}')
# Out:
# tstart = 1952-04-15 04:35:00 and tend = 1969-03-06 05:06:40

# %%
from ninolearn.IO.read_raw import ZC_raw, ZC_h, ZC_oni
from ninolearn.preprocess.prepare import prep_nms
from ninolearn.plot.ZC_dem_plots import nms_plots
## read raw ZC data and save to 1x1 grid file in processeddir
## also makes field of h and sst
ZC_raw(version)

## calculates monthly averaged (?) fields of thermocline height within region 
## of interest. cacluate ONI in region of interest. calculate network metrics 
## from sst (Henk's suggestion) or thermocline height (like Paul)
ZC_h(version) 
ZC_oni(version)
prep_nms(version, 0.99, t_start, t_end)

# make plots
nms_plots(version)
# Out:
# using dimensions ('lat', 'lon') from data variable temperature as the horizontal dimensions for this dataset.
# /home/ivo/anaconda3/envs/ninolearn/lib/python3.6/site-packages/xesmf/frontend.py:524: FutureWarning: ``output_sizes`` should be given in the ``dask_gufunc_kwargs`` parameter. It will be removed as direct parameter in a future version.
#   keep_attrs=keep_attrs
# /home/ivo/anaconda3/envs/ninolearn/lib/python3.6/site-packages/xesmf/smm.py:93: UserWarning: Input array is not C_CONTIGUOUS. Will affect performance.
#   warnings.warn("Input array is not C_CONTIGUOUS. "
# - Read sst climatetology
# using dimensions ('lat', 'lon') from data variable temperature as the horizontal dimensions for this dataset.
# /home/ivo/anaconda3/envs/ninolearn/lib/python3.6/site-packages/xesmf/frontend.py:524: FutureWarning: ``output_sizes`` should be given in the ``dask_gufunc_kwargs`` parameter. It will be removed as direct parameter in a future version.
#   keep_attrs=keep_attrs
# WARNING:Wrong input for computation of hamming distance.
# WARNING:Wrong input for computation of corrected hamming distance.
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!

# %%
reader = data_reader(startdate=(t_start + pd.Timedelta(365,'D')) , enddate=(t_end - pd.Timedelta(365, 'D')) , lon_min = 124, lon_max = 280,
                         lat_min = -19, lat_max = 19)

oni = reader.read_csv(('oni_ZC_' +version))
h = reader.read_csv(('h_mean_ZC_' + version))

network_ssh = reader.read_statistic('network_metrics', variable='sst', dataset=('ZC_25x25_' + version), processed="anom")
c2 = network_ssh['fraction_clusters_size_2']
H = network_ssh['corrected_hamming_distance']

# %%
if h.shape[0] + c2.shape[0] - H.shape[0] - oni.shape[0] == 0:
    print('All datasets are of equal length')
# Out:
# All datasets are of equal length

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler

from ninolearn.utils import include_time_lag
from ninolearn.IO.read_processed import data_reader


def pipeline(lead_time):
    """
    Data pipeline for the processing of the data before the Deep Ensemble
    is trained.

    :type lead_time: int
    :param lead_time: The lead time in month.

    :returns: The feature "X" (at observation time), the label "y" (at lead
    time), the target season "timey" (least month)
    """
#     reader = data_reader(startdate='1952-01', enddate='1992-12', lon_min = 124, lon_max = 280,
#                          lat_min = -19, lat_max = 19)
    reader = data_reader(startdate=(t_start + oneyear), enddate=(t_end - oneyear), lon_min = 124, lon_max = 280,
                         lat_min = -19, lat_max = 19)

    # indeces
    oni = reader.read_csv(('oni_ZC_' +version))
    h = reader.read_csv(('h_mean_ZC_' + version))
    #IOD unavailable in ZC87 model 
    
    # seasonal cycle
    sc = np.cos(np.arange(len(oni))/12*2*np.pi)

    # network metrics
    network_ssh = reader.read_statistic('network_metrics', variable='sst', dataset=('ZC_25x25_'+version), processed="anom")
    c2 = network_ssh['fraction_clusters_size_2']
    H = network_ssh['corrected_hamming_distance']

    # time lag
    time_lag = 12

    # shift such that lead time corresponds to the definition of lead time
    shift = 3

    # process features
    feature_unscaled = np.stack((oni, h,
                                 c2, H), axis=1)

    # scale each feature
    scalerX = StandardScaler()
    Xorg = scalerX.fit_transform(feature_unscaled)

    # set nans to 0.
    Xorg = np.nan_to_num(Xorg)

    # arange the feature array
    X = Xorg[:-lead_time-shift,:]
#     X = include_time_lag(X, max_lag=time_lag)
    X = include_time_lag(X, n_lags =12) 


    # arange label
    yorg = oni.values
    y = yorg[lead_time + time_lag + shift:]

    # get the time axis of the label
    timey = oni.index[lead_time + time_lag + shift:]

    return X, y, timey

# %% [markdown]
# ## Split the data set
#
# For the training and testing of machine learning models it is crucial to split the data set into:
#
# 1. __Train data set__ which is used to train the weights of the neural network
#
# 2. __Validation data set__ which is used to check for overfitting (e.g. when using early stopping) and to optimize the hyperparameters
#
# 3. __Test data set__ which is used to to evaluate the trained model.
#
# __NOTE:__ It is important to understand that hyperparamters must be tuned so that the result is best for the Validation data set and __not__ for the test data set. Otherwise you can not rule out the case that the specific hyperparameter setting just works good for the specific test data set but is not generally a good hyperparameter setting.
#
# In the following cell the train and the validation data set are still one data set, because this array will be later splitted into two arrays when th model is fitted.

# %%
import keras.backend as K
from ninolearn.learn.models.dem import DEM

# clear memory from previous sessions
K.clear_session()

# define the lead time
lead_time = leadtime

# get the features (X), the label (y) and 
# the time axis of the label (timey)
X, y, timey = pipeline(lead_time)

# split the data set into 
# test_indeces = (timey>='1987-01-01') & (timey<='1993-12-01')
test_indeces = (timey>=t_end - pd.Timedelta(5*365, 'D')) & (timey<=t_end)

train_val_indeces = np.invert(test_indeces)

train_val_X, train_val_y, train_val_timey = X[train_val_indeces,:], y[train_val_indeces], timey[train_val_indeces]
testX, testy, testtimey = X[test_indeces,:], y[test_indeces], timey[test_indeces]

# %% [markdown]
# ## Fit the model
#
# Now it is time to train the model! For this a random search is used for all keyword arguments that are passed in a *list* to the DEM.set_parameters() method.

# %%
# initiated an instance of the DEM (Deep Ensemble Model) class
model = DEM()

# Set parameters
model.set_hyperparameters(searchtype='linear', layers=1, neurons=16, dropout=[0.1, 0.5], noise_in=[0.1,0.5], noise_sigma=[0.1,0.5],
                     noise_mu=[0.1,0.5], l1_hidden=[0.0, 0.2], l2_hidden=[0., 0.2],
                     l1_mu=[0.0, 0.2], l2_mu=[0.0, 0.2], l1_sigma=[0.0, 0.2],
                     l2_sigma=[0.0, 0.2], lr=[0.0001,0.01], batch_size=100, epochs=500, n_segments=5,
                     n_members_segment=1, patience=30, verbose=0, pdf='normal', activation = 'relu')

# Use a random search to find the optimal hyperparameters

model.fit_RandomizedSearch(train_val_X, train_val_y, train_val_timey, n_iter=20)
# Out:
# Search iteration Nr 1/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00095: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 8.4433 - nll_gaussian: 0.1182
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00101: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 9.2704 - nll_gaussian: 0.3498
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00031: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 4.4437 - nll_gaussian: 1.2624
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00070: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 7.1917 - nll_gaussian: 0.6323
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00111: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 8.4993 - nll_gaussian: -0.2213
# Loss: 0.42828450798988343
# Computation time: 55.0s
# New best hyperparameters
# Mean loss: 0.42828450798988343
# {'layers': 1, 'neurons': 16, 'dropout': 0.37407923615231065, 'noise_in': 0.4824745934277349, 'noise_sigma': 0.39175818666398066, 'noise_mu': 0.2512777067567974, 'l1_hidden': 0.1626197930248032, 'l2_hidden': 0.089939887575746, 'l1_mu': 0.16783646950529482, 'l2_mu': 0.15824494569251238, 'l1_sigma': 0.19851301083212491, 'l2_sigma': 0.1386024096643833, 'lr': 0.008500132025543713, 'batch_size': 100, 'epochs': 500, 'n_segments': 5, 'n_members_segment': 1, 'patience': 30, 'verbose': 0, 'pdf': 'normal', 'activation': 'relu', 'n_members': 5}
# Search iteration Nr 2/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00097: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 7.9835 - nll_gaussian: 0.3301
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00100: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 10.3017 - nll_gaussian: 1.1140
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00125: early stopping
# 1/1 [==============================] - 0s 2ms/step - loss: 12.1719 - nll_gaussian: 0.1717
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00100: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 9.0206 - nll_gaussian: 0.0748
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00115: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 8.8537 - nll_gaussian: 0.3266
# Loss: 0.4034221023321152
# Computation time: 61.8s
# New best hyperparameters
# Mean loss: 0.4034221023321152
# {'layers': 1, 'neurons': 16, 'dropout': 0.2523131356646192, 'noise_in': 0.11497127895063729, 'noise_sigma': 0.4255230934168336, 'noise_mu': 0.2785919798057548, 'l1_hidden': 0.1748620460598988, 'l2_hidden': 0.12798888724428403, 'l1_mu': 0.11155398585503669, 'l2_mu': 0.0182608153091707, 'l1_sigma': 0.13693357532142447, 'l2_sigma': 0.1963867080203375, 'lr': 0.00858851021916489, 'batch_size': 100, 'epochs': 500, 'n_segments': 5, 'n_members_segment': 1, 'patience': 30, 'verbose': 0, 'pdf': 'normal', 'activation': 'relu', 'n_members': 5}
# Search iteration Nr 3/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00032: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 1.8799 - nll_gaussian: 0.5865
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00064: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 4.2478 - nll_gaussian: 1.9863
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00036: early stopping
# 1/1 [==============================] - 0s 2ms/step - loss: 2.4643 - nll_gaussian: 1.2128
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00031: early stopping
# 1/1 [==============================] - 0s 2ms/step - loss: 3.6660 - nll_gaussian: 2.4013
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00065: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 2.5950 - nll_gaussian: 0.7734
# Loss: 1.392046284675598
# Computation time: 29.8s
# Search iteration Nr 4/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00180: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 0.6211 - nll_gaussian: -0.0525
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00141: early stopping
# 1/1 [==============================] - 0s 2ms/step - loss: 1.3291 - nll_gaussian: 0.7723
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00205: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 0.9283 - nll_gaussian: 0.2828
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00139: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 1.3819 - nll_gaussian: 0.9230
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00160: early stopping
# 1/1 [==============================] - 0s 2ms/step - loss: 0.7774 - nll_gaussian: 0.0820
# Loss: 0.4015264339745045
# Computation time: 90.3s
# New best hyperparameters
# Mean loss: 0.4015264339745045
# {'layers': 1, 'neurons': 16, 'dropout': 0.4220086846783536, 'noise_in': 0.3898797794548101, 'noise_sigma': 0.17048934025665666, 'noise_mu': 0.43577324128801476, 'l1_hidden': 0.07238950164059887, 'l2_hidden': 0.040173385090002435, 'l1_mu': 0.14824459170454315, 'l2_mu': 0.09036426953246557, 'l1_sigma': 0.08009267498178925, 'l2_sigma': 0.19204472079201865, 'lr': 0.004946304942935298, 'batch_size': 100, 'epochs': 500, 'n_segments': 5, 'n_members_segment': 1, 'patience': 30, 'verbose': 0, 'pdf': 'normal', 'activation': 'relu', 'n_members': 5}
# Search iteration Nr 5/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00075: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 1.5095 - nll_gaussian: 0.1088
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00234: early stopping
# 1/1 [==============================] - 0s 930us/step - loss: 1.7026 - nll_gaussian: 0.4362
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00171: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 1.0228 - nll_gaussian: 0.1362
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00034: early stopping
# 1/1 [==============================] - 0s 2ms/step - loss: 3.2617 - nll_gaussian: 2.1162
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00162: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 1.8273 - nll_gaussian: 0.1825
# Loss: 0.5960021391510963
# Computation time: 76.5s
# Search iteration Nr 6/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00270: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 0.3804 - nll_gaussian: -0.3194
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00336: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 2.3234 - nll_gaussian: 1.1218
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00031: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 3.6109 - nll_gaussian: 1.2340
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00323: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 0.9231 - nll_gaussian: 0.3821
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00272: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 0.5969 - nll_gaussian: -0.0901
# Loss: 0.4656800240278244
# Computation time: 129.0s
# Search iteration Nr 7/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00095: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 0.3140 - nll_gaussian: -0.2765
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00177: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 0.6258 - nll_gaussian: 0.0249
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00159: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 0.4897 - nll_gaussian: -0.0750
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00142: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 0.5155 - nll_gaussian: -0.0222
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00126: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 0.3361 - nll_gaussian: -0.2348
# Loss: -0.11670752950012683
# Computation time: 77.3s
# New best hyperparameters
# Mean loss: -0.11670752950012683
# {'layers': 1, 'neurons': 16, 'dropout': 0.30988146679267004, 'noise_in': 0.37322476265885673, 'noise_sigma': 0.15916438908329053, 'noise_mu': 0.4483086636185989, 'l1_hidden': 0.06135313634932063, 'l2_hidden': 0.14299971038704415, 'l1_mu': 0.00417329115530678, 'l2_mu': 0.07843650423279065, 'l1_sigma': 0.00917901054139021, 'l2_sigma': 0.1084381701294735, 'lr': 0.009272135024329794, 'batch_size': 100, 'epochs': 500, 'n_segments': 5, 'n_members_segment': 1, 'patience': 30, 'verbose': 0, 'pdf': 'normal', 'activation': 'relu', 'n_members': 5}
# Search iteration Nr 8/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00168: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 5.8212 - nll_gaussian: -0.1262
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00142: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 5.0648 - nll_gaussian: 0.8965
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00077: early stopping
# 1/1 [==============================] - 0s 2ms/step - loss: 3.7434 - nll_gaussian: 0.7351
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00103: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 2.9465 - nll_gaussian: 0.6944
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00323: early stopping
# 1/1 [==============================] - 0s 13ms/step - loss: 4.7829 - nll_gaussian: 0.2016
# Loss: 0.4802774965763092
# Computation time: 64.6s
# Search iteration Nr 9/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00161: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 4.0305 - nll_gaussian: 0.2024
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00090: early stopping
# 1/1 [==============================] - 0s 946us/step - loss: 6.3793 - nll_gaussian: 2.4410
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00080: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 4.6660 - nll_gaussian: 1.0010
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00093: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 5.9070 - nll_gaussian: 2.1397
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00088: early stopping
# 1/1 [==============================] - 0s 3ms/step - loss: 4.5225 - nll_gaussian: 1.0263
# Loss: 1.3620899975299836
# Computation time: 41.0s
# Search iteration Nr 10/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00047: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 2.5441 - nll_gaussian: 0.5360
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00419: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 3.7687 - nll_gaussian: 2.3487
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00120: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 3.3142 - nll_gaussian: 1.2063
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00049: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 4.0850 - nll_gaussian: 2.1863
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00086: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 2.5956 - nll_gaussian: 1.1683
# Loss: 1.4891396284103393
# Computation time: 58.9s
# Search iteration Nr 11/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00045: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 2.0645 - nll_gaussian: 0.3797
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00031: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 4.0898 - nll_gaussian: 2.8206
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00180: early stopping
# 1/1 [==============================] - 0s 994us/step - loss: 4.3268 - nll_gaussian: 0.3595
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00036: early stopping
# 1/1 [==============================] - 0s 3ms/step - loss: 3.0560 - nll_gaussian: 1.6160
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00070: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 3.1469 - nll_gaussian: 0.7586
# Loss: 1.1868766725063324
# Computation time: 30.6s
# Search iteration Nr 12/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00048: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 5.1120 - nll_gaussian: 0.2817
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00049: early stopping
# 1/1 [==============================] - 0s 988us/step - loss: 5.5305 - nll_gaussian: 0.5960
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00031: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 4.2231 - nll_gaussian: 1.3073
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00077: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 8.1602 - nll_gaussian: 0.8574
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00042: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 4.4786 - nll_gaussian: 0.6845
# Loss: 0.74537593126297
# Computation time: 24.2s
# Search iteration Nr 13/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00031: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 3.2865 - nll_gaussian: 0.5740
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00078: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 5.9194 - nll_gaussian: 2.4242
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00066: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 4.1819 - nll_gaussian: 1.1161
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00105: early stopping
# 1/1 [==============================] - 0s 931us/step - loss: 5.3679 - nll_gaussian: 1.9415
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00032: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 3.9604 - nll_gaussian: 1.1732
# Loss: 1.4457900524139404
# Computation time: 27.8s
# Search iteration Nr 14/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00135: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 1.2391 - nll_gaussian: 0.1435
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00135: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 3.0577 - nll_gaussian: 0.2910
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00177: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 1.1605 - nll_gaussian: 0.2203
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00249: early stopping
# 1/1 [==============================] - 0s 3ms/step - loss: 0.9517 - nll_gaussian: 0.2378
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00060: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 1.7863 - nll_gaussian: 0.3154
# Loss: 0.24159368872642517
# Computation time: 56.8s
# Search iteration Nr 15/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00137: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 0.3642 - nll_gaussian: -0.3088
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00126: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 0.8228 - nll_gaussian: 0.1183
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00126: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 0.7496 - nll_gaussian: 0.0353
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00166: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 0.4844 - nll_gaussian: -0.1759
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00162: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 0.4238 - nll_gaussian: -0.1988
# Loss: -0.10600084587931632
# Computation time: 54.2s
# Search iteration Nr 16/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00138: early stopping
# 1/1 [==============================] - 0s 965us/step - loss: 1.6882 - nll_gaussian: 0.3408
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00112: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 2.5659 - nll_gaussian: 1.5028
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00141: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 2.1105 - nll_gaussian: 0.9012
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00104: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 1.6551 - nll_gaussian: 1.1677
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00432: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 1.0901 - nll_gaussian: 0.3854
# Loss: 0.8595784127712249
# Computation time: 67.3s
# Search iteration Nr 17/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00113: early stopping
# 1/1 [==============================] - 0s 965us/step - loss: 0.7155 - nll_gaussian: -0.0425
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00264: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 1.4176 - nll_gaussian: 0.9243
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00198: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 1.0815 - nll_gaussian: 0.4187
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00306: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 1.0793 - nll_gaussian: 0.6328
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00231: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 0.8093 - nll_gaussian: 0.1541
# Loss: 0.417499865591526
# Computation time: 79.2s
# Search iteration Nr 18/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00034: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 2.1331 - nll_gaussian: 0.5905
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00177: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 1.7070 - nll_gaussian: 1.4480
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00137: early stopping
# 1/1 [==============================] - 0s 2ms/step - loss: 1.2378 - nll_gaussian: 0.7845
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00156: early stopping
# 1/1 [==============================] - 0s 840us/step - loss: 1.4993 - nll_gaussian: 1.2794
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00127: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 1.0472 - nll_gaussian: 0.6794
# Loss: 0.9563339829444886
# Computation time: 48.5s
# Search iteration Nr 19/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00064: early stopping
# 1/1 [==============================] - 0s 986us/step - loss: 0.9707 - nll_gaussian: 0.4733
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00074: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 1.5815 - nll_gaussian: 1.3176
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00091: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 1.0333 - nll_gaussian: 0.7834
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00073: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 1.4711 - nll_gaussian: 1.1984
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00097: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 0.9563 - nll_gaussian: 0.6829
# Loss: 0.8910909712314605
# Computation time: 36.3s
# Search iteration Nr 20/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00058: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 0.6133 - nll_gaussian: -0.5241
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00052: early stopping
# 1/1 [==============================] - 0s 2ms/step - loss: 1.7557 - nll_gaussian: 0.9367
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00077: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 2.1310 - nll_gaussian: 0.5871
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00083: early stopping
# 1/1 [==============================] - 0s 994us/step - loss: 2.2542 - nll_gaussian: 1.0597
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00050: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 1.6920 - nll_gaussian: 0.8336
# Loss: 0.5786070704460144
# Computation time: 29.4s
# Refit the model with best hyperparamters
# {'layers': 1, 'neurons': 16, 'dropout': 0.30988146679267004, 'noise_in': 0.37322476265885673, 'noise_sigma': 0.15916438908329053, 'noise_mu': 0.4483086636185989, 'l1_hidden': 0.06135313634932063, 'l2_hidden': 0.14299971038704415, 'l1_mu': 0.00417329115530678, 'l2_mu': 0.07843650423279065, 'l1_sigma': 0.00917901054139021, 'l2_sigma': 0.1084381701294735, 'lr': 0.009272135024329794, 'batch_size': 100, 'epochs': 500, 'n_segments': 5, 'n_members_segment': 1, 'patience': 30, 'verbose': 0, 'pdf': 'normal', 'activation': 'relu', 'n_members': 5}
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00109: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 0.3443 - nll_gaussian: -0.2564
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00123: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 0.6280 - nll_gaussian: 0.1215
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00136: early stopping
# 1/1 [==============================] - 0s 2ms/step - loss: 0.4955 - nll_gaussian: -0.0935
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00180: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 0.4685 - nll_gaussian: -0.0481
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00101: early stopping
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2906 - nll_gaussian: -0.3062
# Loss: -0.11654359698295594
# Computation time: 63.4s
# best loss search: -0.11670752950012683
# loss refitting : -0.11654359698295594

# %% [markdown]
# ## Make predictions for the test data set
# Now we can use the trained models to make predicitons on the test data set to evaluate how good the model perfoms on a data set that it never saw before.

# %%
pred_mean, pred_std = model.predict(testX)

# %% [markdown]
# ## Plot the prediction
# Let's see how the predicion is looking like

# %%
import matplotlib.pyplot as plt
from ninolearn.plot.prediction import plot_prediction
import pandas as pd
from ninolearn.pathes import plotdir

from os.path import join


plt.subplots(figsize=(15,3.5))
plt.axhspan(-0.5,
            -6,
            facecolor='blue',
            alpha=0.1,zorder=0)

plt.axhspan(0.5,
            6,
            facecolor='red',
            alpha=0.1,zorder=0)

plt.xlim(testtimey[0], testtimey[-1])
plt.ylim(-3,3)

# plot the prediction
plot_prediction(testtimey, pred_mean, std=pred_std, facecolor='royalblue', line_color='navy')

# plot the observation
plt.plot(timey, y, "r", label = 'observation')
plt.legend()

plt.savefig(join(plotdir, f'predicVSobs_{version}_{lead_time}lead'))

plt.show()

# %% [markdown]
# ## Evaluate the model
#
# We can evaluate the model a bit more quantitatively using the loss function that was used to train the model, namely the negative-log-likelihood of the Gaussian and the correlation between the predicted mean and the observed ONI index.

# %%
from ninolearn.plot.evaluation import plot_correlation

loss = model.evaluate(testy, pred_mean, pred_std)
print(f"Loss (Negative-Log-Likelihood): {loss}")

# make a plot of the seasonal correaltion
# note: - pd.tseries.offsets.MonthBegin(1) appears to ensure that the correlations are plotted
# agains the correct season
plot_correlation(testy, pred_mean, testtimey - pd.tseries.offsets.MonthBegin(1), title="")

plt.savefig(join(plotdir, f'correlation_{version}_{lead_time}lead'))
# Out:
# Loss (Negative-Log-Likelihood): 0.12831224419474876
