# %% [markdown]
# # Deep ensemble for ENSO-forecasting
#
# In this tutorial you learn how to use a neural network model called Deep Ensemble (DE) for the ENSO forecasting. This network architecture was initially developed [Lakshminarayanan et al. (2017)](https://papers.nips.cc/paper/7219-simple-and-scalable-predictive-uncertainty-estimation-using-deep-ensembles.pdf).
#
# DEs are feed foreword neural networks that predict the mean and the standard deviation of a Gaussian. Hence, their predicion comes with an uncertainty estimation which is a valuable feature for ENSO-forecasting.

# %% [markdown]
# ## Create a data pipe line
#
# At first, we define a data pipeline. This is in general quite useful to keep your code clean and also to reuse the pipeline for later purpose.
#
# The data pipeline generates returns:
#
# 1. The feature array
#
# 2. The label array
#
# 3. The time  array corresponding to the time of the label
#
# NOTE (again): Lead time is defined as the time that passed between the last observed and the first date of the target season. Hence, negative appear, e.g. if you compare the DJF season with the target season JFM, you have a lead time of -2 month (Last observed date: Feburary 28/29, First date of the target season January 1).

# %%
from ninolearn.IO.read_processed import data_reader
from ninolearn.IO.read_raw import ZC_simple_read
import numpy as np
import pandas as pd

oneyear= pd.Timedelta(365, 'D')

# %%
version = 'de12hires'
leadtime = 12

# t_start is defined using a funky timedelta because the starting date of the network analysis data is the last month
# of its start year which is 1951-12 therefore the time must start in 1952 with some months added for values lost in 
# interpolation. TODO: fix this by backwards interpolating the first values of the year and finding out what is happening 
# with the nms
times = np.unique(ZC_simple_read(version)['time'])

t_start = times[0] + pd.Timedelta((2*365 + 90),'D')
t_end = times[-1] - pd.Timedelta(90,'D')

print(f'tstart = {t_start} and tend = {t_end}')
# Out:
# tstart = 1952-04-07 14:17:30 and tend = 1994-08-26 03:33:20

# %%
from ninolearn.IO.read_raw import ZC_raw, ZC_h, ZC_oni
from ninolearn.preprocess.prepare import prep_nms
from ninolearn.plot.ZC_dem_plots import nms_plots
## read raw ZC data and save to 1x1 grid file in processeddir
## also makes field of h and sst
ZC_raw(version)

## calculates monthly averaged (?) fields of thermocline height within region 
## of interest. cacluate ONI in region of interest. calculate network metrics 
## from sst (Henk's suggestion) or thermocline height (like Paul)
ZC_h(version) 
ZC_oni(version)
prep_nms(version, 0.99, t_start, t_end)

# make plots
nms_plots(version)
# Out:
# using dimensions ('lat', 'lon') from data variable temperature as the horizontal dimensions for this dataset.
# /home/ivo/anaconda3/envs/ninolearn/lib/python3.6/site-packages/xesmf/frontend.py:524: FutureWarning: ``output_sizes`` should be given in the ``dask_gufunc_kwargs`` parameter. It will be removed as direct parameter in a future version.
#   keep_attrs=keep_attrs
# /home/ivo/anaconda3/envs/ninolearn/lib/python3.6/site-packages/xesmf/smm.py:93: UserWarning: Input array is not C_CONTIGUOUS. Will affect performance.
#   warnings.warn("Input array is not C_CONTIGUOUS. "
# - Read sst climatetology
# using dimensions ('lat', 'lon') from data variable temperature as the horizontal dimensions for this dataset.
# /home/ivo/anaconda3/envs/ninolearn/lib/python3.6/site-packages/xesmf/frontend.py:524: FutureWarning: ``output_sizes`` should be given in the ``dask_gufunc_kwargs`` parameter. It will be removed as direct parameter in a future version.
#   keep_attrs=keep_attrs
# WARNING:Wrong input for computation of hamming distance.
# WARNING:Wrong input for computation of corrected hamming distance.
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!

# %%
reader = data_reader(startdate=(t_start + pd.Timedelta(365,'D')) , enddate=(t_end - pd.Timedelta(2 *365, 'D')) , lon_min = 124, lon_max = 280,
                         lat_min = -19, lat_max = 19)

oni = reader.read_csv(('oni_ZC_' +version))
h = reader.read_csv(('h_mean_ZC_' + version))

network_ssh = reader.read_statistic('network_metrics', variable='sst', dataset=('ZC_25x25_' + version), processed="anom")
c2 = network_ssh['fraction_clusters_size_2']
H = network_ssh['corrected_hamming_distance']

# %%
if h.shape[0] + c2.shape[0] - H.shape[0] - oni.shape[0] == 0:
    print('All datasets are of equal length')
# Out:
# All datasets are of equal length

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler

from ninolearn.utils import include_time_lag
from ninolearn.IO.read_processed import data_reader


def pipeline(lead_time):
    """
    Data pipeline for the processing of the data before the Deep Ensemble
    is trained.

    :type lead_time: int
    :param lead_time: The lead time in month.

    :returns: The feature "X" (at observation time), the label "y" (at lead
    time), the target season "timey" (least month)
    """
#     reader = data_reader(startdate='1952-01', enddate='1992-12', lon_min = 124, lon_max = 280,
#                          lat_min = -19, lat_max = 19)
    reader = data_reader(startdate=(t_start + oneyear), enddate=(t_end - oneyear), lon_min = 124, lon_max = 280,
                         lat_min = -19, lat_max = 19)

    # indeces
    oni = reader.read_csv(('oni_ZC_' +version))
    h = reader.read_csv(('h_mean_ZC_' + version))
    #IOD unavailable in ZC87 model 
    
    # seasonal cycle
    sc = np.cos(np.arange(len(oni))/12*2*np.pi)

    # network metrics
    network_ssh = reader.read_statistic('network_metrics', variable='sst', dataset=('ZC_25x25_'+version), processed="anom")
    c2 = network_ssh['fraction_clusters_size_2']
    H = network_ssh['corrected_hamming_distance']

    # time lag
    time_lag = 12

    # shift such that lead time corresponds to the definition of lead time
    shift = 3

    # process features
    feature_unscaled = np.stack((oni, h,
                                 c2, H), axis=1)

    # scale each feature
    scalerX = StandardScaler()
    Xorg = scalerX.fit_transform(feature_unscaled)

    # set nans to 0.
    Xorg = np.nan_to_num(Xorg)

    # arange the feature array
    X = Xorg[:-lead_time-shift,:]
#     X = include_time_lag(X, max_lag=time_lag)
    X = include_time_lag(X, n_lags =12) 


    # arange label
    yorg = oni.values
    y = yorg[lead_time + time_lag + shift:]

    # get the time axis of the label
    timey = oni.index[lead_time + time_lag + shift:]

    return X, y, timey

# %% [markdown]
# ## Split the data set
#
# For the training and testing of machine learning models it is crucial to split the data set into:
#
# 1. __Train data set__ which is used to train the weights of the neural network
#
# 2. __Validation data set__ which is used to check for overfitting (e.g. when using early stopping) and to optimize the hyperparameters
#
# 3. __Test data set__ which is used to to evaluate the trained model.
#
# __NOTE:__ It is important to understand that hyperparamters must be tuned so that the result is best for the Validation data set and __not__ for the test data set. Otherwise you can not rule out the case that the specific hyperparameter setting just works good for the specific test data set but is not generally a good hyperparameter setting.
#
# In the following cell the train and the validation data set are still one data set, because this array will be later splitted into two arrays when th model is fitted.

# %%
import keras.backend as K
from ninolearn.learn.models.dem import DEM

# clear memory from previous sessions
K.clear_session()

# define the lead time
lead_time = leadtime

# get the features (X), the label (y) and 
# the time axis of the label (timey)
X, y, timey = pipeline(lead_time)

# split the data set into 
# test_indeces = (timey>='1987-01-01') & (timey<='1993-12-01')
test_indeces = (timey>=t_end - pd.Timedelta(5*365, 'D')) & (timey<=t_end)

train_val_indeces = np.invert(test_indeces)

train_val_X, train_val_y, train_val_timey = X[train_val_indeces,:], y[train_val_indeces], timey[train_val_indeces]
testX, testy, testtimey = X[test_indeces,:], y[test_indeces], timey[test_indeces]

# %% [markdown]
# ## Fit the model
#
# Now it is time to train the model! For this a random search is used for all keyword arguments that are passed in a *list* to the DEM.set_parameters() method.

# %%
# initiated an instance of the DEM (Deep Ensemble Model) class
model = DEM()

# Set parameters
model.set_hyperparameters(searchtype='linear', layers=1, neurons=16, dropout=[0.1, 0.5], noise_in=[0.1,0.5], noise_sigma=[0.1,0.5],
                     noise_mu=[0.1,0.5], l1_hidden=[0.0, 0.2], l2_hidden=[0., 0.2],
                     l1_mu=[0.0, 0.2], l2_mu=[0.0, 0.2], l1_sigma=[0.0, 0.2],
                     l2_sigma=[0.0, 0.2], lr=[0.0001,0.01], batch_size=100, epochs=500, n_segments=5,
                     n_members_segment=1, patience=30, verbose=0, pdf='normal', activation = 'relu')

# Use a random search to find the optimal hyperparameters

model.fit_RandomizedSearch(train_val_X, train_val_y, train_val_timey, n_iter=20)
# Out:
# Search iteration Nr 1/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00242: early stopping
# 3/3 [==============================] - 0s 2ms/step - loss: 6.1950 - nll_gaussian: 0.5962
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00213: early stopping
# 3/3 [==============================] - 0s 3ms/step - loss: 8.5944 - nll_gaussian: 0.8164
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00043: early stopping
# 3/3 [==============================] - 0s 4ms/step - loss: 5.1501 - nll_gaussian: 2.0009
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00074: early stopping
# 3/3 [==============================] - 0s 6ms/step - loss: 5.3847 - nll_gaussian: 0.3890
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00072: early stopping
# 3/3 [==============================] - 0s 2ms/step - loss: 7.4837 - nll_gaussian: 1.0680
# Loss: 0.9740859270095825
# Computation time: 139.2s
# New best hyperparameters
# Mean loss: 0.9740859270095825
# {'layers': 1, 'neurons': 16, 'dropout': 0.18930270940107247, 'noise_in': 0.1716878980962082, 'noise_sigma': 0.3521085237182686, 'noise_mu': 0.10904710508486226, 'l1_hidden': 0.10581697888077907, 'l2_hidden': 0.1318964190372794, 'l1_mu': 0.17759260653112421, 'l2_mu': 0.07936402681904123, 'l1_sigma': 0.0617553091924774, 'l2_sigma': 0.005895889769902052, 'lr': 0.005529322379188088, 'batch_size': 100, 'epochs': 500, 'n_segments': 5, 'n_members_segment': 1, 'patience': 30, 'verbose': 0, 'pdf': 'normal', 'activation': 'relu', 'n_members': 5}
# Search iteration Nr 2/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00072: early stopping
# 3/3 [==============================] - 0s 3ms/step - loss: 7.1151 - nll_gaussian: 0.5789
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00051: early stopping
# 3/3 [==============================] - 0s 2ms/step - loss: 10.4333 - nll_gaussian: 2.3748
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00040: early stopping
# 3/3 [==============================] - 0s 2ms/step - loss: 7.1975 - nll_gaussian: 0.6922
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00069: early stopping
# 3/3 [==============================] - 0s 4ms/step - loss: 9.1976 - nll_gaussian: 0.5957
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00069: early stopping
# 3/3 [==============================] - 0s 2ms/step - loss: 10.1879 - nll_gaussian: 0.5045
# Loss: 0.9492461562156678
# Computation time: 71.7s
# New best hyperparameters
# Mean loss: 0.9492461562156678
# {'layers': 1, 'neurons': 16, 'dropout': 0.401670866398088, 'noise_in': 0.3453680136887147, 'noise_sigma': 0.40323526600565707, 'noise_mu': 0.41494830491602364, 'l1_hidden': 0.14170836127942602, 'l2_hidden': 0.07385393004135025, 'l1_mu': 0.18506979705889723, 'l2_mu': 0.14506606688529464, 'l1_sigma': 0.12263509738010564, 'l2_sigma': 0.12498440501423605, 'lr': 0.008310878131091558, 'batch_size': 100, 'epochs': 500, 'n_segments': 5, 'n_members_segment': 1, 'patience': 30, 'verbose': 0, 'pdf': 'normal', 'activation': 'relu', 'n_members': 5}
# Search iteration Nr 3/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00035: early stopping
# 3/3 [==============================] - 0s 5ms/step - loss: 5.5954 - nll_gaussian: 2.0715
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00092: early stopping
# 3/3 [==============================] - 0s 5ms/step - loss: 6.4645 - nll_gaussian: 1.7635
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00182: early stopping
# 3/3 [==============================] - 0s 3ms/step - loss: 9.5477 - nll_gaussian: 2.4600
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00118: early stopping
# 3/3 [==============================] - 0s 11ms/step - loss: 7.0143 - nll_gaussian: 1.2179
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00068: early stopping
# 3/3 [==============================] - 0s 2ms/step - loss: 5.8063 - nll_gaussian: 1.7003
# Loss: 1.8426347017288207
# Computation time: 102.9s
# Search iteration Nr 4/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00098: early stopping
# 3/3 [==============================] - 0s 2ms/step - loss: 6.0204 - nll_gaussian: 2.1740
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00042: early stopping
# 3/3 [==============================] - 0s 6ms/step - loss: 8.0524 - nll_gaussian: 4.2586
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00476: early stopping
# 3/3 [==============================] - 0s 2ms/step - loss: 6.9633 - nll_gaussian: 2.8897
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00077: early stopping
# 3/3 [==============================] - 0s 3ms/step - loss: 5.8826 - nll_gaussian: 1.8890
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00093: early stopping
# 3/3 [==============================] - 0s 3ms/step - loss: 6.1566 - nll_gaussian: 2.3590
# Loss: 2.714057946205139
# Computation time: 159.5s
# Search iteration Nr 5/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00101: early stopping
# 3/3 [==============================] - 0s 7ms/step - loss: 1.3552 - nll_gaussian: 0.1398
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00114: early stopping
# 3/3 [==============================] - 0s 1ms/step - loss: 1.4090 - nll_gaussian: 0.2873
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00124: early stopping
# 3/3 [==============================] - 0s 2ms/step - loss: 1.2203 - nll_gaussian: 0.3284
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00102: early stopping
# 3/3 [==============================] - 0s 3ms/step - loss: 1.9315 - nll_gaussian: 0.2155
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00102: early stopping
# 3/3 [==============================] - 0s 2ms/step - loss: 1.1948 - nll_gaussian: 0.1810
# Loss: 0.23037563860416413
# Computation time: 123.0s
# New best hyperparameters
# Mean loss: 0.23037563860416413
# {'layers': 1, 'neurons': 16, 'dropout': 0.2287644042624576, 'noise_in': 0.27099338154270947, 'noise_sigma': 0.21531983748479255, 'noise_mu': 0.1055986797209759, 'l1_hidden': 0.034916496791224994, 'l2_hidden': 0.15967899718308187, 'l1_mu': 0.12566225821725036, 'l2_mu': 0.0567411509586911, 'l1_sigma': 0.19612102001980608, 'l2_sigma': 0.1385688840181072, 'lr': 0.002650207177247585, 'batch_size': 100, 'epochs': 500, 'n_segments': 5, 'n_members_segment': 1, 'patience': 30, 'verbose': 0, 'pdf': 'normal', 'activation': 'relu', 'n_members': 5}
# Search iteration Nr 6/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00251: early stopping
# 3/3 [==============================] - 0s 6ms/step - loss: 6.3182 - nll_gaussian: 1.0704
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00140: early stopping
# 3/3 [==============================] - 0s 7ms/step - loss: 4.0242 - nll_gaussian: 0.7778
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00081: early stopping
# 3/3 [==============================] - 0s 2ms/step - loss: 4.2037 - nll_gaussian: 0.9238
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00041: early stopping
# 3/3 [==============================] - 0s 1ms/step - loss: 5.2663 - nll_gaussian: 1.7022
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00087: early stopping
# 3/3 [==============================] - 0s 3ms/step - loss: 5.5928 - nll_gaussian: 0.9382
# Loss: 1.0824856162071228
# Computation time: 120.7s
# Search iteration Nr 7/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00033: early stopping
# 3/3 [==============================] - 0s 4ms/step - loss: 5.1256 - nll_gaussian: 1.8512
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00052: early stopping
# 3/3 [==============================] - 0s 5ms/step - loss: 7.9672 - nll_gaussian: 0.7449
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00107: early stopping
# 3/3 [==============================] - 0s 2ms/step - loss: 11.8682 - nll_gaussian: 1.1948
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00048: early stopping
# 3/3 [==============================] - 0s 3ms/step - loss: 6.5695 - nll_gaussian: 0.5948
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00053: early stopping
# 3/3 [==============================] - 0s 2ms/step - loss: 10.4637 - nll_gaussian: 1.3215
# Loss: 1.1414543867111206
# Computation time: 69.1s
# Search iteration Nr 8/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00151: early stopping
# 3/3 [==============================] - 0s 9ms/step - loss: 5.7313 - nll_gaussian: 1.0512
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00167: early stopping
# 3/3 [==============================] - 0s 2ms/step - loss: 6.8889 - nll_gaussian: 2.2143
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00035: early stopping
# 3/3 [==============================] - 0s 3ms/step - loss: 6.0912 - nll_gaussian: 3.4612
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00048: early stopping
# 3/3 [==============================] - 0s 6ms/step - loss: 4.9882 - nll_gaussian: 1.8254
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00267: early stopping
# 3/3 [==============================] - 0s 6ms/step - loss: 6.8673 - nll_gaussian: 0.5797
# Loss: 1.8263367772102357
# Computation time: 136.7s
# Search iteration Nr 9/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00031: early stopping
# 3/3 [==============================] - 0s 3ms/step - loss: 5.9485 - nll_gaussian: 2.5044
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00141: early stopping
# 3/3 [==============================] - 0s 4ms/step - loss: 7.4190 - nll_gaussian: 3.8732
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00074: early stopping
# 3/3 [==============================] - 0s 10ms/step - loss: 6.7402 - nll_gaussian: 3.6340
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00103: early stopping
# 3/3 [==============================] - 0s 2ms/step - loss: 5.1682 - nll_gaussian: 1.8722
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00278: early stopping
# 3/3 [==============================] - 0s 3ms/step - loss: 5.7356 - nll_gaussian: 1.8584
# Loss: 2.748442554473877
# Computation time: 125.3s
# Search iteration Nr 10/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00094: early stopping
# 3/3 [==============================] - 0s 2ms/step - loss: 2.6852 - nll_gaussian: 1.4222
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00226: early stopping
# 3/3 [==============================] - 0s 1ms/step - loss: 1.2243 - nll_gaussian: 0.4844
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00235: early stopping
# 3/3 [==============================] - 0s 2ms/step - loss: 1.5418 - nll_gaussian: 0.5402
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00167: early stopping
# 3/3 [==============================] - 0s 2ms/step - loss: 1.5068 - nll_gaussian: 0.2644
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00129: early stopping
# 3/3 [==============================] - 0s 3ms/step - loss: 1.5219 - nll_gaussian: 0.3267
# Loss: 0.6075794160366058
# Computation time: 162.5s
# Search iteration Nr 11/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00092: early stopping
# 3/3 [==============================] - 0s 6ms/step - loss: 3.0465 - nll_gaussian: 0.1140
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00139: early stopping
# 3/3 [==============================] - 0s 3ms/step - loss: 1.4631 - nll_gaussian: 0.4069
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00075: early stopping
# 3/3 [==============================] - 0s 2ms/step - loss: 3.7903 - nll_gaussian: 0.4992
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00134: early stopping
# 3/3 [==============================] - 0s 4ms/step - loss: 0.9608 - nll_gaussian: 0.1977
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00071: early stopping
# 3/3 [==============================] - 0s 6ms/step - loss: 2.5212 - nll_gaussian: 0.3032
# Loss: 0.3042022094130516
# Computation time: 108.5s
# Search iteration Nr 12/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00044: early stopping
# 3/3 [==============================] - 0s 1ms/step - loss: 1.8236 - nll_gaussian: 0.5920
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00054: early stopping
# 3/3 [==============================] - 0s 5ms/step - loss: 1.9220 - nll_gaussian: 0.9722
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00055: early stopping
# 3/3 [==============================] - 0s 6ms/step - loss: 1.9859 - nll_gaussian: 0.8316
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00050: early stopping
# 3/3 [==============================] - 0s 3ms/step - loss: 1.9723 - nll_gaussian: 0.4291
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00047: early stopping
# 3/3 [==============================] - 0s 1ms/step - loss: 2.0595 - nll_gaussian: 0.5387
# Loss: 0.6727347433567047
# Computation time: 63.7s
# Search iteration Nr 13/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00040: early stopping
# 3/3 [==============================] - 0s 8ms/step - loss: 5.2745 - nll_gaussian: 0.5336
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00061: early stopping
# 3/3 [==============================] - 0s 2ms/step - loss: 9.7836 - nll_gaussian: 2.6473
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00047: early stopping
# 3/3 [==============================] - 0s 3ms/step - loss: 5.8684 - nll_gaussian: 1.0068
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00092: early stopping
# 3/3 [==============================] - 0s 2ms/step - loss: 7.1070 - nll_gaussian: 0.5092
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00078: early stopping
# 3/3 [==============================] - 0s 3ms/step - loss: 9.8491 - nll_gaussian: 1.8464
# Loss: 1.3086795687675477
# Computation time: 74.9s
# Search iteration Nr 14/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00147: early stopping
# 3/3 [==============================] - 0s 8ms/step - loss: 10.3325 - nll_gaussian: 0.6007
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00046: early stopping
# 3/3 [==============================] - 0s 4ms/step - loss: 9.7316 - nll_gaussian: 2.1438
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00128: early stopping
# 3/3 [==============================] - 0s 2ms/step - loss: 15.0649 - nll_gaussian: 1.2515
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00054: early stopping
# 3/3 [==============================] - 0s 2ms/step - loss: 8.3822 - nll_gaussian: 0.7277
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00093: early stopping
# 3/3 [==============================] - 0s 3ms/step - loss: 9.2117 - nll_gaussian: 0.8847
# Loss: 1.1217007398605348
# Computation time: 106.1s
# Search iteration Nr 15/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00070: early stopping
# 3/3 [==============================] - 0s 4ms/step - loss: 4.0671 - nll_gaussian: 1.3742
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00143: early stopping
# 3/3 [==============================] - 0s 4ms/step - loss: 3.5895 - nll_gaussian: 0.5722
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00126: early stopping
# 3/3 [==============================] - 0s 4ms/step - loss: 3.5283 - nll_gaussian: 0.7214
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00153: early stopping
# 3/3 [==============================] - 0s 2ms/step - loss: 3.4938 - nll_gaussian: 1.1226
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00125: early stopping
# 3/3 [==============================] - 0s 4ms/step - loss: 4.4505 - nll_gaussian: 0.7638
# Loss: 0.9108371734619141
# Computation time: 135.6s
# Search iteration Nr 16/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00066: early stopping
# 3/3 [==============================] - 0s 3ms/step - loss: 4.7147 - nll_gaussian: 1.8996
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00131: early stopping
# 3/3 [==============================] - 0s 2ms/step - loss: 5.5929 - nll_gaussian: 2.2395
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00145: early stopping
# 3/3 [==============================] - 0s 2ms/step - loss: 5.2072 - nll_gaussian: 1.6824
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00060: early stopping
# 3/3 [==============================] - 0s 3ms/step - loss: 4.5761 - nll_gaussian: 1.7546
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00049: early stopping
# 3/3 [==============================] - 0s 4ms/step - loss: 4.8342 - nll_gaussian: 2.1842
# Loss: 1.9520695447921752
# Computation time: 105.1s
# Search iteration Nr 17/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00056: early stopping
# 3/3 [==============================] - 0s 2ms/step - loss: 0.9777 - nll_gaussian: 0.1454
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00058: early stopping
# 3/3 [==============================] - 0s 4ms/step - loss: 1.2677 - nll_gaussian: 0.3504
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00069: early stopping
# 3/3 [==============================] - 0s 2ms/step - loss: 1.1110 - nll_gaussian: 0.3482
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00055: early stopping
# 3/3 [==============================] - 0s 6ms/step - loss: 0.8726 - nll_gaussian: 0.1197
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00107: early stopping
# 3/3 [==============================] - 0s 4ms/step - loss: 1.5885 - nll_gaussian: 0.4354
# Loss: 0.27983772903680804
# Computation time: 86.3s
# Search iteration Nr 18/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00067: early stopping
# 3/3 [==============================] - 0s 2ms/step - loss: 7.0771 - nll_gaussian: 0.6230
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00031: early stopping
# 3/3 [==============================] - 0s 13ms/step - loss: 7.5507 - nll_gaussian: 4.4926
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00087: early stopping
# 3/3 [==============================] - 0s 3ms/step - loss: 10.1061 - nll_gaussian: 0.8281
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00050: early stopping
# 3/3 [==============================] - 0s 5ms/step - loss: 7.9513 - nll_gaussian: 0.7078
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00038: early stopping
# 3/3 [==============================] - 0s 3ms/step - loss: 7.2907 - nll_gaussian: 1.7154
# Loss: 1.6733602285385132
# Computation time: 63.0s
# Search iteration Nr 19/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00085: early stopping
# 3/3 [==============================] - 0s 2ms/step - loss: 1.3467 - nll_gaussian: 0.4330
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00096: early stopping
# 3/3 [==============================] - 0s 3ms/step - loss: 2.0872 - nll_gaussian: 0.8242
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00062: early stopping
# 3/3 [==============================] - 0s 2ms/step - loss: 1.5705 - nll_gaussian: 0.6412
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00127: early stopping
# 3/3 [==============================] - 0s 2ms/step - loss: 1.7228 - nll_gaussian: 0.3867
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00119: early stopping
# 3/3 [==============================] - 0s 4ms/step - loss: 1.8128 - nll_gaussian: 0.5386
# Loss: 0.5647392809391022
# Computation time: 102.5s
# Search iteration Nr 20/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00141: early stopping
# 3/3 [==============================] - 0s 5ms/step - loss: 0.4206 - nll_gaussian: 0.0033
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00088: early stopping
# 3/3 [==============================] - 0s 8ms/step - loss: 0.6986 - nll_gaussian: 0.1784
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00098: early stopping
# 3/3 [==============================] - 0s 3ms/step - loss: 0.5988 - nll_gaussian: 0.2151
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00080: early stopping
# 3/3 [==============================] - 0s 3ms/step - loss: 0.5035 - nll_gaussian: 0.0270
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00095: early stopping
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6207 - nll_gaussian: 0.1277
# Loss: 0.11031192080117762
# Computation time: 81.2s
# New best hyperparameters
# Mean loss: 0.11031192080117762
# {'layers': 1, 'neurons': 16, 'dropout': 0.3395760388808079, 'noise_in': 0.1301330205279063, 'noise_sigma': 0.15455446908695372, 'noise_mu': 0.36765536170788093, 'l1_hidden': 0.006475631796129222, 'l2_hidden': 0.18213375015966582, 'l1_mu': 0.04474625648473432, 'l2_mu': 0.11993216765068743, 'l1_sigma': 0.03153832675351818, 'l2_sigma': 0.19745404428414845, 'lr': 0.003669541949678089, 'batch_size': 100, 'epochs': 500, 'n_segments': 5, 'n_members_segment': 1, 'patience': 30, 'verbose': 0, 'pdf': 'normal', 'activation': 'relu', 'n_members': 5}
# Refit the model with best hyperparamters
# {'layers': 1, 'neurons': 16, 'dropout': 0.3395760388808079, 'noise_in': 0.1301330205279063, 'noise_sigma': 0.15455446908695372, 'noise_mu': 0.36765536170788093, 'l1_hidden': 0.006475631796129222, 'l2_hidden': 0.18213375015966582, 'l1_mu': 0.04474625648473432, 'l2_mu': 0.11993216765068743, 'l1_sigma': 0.03153832675351818, 'l2_sigma': 0.19745404428414845, 'lr': 0.003669541949678089, 'batch_size': 100, 'epochs': 500, 'n_segments': 5, 'n_members_segment': 1, 'patience': 30, 'verbose': 0, 'pdf': 'normal', 'activation': 'relu', 'n_members': 5}
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00132: early stopping
# 3/3 [==============================] - 0s 3ms/step - loss: 0.4200 - nll_gaussian: 0.0035
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00120: early stopping
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6241 - nll_gaussian: 0.1288
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00101: early stopping
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6273 - nll_gaussian: 0.1986
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00110: early stopping
# 3/3 [==============================] - 0s 2ms/step - loss: 0.4821 - nll_gaussian: 0.0310
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00073: early stopping
# 3/3 [==============================] - 0s 3ms/step - loss: 0.7474 - nll_gaussian: 0.1947
# Loss: 0.11132298894226551
# Computation time: 54.7s
# best loss search: 0.11031192080117762
# loss refitting : 0.11132298894226551

# %% [markdown]
# ## Make predictions for the test data set
# Now we can use the trained models to make predicitons on the test data set to evaluate how good the model perfoms on a data set that it never saw before.

# %%
pred_mean, pred_std = model.predict(testX)

# %%
# from ninolearn.learn.fit import cross_hindcast_dem, cross_hindcast
# cross_hindcast(model, pipeline, 'DEM')
# # cross_hindcast_dem(model, pipeline, 'DEM')

# %% [markdown]
# ## Plot the prediction
# Let's see how the predicion is looking like

# %%
import matplotlib.pyplot as plt
from ninolearn.plot.prediction import plot_prediction
import pandas as pd
from ninolearn.pathes import plotdir

from os.path import join


plt.subplots(figsize=(15,3.5))
plt.axhspan(-0.5,
            -6,
            facecolor='blue',
            alpha=0.1,zorder=0)

plt.axhspan(0.5,
            6,
            facecolor='red',
            alpha=0.1,zorder=0)

plt.xlim(testtimey[0], testtimey[-1])
plt.ylim(-3,3)

# plot the prediction
plot_prediction(testtimey, pred_mean, std=pred_std, facecolor='royalblue', line_color='navy')

# plot the observation
plt.plot(timey, y, "r", label = 'observation')
plt.legend()

plt.savefig(join(plotdir, f'predicVSobs_{version}_{lead_time}lead'))

plt.show()

# %% [markdown]
# ## Evaluate the model
#
# We can evaluate the model a bit more quantitatively using the loss function that was used to train the model, namely the negative-log-likelihood of the Gaussian and the correlation between the predicted mean and the observed ONI index.

# %%
from ninolearn.plot.evaluation import plot_correlation, plot_confMat, plot_seasonal_skill

loss = model.evaluate(testy, pred_mean, pred_std)
print(f"Loss (Negative-Log-Likelihood): {loss}")

# make a plot of the seasonal correaltion
# note: - pd.tseries.offsets.MonthBegin(1) appears to ensure that the correlations are plotted
# agains the correct season
plot_correlation(testy, pred_mean, testtimey - pd.tseries.offsets.MonthBegin(1), title="")

# plot_seasonal_skill(leadtime, r_seas)

# plt.savefig(join(plotdir, f'correlation_{version}_{lead_time}lead'))
# Out:
# Loss (Negative-Log-Likelihood): 0.08711931488296602

# %%
from ninolearn.learn.fit import n_decades, lead_times, decade_color, decade_name, cross_hindcast_dem
from ninolearn.learn.evaluation import evaluation_correlation, evaluation_decadal_correlation, evaluation_seasonal_correlation

# cross_hindcast_dem(model, pipeline, 'DEM')

# r_seas, p_seas = evaluation_seasonal_correlation('DEM', variable_name='prediction')

plot_seasonal_skill(lead_times, r_seas,  vmin=0, vmax=1)
plt.contour(np.arange(1,13),lead_times, p_seas, levels=[0.01, 0.05, 0.1], linestyles=['solid', 'dashed', 'dotted'], colors='k')
plt.title('Correlation skill')
plt.tight_layout()
# Out:
# Traceback (most recent call last):
#
#   File "/home/ivo/anaconda3/envs/ninolearn/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3343, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-13-a2c06cc56853>", line 1, in <module>
#     from ninolearn.learn.fit import n_decades, lead_times, decade_color, decade_name, cross_hindcast_dem
#
#   File "/home/ivo/Documents/GitHub/ninolearn/ninolearn/learn/fit.py", line 3
#     """
#
# ^
# SyntaxError: invalid syntax
