# %% [markdown]
# # Deep ensemble for ENSO-forecasting
#
# In this tutorial you learn how to use a neural network model called Deep Ensemble (DE) for the ENSO forecasting. This network architecture was initially developed [Lakshminarayanan et al. (2017)](https://papers.nips.cc/paper/7219-simple-and-scalable-predictive-uncertainty-estimation-using-deep-ensembles.pdf).
#
# DEs are feed foreword neural networks that predict the mean and the standard deviation of a Gaussian. Hence, their predicion comes with an uncertainty estimation which is a valuable feature for ENSO-forecasting.

# %% [markdown]
# ## Create a data pipe line
#
# At first, we define a data pipeline. This is in general quite useful to keep your code clean and also to reuse the pipeline for later purpose.
#
# The data pipeline generates returns:
#
# 1. The feature array
#
# 2. The label array
#
# 3. The time  array corresponding to the time of the label
#
# NOTE (again): Lead time is defined as the time that passed between the last observed and the first date of the target season. Hence, negative appear, e.g. if you compare the DJF season with the target season JFM, you have a lead time of -2 month (Last observed date: Feburary 28/29, First date of the target season January 1).

# %%
from ninolearn.IO.read_processed import data_reader
from ninolearn.IO.read_raw import ZC_simple_read
import numpy as np
import pandas as pd

oneyear= pd.Timedelta(365, 'D')

# %%
version = 'mu25'
leadtime = 24

# t_start is defined using a funky timedelta because the starting date of the network analysis data is the last month
# of its start year which is 1951-12 therefore the time must start in 1952 with some months added for values lost in 
# interpolation. TODO: fix this by backwards interpolating the first values of the year and finding out what is happening 
# with the nms
times = np.unique(ZC_simple_read(version)['time'])

t_start = times[0] + pd.Timedelta((2*365 + 90),'D')
t_end = times[-1] - pd.Timedelta(90,'D')

print(f'tstart = {t_start} and tend = {t_end}')
# Out:
# tstart = 1952-04-15 04:35:00 and tend = 1980-07-28 11:33:20

# %%
from ninolearn.IO.read_raw import ZC_raw, ZC_h, ZC_oni
from ninolearn.preprocess.prepare import prep_nms
from ninolearn.plot.ZC_dem_plots import nms_plots
## read raw ZC data and save to 1x1 grid file in processeddir
## also makes field of h and sst
ZC_raw(version)

## calculates monthly averaged (?) fields of thermocline height within region 
## of interest. cacluate ONI in region of interest. calculate network metrics 
## from sst (Henk's suggestion) or thermocline height (like Paul)
ZC_h(version) 
ZC_oni(version)
prep_nms(version, 0.99, t_start, t_end)

# make plots
nms_plots(version)
# Out:
# using dimensions ('lat', 'lon') from data variable temperature as the horizontal dimensions for this dataset.
# /home/ivo/anaconda3/envs/ninolearn/lib/python3.6/site-packages/xesmf/frontend.py:524: FutureWarning: ``output_sizes`` should be given in the ``dask_gufunc_kwargs`` parameter. It will be removed as direct parameter in a future version.
#   keep_attrs=keep_attrs
# /home/ivo/anaconda3/envs/ninolearn/lib/python3.6/site-packages/xesmf/smm.py:93: UserWarning: Input array is not C_CONTIGUOUS. Will affect performance.
#   warnings.warn("Input array is not C_CONTIGUOUS. "
# - Read sst climatetology
# using dimensions ('lat', 'lon') from data variable temperature as the horizontal dimensions for this dataset.
# /home/ivo/anaconda3/envs/ninolearn/lib/python3.6/site-packages/xesmf/frontend.py:524: FutureWarning: ``output_sizes`` should be given in the ``dask_gufunc_kwargs`` parameter. It will be removed as direct parameter in a future version.
#   keep_attrs=keep_attrs
# WARNING:Wrong input for computation of hamming distance.
# WARNING:Wrong input for computation of corrected hamming distance.
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!

# %%
reader = data_reader(startdate=(t_start + pd.Timedelta(365,'D')) , enddate=(t_end - pd.Timedelta(365, 'D')) , lon_min = 124, lon_max = 280,
                         lat_min = -19, lat_max = 19)

oni = reader.read_csv(('oni_ZC_' +version))
h = reader.read_csv(('h_mean_ZC_' + version))

network_ssh = reader.read_statistic('network_metrics', variable='sst', dataset=('ZC_25x25_' + version), processed="anom")
c2 = network_ssh['fraction_clusters_size_2']
H = network_ssh['corrected_hamming_distance']

# %%
if h.shape[0] + c2.shape[0] - H.shape[0] - oni.shape[0] == 0:
    print('All datasets are of equal length')
# Out:
# All datasets are of equal length

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler

from ninolearn.utils import include_time_lag
from ninolearn.IO.read_processed import data_reader


def pipeline(lead_time):
    """
    Data pipeline for the processing of the data before the Deep Ensemble
    is trained.

    :type lead_time: int
    :param lead_time: The lead time in month.

    :returns: The feature "X" (at observation time), the label "y" (at lead
    time), the target season "timey" (least month)
    """
#     reader = data_reader(startdate='1952-01', enddate='1992-12', lon_min = 124, lon_max = 280,
#                          lat_min = -19, lat_max = 19)
    reader = data_reader(startdate=(t_start + oneyear), enddate=(t_end - oneyear), lon_min = 124, lon_max = 280,
                         lat_min = -19, lat_max = 19)

    # indeces
    oni = reader.read_csv(('oni_ZC_' +version))
    h = reader.read_csv(('h_mean_ZC_' + version))
    #IOD unavailable in ZC87 model 
    
    # seasonal cycle
    sc = np.cos(np.arange(len(oni))/12*2*np.pi)

    # network metrics
    network_ssh = reader.read_statistic('network_metrics', variable='sst', dataset=('ZC_25x25_'+version), processed="anom")
    c2 = network_ssh['fraction_clusters_size_2']
    H = network_ssh['corrected_hamming_distance']

    # time lag
    time_lag = 12

    # shift such that lead time corresponds to the definition of lead time
    shift = 3

    # process features
    feature_unscaled = np.stack((oni, h,
                                 c2, H), axis=1)

    # scale each feature
    scalerX = StandardScaler()
    Xorg = scalerX.fit_transform(feature_unscaled)

    # set nans to 0.
    Xorg = np.nan_to_num(Xorg)

    # arange the feature array
    X = Xorg[:-lead_time-shift,:]
#     X = include_time_lag(X, max_lag=time_lag)
    X = include_time_lag(X, n_lags =12) 


    # arange label
    yorg = oni.values
    y = yorg[lead_time + time_lag + shift:]

    # get the time axis of the label
    timey = oni.index[lead_time + time_lag + shift:]

    return X, y, timey

# %% [markdown]
# ## Split the data set
#
# For the training and testing of machine learning models it is crucial to split the data set into:
#
# 1. __Train data set__ which is used to train the weights of the neural network
#
# 2. __Validation data set__ which is used to check for overfitting (e.g. when using early stopping) and to optimize the hyperparameters
#
# 3. __Test data set__ which is used to to evaluate the trained model.
#
# __NOTE:__ It is important to understand that hyperparamters must be tuned so that the result is best for the Validation data set and __not__ for the test data set. Otherwise you can not rule out the case that the specific hyperparameter setting just works good for the specific test data set but is not generally a good hyperparameter setting.
#
# In the following cell the train and the validation data set are still one data set, because this array will be later splitted into two arrays when th model is fitted.

# %%
import keras.backend as K
from ninolearn.learn.models.dem import DEM

# clear memory from previous sessions
K.clear_session()

# define the lead time
lead_time = leadtime

# get the features (X), the label (y) and 
# the time axis of the label (timey)
X, y, timey = pipeline(lead_time)

# split the data set into 
# test_indeces = (timey>='1987-01-01') & (timey<='1993-12-01')
test_indeces = (timey>=t_end - pd.Timedelta(5*365, 'D')) & (timey<=t_end)

train_val_indeces = np.invert(test_indeces)

train_val_X, train_val_y, train_val_timey = X[train_val_indeces,:], y[train_val_indeces], timey[train_val_indeces]
testX, testy, testtimey = X[test_indeces,:], y[test_indeces], timey[test_indeces]

# %% [markdown]
# ## Fit the model
#
# Now it is time to train the model! For this a random search is used for all keyword arguments that are passed in a *list* to the DEM.set_parameters() method.

# %%
# initiated an instance of the DEM (Deep Ensemble Model) class
model = DEM()

# Set parameters
model.set_hyperparameters(searchtype='linear', layers=1, neurons=16, dropout=[0.1, 0.5], noise_in=[0.1,0.5], noise_sigma=[0.1,0.5],
                     noise_mu=[0.1,0.5], l1_hidden=[0.0, 0.2], l2_hidden=[0., 0.2],
                     l1_mu=[0.0, 0.2], l2_mu=[0.0, 0.2], l1_sigma=[0.0, 0.2],
                     l2_sigma=[0.0, 0.2], lr=[0.0001,0.01], batch_size=100, epochs=500, n_segments=5,
                     n_members_segment=1, patience=30, verbose=0, pdf='normal', activation = 'relu')

# Use a random search to find the optimal hyperparameters

model.fit_RandomizedSearch(train_val_X, train_val_y, train_val_timey, n_iter=20)
# Out:
# Search iteration Nr 1/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00173: early stopping
# 2/2 [==============================] - 0s 16ms/step - loss: 3.9749 - nll_gaussian: 1.7275
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00295: early stopping
# 2/2 [==============================] - 0s 15ms/step - loss: 3.7692 - nll_gaussian: 1.3369
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00102: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 4.8240 - nll_gaussian: 2.4084
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00033: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 3.3296 - nll_gaussian: 1.1286
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00040: early stopping
# 2/2 [==============================] - 0s 12ms/step - loss: 4.9246 - nll_gaussian: 2.6072
# Loss: 1.8417140007019044
# Computation time: 72.1s
# New best hyperparameters
# Mean loss: 1.8417140007019044
# {'layers': 1, 'neurons': 16, 'dropout': 0.1462694358845108, 'noise_in': 0.48505068435694565, 'noise_sigma': 0.3171060198294011, 'noise_mu': 0.2705595719681753, 'l1_hidden': 0.11004671976583347, 'l2_hidden': 0.12201307726789024, 'l1_mu': 0.15054788638649413, 'l2_mu': 0.18213542526587248, 'l1_sigma': 0.03549650743926134, 'l2_sigma': 0.1360587618181047, 'lr': 0.000851521530924272, 'batch_size': 100, 'epochs': 500, 'n_segments': 5, 'n_members_segment': 1, 'patience': 30, 'verbose': 0, 'pdf': 'normal', 'activation': 'relu', 'n_members': 5}
# Search iteration Nr 2/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00045: early stopping
# 2/2 [==============================] - 0s 23ms/step - loss: 1.3754 - nll_gaussian: 0.7248
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00042: early stopping
# 2/2 [==============================] - 0s 14ms/step - loss: 1.3683 - nll_gaussian: 0.7381
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00055: early stopping
# 2/2 [==============================] - 0s 18ms/step - loss: 1.5521 - nll_gaussian: 1.0345
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00041: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 1.5031 - nll_gaussian: 0.4886
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00050: early stopping
# 2/2 [==============================] - 0s 1ms/step - loss: 1.5648 - nll_gaussian: 0.9464
# Loss: 0.7864736557006836
# Computation time: 27.7s
# New best hyperparameters
# Mean loss: 0.7864736557006836
# {'layers': 1, 'neurons': 16, 'dropout': 0.4806622160367967, 'noise_in': 0.45230035585348605, 'noise_sigma': 0.15852653396557315, 'noise_mu': 0.37653482249078485, 'l1_hidden': 0.18039089681263445, 'l2_hidden': 0.07132258667834594, 'l1_mu': 0.012719408873202798, 'l2_mu': 0.19714488156109466, 'l1_sigma': 0.0031535715422759793, 'l2_sigma': 0.1784530134644685, 'lr': 0.008281296391142662, 'batch_size': 100, 'epochs': 500, 'n_segments': 5, 'n_members_segment': 1, 'patience': 30, 'verbose': 0, 'pdf': 'normal', 'activation': 'relu', 'n_members': 5}
# Search iteration Nr 3/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00115: early stopping
# 2/2 [==============================] - 0s 13ms/step - loss: 1.2275 - nll_gaussian: 0.3531
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00140: early stopping
# 2/2 [==============================] - 0s 5ms/step - loss: 1.0418 - nll_gaussian: 0.2267
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00163: early stopping
# 2/2 [==============================] - 0s 9ms/step - loss: 1.3317 - nll_gaussian: 0.4801
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00067: early stopping
# 2/2 [==============================] - 0s 3ms/step - loss: 2.5521 - nll_gaussian: 0.4197
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00146: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 1.3886 - nll_gaussian: 0.4535
# Loss: 0.38662555515766145
# Computation time: 63.7s
# New best hyperparameters
# Mean loss: 0.38662555515766145
# {'layers': 1, 'neurons': 16, 'dropout': 0.12732225844716638, 'noise_in': 0.1362881784421619, 'noise_sigma': 0.21780526241601805, 'noise_mu': 0.34055053529200485, 'l1_hidden': 0.1766623104157135, 'l2_hidden': 0.14667747790917948, 'l1_mu': 0.13698081140048596, 'l2_mu': 0.07085124203028002, 'l1_sigma': 0.19520926434647126, 'l2_sigma': 0.09627776681159246, 'lr': 0.005853255079000589, 'batch_size': 100, 'epochs': 500, 'n_segments': 5, 'n_members_segment': 1, 'patience': 30, 'verbose': 0, 'pdf': 'normal', 'activation': 'relu', 'n_members': 5}
# Search iteration Nr 4/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00140: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 4.9669 - nll_gaussian: 1.4107
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00064: early stopping
# 2/2 [==============================] - 0s 8ms/step - loss: 4.1749 - nll_gaussian: 1.3345
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00104: early stopping
# 2/2 [==============================] - 0s 3ms/step - loss: 5.7036 - nll_gaussian: 2.4259
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00066: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 4.3966 - nll_gaussian: 1.0760
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00126: early stopping
# 2/2 [==============================] - 0s 4ms/step - loss: 5.2454 - nll_gaussian: 1.9050
# Loss: 1.630401110649109
# Computation time: 54.5s
# Search iteration Nr 5/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00067: early stopping
# 2/2 [==============================] - 0s 3ms/step - loss: 1.8123 - nll_gaussian: 0.7511
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00061: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 2.6966 - nll_gaussian: 0.7805
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00229: early stopping
# 2/2 [==============================] - 0s 1ms/step - loss: 4.6196 - nll_gaussian: 1.0927
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00063: early stopping
# 2/2 [==============================] - 0s 3ms/step - loss: 2.1422 - nll_gaussian: 0.5560
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00090: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 1.6466 - nll_gaussian: 1.0666
# Loss: 0.8493995547294617
# Computation time: 52.4s
# Search iteration Nr 6/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00161: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 0.7486 - nll_gaussian: 0.3186
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00187: early stopping
# 2/2 [==============================] - 0s 1ms/step - loss: 0.5791 - nll_gaussian: 0.0257
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00192: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 0.9571 - nll_gaussian: 0.3529
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00096: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 1.1718 - nll_gaussian: 0.3602
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00220: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 0.9619 - nll_gaussian: 0.3607
# Loss: 0.28362405970692633
# Computation time: 79.4s
# New best hyperparameters
# Mean loss: 0.28362405970692633
# {'layers': 1, 'neurons': 16, 'dropout': 0.3237873695663471, 'noise_in': 0.27838770780767286, 'noise_sigma': 0.1412230249651596, 'noise_mu': 0.4753278701921788, 'l1_hidden': 0.06470730321555672, 'l2_hidden': 0.12940078520004214, 'l1_mu': 0.03893075177239287, 'l2_mu': 0.02592843562294225, 'l1_sigma': 0.10476624195410883, 'l2_sigma': 0.14376216854906318, 'lr': 0.0018649945260983704, 'batch_size': 100, 'epochs': 500, 'n_segments': 5, 'n_members_segment': 1, 'patience': 30, 'verbose': 0, 'pdf': 'normal', 'activation': 'relu', 'n_members': 5}
# Search iteration Nr 7/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00056: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 4.6107 - nll_gaussian: 0.6020
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00080: early stopping
# 2/2 [==============================] - 0s 1ms/step - loss: 4.6616 - nll_gaussian: 0.2939
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00132: early stopping
# 2/2 [==============================] - 0s 3ms/step - loss: 8.9810 - nll_gaussian: 0.5237
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00119: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 7.4417 - nll_gaussian: 0.2442
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00038: early stopping
# 2/2 [==============================] - 0s 5ms/step - loss: 7.0341 - nll_gaussian: 2.4139
# Loss: 0.8155474483966827
# Computation time: 41.0s
# Search iteration Nr 8/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00082: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 2.6023 - nll_gaussian: 0.5219
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00237: early stopping
# 2/2 [==============================] - 0s 1ms/step - loss: 3.6169 - nll_gaussian: 0.3296
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00074: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 3.0591 - nll_gaussian: 0.4587
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00086: early stopping
# 2/2 [==============================] - 0s 3ms/step - loss: 2.6983 - nll_gaussian: 0.4230
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00144: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 2.4998 - nll_gaussian: 0.6592
# Loss: 0.4784898340702057
# Computation time: 58.6s
# Search iteration Nr 9/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00096: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 2.5359 - nll_gaussian: 1.3930
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00049: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 1.8774 - nll_gaussian: 1.4764
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00117: early stopping
# 2/2 [==============================] - 0s 1ms/step - loss: 2.1725 - nll_gaussian: 0.7443
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00086: early stopping
# 2/2 [==============================] - 0s 3ms/step - loss: 1.2841 - nll_gaussian: 0.1926
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00286: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 1.9360 - nll_gaussian: 0.9428
# Loss: 0.9498234003782272
# Computation time: 59.7s
# Search iteration Nr 10/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00055: early stopping
# 2/2 [==============================] - 0s 3ms/step - loss: 6.6736 - nll_gaussian: 0.7418
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00075: early stopping
# 2/2 [==============================] - 0s 3ms/step - loss: 8.6799 - nll_gaussian: 1.0951
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00074: early stopping
# 2/2 [==============================] - 0s 8ms/step - loss: 7.6708 - nll_gaussian: 0.5637
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00052: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 6.0956 - nll_gaussian: 0.3628
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00144: early stopping
# 2/2 [==============================] - 0s 1ms/step - loss: 8.5507 - nll_gaussian: 0.6783
# Loss: 0.6883658945560456
# Computation time: 41.3s
# Search iteration Nr 11/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00248: early stopping
# 2/2 [==============================] - 0s 3ms/step - loss: 0.7966 - nll_gaussian: 0.3526
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00198: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 0.6830 - nll_gaussian: 0.0311
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00236: early stopping
# 2/2 [==============================] - 0s 1ms/step - loss: 1.0666 - nll_gaussian: 0.3623
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00121: early stopping
# 2/2 [==============================] - 0s 3ms/step - loss: 1.2660 - nll_gaussian: 0.3272
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00231: early stopping
# 2/2 [==============================] - 0s 3ms/step - loss: 1.0149 - nll_gaussian: 0.3446
# Loss: 0.28353567123413087
# Computation time: 92.3s
# New best hyperparameters
# Mean loss: 0.28353567123413087
# {'layers': 1, 'neurons': 16, 'dropout': 0.43663708682438784, 'noise_in': 0.12116784301196924, 'noise_sigma': 0.17118317505084757, 'noise_mu': 0.1742484936111747, 'l1_hidden': 0.04661168987923532, 'l2_hidden': 0.026214233792031583, 'l1_mu': 0.07088704010304625, 'l2_mu': 0.06889042536286949, 'l1_sigma': 0.12668868022361315, 'l2_sigma': 0.15847098351400057, 'lr': 0.0010894976398420565, 'batch_size': 100, 'epochs': 500, 'n_segments': 5, 'n_members_segment': 1, 'patience': 30, 'verbose': 0, 'pdf': 'normal', 'activation': 'relu', 'n_members': 5}
# Search iteration Nr 12/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00129: early stopping
# 2/2 [==============================] - 0s 1ms/step - loss: 0.9033 - nll_gaussian: 0.3391
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00050: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 1.2057 - nll_gaussian: 0.4104
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00161: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 1.1659 - nll_gaussian: 0.3987
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00109: early stopping
# 2/2 [==============================] - 0s 5ms/step - loss: 1.0169 - nll_gaussian: 0.1524
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00062: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 1.5051 - nll_gaussian: 0.8778
# Loss: 0.4357068300247192
# Computation time: 45.0s
# Search iteration Nr 13/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00043: early stopping
# 2/2 [==============================] - 0s 3ms/step - loss: 4.2386 - nll_gaussian: 1.6122
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00075: early stopping
# 2/2 [==============================] - 0s 6ms/step - loss: 4.5363 - nll_gaussian: 0.9019
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00038: early stopping
# 2/2 [==============================] - 0s 6ms/step - loss: 5.2256 - nll_gaussian: 2.4819
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00033: early stopping
# 2/2 [==============================] - 0s 3ms/step - loss: 3.6162 - nll_gaussian: 0.9639
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00139: early stopping
# 2/2 [==============================] - 0s 7ms/step - loss: 7.5974 - nll_gaussian: 1.0253
# Loss: 1.3970484375953673
# Computation time: 32.8s
# Search iteration Nr 14/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00342: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 1.9086 - nll_gaussian: 0.8251
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00040: early stopping
# 2/2 [==============================] - 0s 6ms/step - loss: 1.9122 - nll_gaussian: 1.5111
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00073: early stopping
# 2/2 [==============================] - 0s 7ms/step - loss: 3.3435 - nll_gaussian: 2.4369
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00039: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 1.6422 - nll_gaussian: 1.0431
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00050: early stopping
# 2/2 [==============================] - 0s 7ms/step - loss: 2.9348 - nll_gaussian: 2.1813
# Loss: 1.5994964122772217
# Computation time: 54.4s
# Search iteration Nr 15/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00121: early stopping
# 2/2 [==============================] - 0s 8ms/step - loss: 4.0580 - nll_gaussian: 0.7729
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00074: early stopping
# 2/2 [==============================] - 0s 8ms/step - loss: 3.8094 - nll_gaussian: 1.0573
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00054: early stopping
# 2/2 [==============================] - 0s 7ms/step - loss: 2.8249 - nll_gaussian: 0.4327
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00049: early stopping
# 2/2 [==============================] - 0s 3ms/step - loss: 2.7206 - nll_gaussian: 0.4999
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00050: early stopping
# 2/2 [==============================] - 0s 7ms/step - loss: 3.7581 - nll_gaussian: 1.5761
# Loss: 0.8677827715873718
# Computation time: 34.6s
# Search iteration Nr 16/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00151: early stopping
# 2/2 [==============================] - 0s 7ms/step - loss: 9.5761 - nll_gaussian: 0.5866
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00050: early stopping
# 2/2 [==============================] - 0s 6ms/step - loss: 5.7199 - nll_gaussian: 1.3666
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00046: early stopping
# 2/2 [==============================] - 0s 8ms/step - loss: 7.2545 - nll_gaussian: 2.4227
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00031: early stopping
# 2/2 [==============================] - 0s 6ms/step - loss: 4.1807 - nll_gaussian: 1.1886
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00152: early stopping
# 2/2 [==============================] - 0s 3ms/step - loss: 10.7953 - nll_gaussian: 0.7815
# Loss: 1.2692113757133483
# Computation time: 47.4s
# Search iteration Nr 17/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00131: early stopping
# 2/2 [==============================] - 0s 1ms/step - loss: 8.9353 - nll_gaussian: 1.9351
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00051: early stopping
# 2/2 [==============================] - 0s 3ms/step - loss: 5.8466 - nll_gaussian: 1.5143
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00073: early stopping
# 2/2 [==============================] - 0s 4ms/step - loss: 5.6031 - nll_gaussian: 0.5289
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00036: early stopping
# 2/2 [==============================] - 0s 5ms/step - loss: 3.2421 - nll_gaussian: 0.6479
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00258: early stopping
# 2/2 [==============================] - 0s 1ms/step - loss: 7.0554 - nll_gaussian: 1.0224
# Loss: 1.1297349691390992
# Computation time: 50.5s
# Search iteration Nr 18/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00054: early stopping
# 2/2 [==============================] - 0s 3ms/step - loss: 4.1413 - nll_gaussian: 0.5945
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00063: early stopping
# 2/2 [==============================] - 0s 3ms/step - loss: 2.5099 - nll_gaussian: 0.2690
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00054: early stopping
# 2/2 [==============================] - 0s 3ms/step - loss: 4.6815 - nll_gaussian: 0.6561
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00058: early stopping
# 2/2 [==============================] - 0s 7ms/step - loss: 1.5458 - nll_gaussian: 0.4079
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00148: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 5.6527 - nll_gaussian: 0.4943
# Loss: 0.4843567669391632
# Computation time: 38.8s
# Search iteration Nr 19/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00070: early stopping
# 2/2 [==============================] - 0s 4ms/step - loss: 9.3813 - nll_gaussian: 0.5284
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00095: early stopping
# 2/2 [==============================] - 0s 3ms/step - loss: 9.2031 - nll_gaussian: 0.7830
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00124: early stopping
# 2/2 [==============================] - 0s 25ms/step - loss: 11.8317 - nll_gaussian: 0.7307
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00039: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 4.2734 - nll_gaussian: 0.4164
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00082: early stopping
# 2/2 [==============================] - 0s 4ms/step - loss: 8.4471 - nll_gaussian: 0.5788
# Loss: 0.6074823379516602
# Computation time: 48.9s
# Search iteration Nr 20/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00106: early stopping
# 2/2 [==============================] - 0s 4ms/step - loss: 6.5826 - nll_gaussian: 1.1425
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00249: early stopping
# 2/2 [==============================] - 0s 1ms/step - loss: 7.6361 - nll_gaussian: 0.3996
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00050: early stopping
# 2/2 [==============================] - 0s 9ms/step - loss: 6.3272 - nll_gaussian: 1.8772
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00080: early stopping
# 2/2 [==============================] - 0s 10ms/step - loss: 4.9914 - nll_gaussian: 0.8585
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00116: early stopping
# 2/2 [==============================] - 0s 11ms/step - loss: 6.6652 - nll_gaussian: 1.5823
# Loss: 1.172005534172058
# Computation time: 68.3s
# Refit the model with best hyperparamters
# {'layers': 1, 'neurons': 16, 'dropout': 0.43663708682438784, 'noise_in': 0.12116784301196924, 'noise_sigma': 0.17118317505084757, 'noise_mu': 0.1742484936111747, 'l1_hidden': 0.04661168987923532, 'l2_hidden': 0.026214233792031583, 'l1_mu': 0.07088704010304625, 'l2_mu': 0.06889042536286949, 'l1_sigma': 0.12668868022361315, 'l2_sigma': 0.15847098351400057, 'lr': 0.0010894976398420565, 'batch_size': 100, 'epochs': 500, 'n_segments': 5, 'n_members_segment': 1, 'patience': 30, 'verbose': 0, 'pdf': 'normal', 'activation': 'relu', 'n_members': 5}
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00216: early stopping
# 2/2 [==============================] - 0s 21ms/step - loss: 0.9311 - nll_gaussian: 0.2302
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00205: early stopping
# 2/2 [==============================] - 0s 4ms/step - loss: 0.6294 - nll_gaussian: 0.0300
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00261: early stopping
# 2/2 [==============================] - 0s 10ms/step - loss: 1.0412 - nll_gaussian: 0.3965
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00110: early stopping
# 2/2 [==============================] - 0s 20ms/step - loss: 1.2542 - nll_gaussian: 0.3611
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00233: early stopping
# 2/2 [==============================] - 0s 9ms/step - loss: 1.0705 - nll_gaussian: 0.3534
# Loss: 0.27423609122633935
# Computation time: 136.1s
# best loss search: 0.28353567123413087
# loss refitting : 0.27423609122633935

# %% [markdown]
# ## Make predictions for the test data set
# Now we can use the trained models to make predicitons on the test data set to evaluate how good the model perfoms on a data set that it never saw before.

# %%
pred_mean, pred_std = model.predict(testX)

# %% [markdown]
# ## Plot the prediction
# Let's see how the predicion is looking like

# %%
import matplotlib.pyplot as plt
from ninolearn.plot.prediction import plot_prediction
import pandas as pd
from ninolearn.pathes import plotdir

from os.path import join


plt.subplots(figsize=(15,3.5))
plt.axhspan(-0.5,
            -6,
            facecolor='blue',
            alpha=0.1,zorder=0)

plt.axhspan(0.5,
            6,
            facecolor='red',
            alpha=0.1,zorder=0)

plt.xlim(testtimey[0], testtimey[-1])
plt.ylim(-3,3)

# plot the prediction
plot_prediction(testtimey, pred_mean, std=pred_std, facecolor='royalblue', line_color='navy')

# plot the observation
plt.plot(timey, y, "r", label = 'observation')
plt.legend()

plt.savefig(join(plotdir, f'predicVSobs_{version}_{lead_time}lead'))

plt.show()

# %% [markdown]
# ## Evaluate the model
#
# We can evaluate the model a bit more quantitatively using the loss function that was used to train the model, namely the negative-log-likelihood of the Gaussian and the correlation between the predicted mean and the observed ONI index.

# %%
from ninolearn.plot.evaluation import plot_correlation

loss = model.evaluate(testy, pred_mean, pred_std)
print(f"Loss (Negative-Log-Likelihood): {loss}")

# make a plot of the seasonal correaltion
# note: - pd.tseries.offsets.MonthBegin(1) appears to ensure that the correlations are plotted
# agains the correct season
plot_correlation(testy, pred_mean, testtimey - pd.tseries.offsets.MonthBegin(1), title="")

plt.savefig(join(plotdir, f'correlation_{version}_{lead_time}lead'))
# Out:
# Loss (Negative-Log-Likelihood): 0.37452185171453617
