# %% [markdown]
# # Deep ensemble for ENSO-forecasting
#
# In this tutorial you learn how to use a neural network model called Deep Ensemble (DE) for the ENSO forecasting. This network architecture was initially developed [Lakshminarayanan et al. (2017)](https://papers.nips.cc/paper/7219-simple-and-scalable-predictive-uncertainty-estimation-using-deep-ensembles.pdf).
#
# DEs are feed foreword neural networks that predict the mean and the standard deviation of a Gaussian. Hence, their predicion comes with an uncertainty estimation which is a valuable feature for ENSO-forecasting.

# %% [markdown]
# ## Create a data pipe line
#
# At first, we define a data pipeline. This is in general quite useful to keep your code clean and also to reuse the pipeline for later purpose.
#
# The data pipeline generates returns:
#
# 1. The feature array
#
# 2. The label array
#
# 3. The time  array corresponding to the time of the label
#
# NOTE (again): Lead time is defined as the time that passed between the last observed and the first date of the target season. Hence, negative appear, e.g. if you compare the DJF season with the target season JFM, you have a lead time of -2 month (Last observed date: Feburary 28/29, First date of the target season January 1).

# %%
from ninolearn.IO.read_processed import data_reader
from ninolearn.IO.read_raw import ZC_simple_read
import numpy as np
import pandas as pd

oneyear= pd.Timedelta(365, 'D')

# %%
version = 'mu25'
leadtime = 24

# t_start is defined using a funky timedelta because the starting date of the network analysis data is the last month
# of its start year which is 1951-12 therefore the time must start in 1952 with some months added for values lost in 
# interpolation. TODO: fix this by backwards interpolating the first values of the year and finding out what is happening 
# with the nms
times = np.unique(ZC_simple_read(version)['time'])

t_start = times[0] + pd.Timedelta((2*365 + 90),'D')
t_end = times[-1] - pd.Timedelta(90,'D')

print(f'tstart = {t_start} and tend = {t_end}')
# Out:
# tstart = 1952-04-15 04:35:00 and tend = 1980-07-28 11:33:20

# %%
from ninolearn.IO.read_raw import ZC_raw, ZC_h, ZC_oni
from ninolearn.preprocess.prepare import prep_nms
from ninolearn.plot.ZC_dem_plots import nms_plots
## read raw ZC data and save to 1x1 grid file in processeddir
## also makes field of h and sst
ZC_raw(version)

## calculates monthly averaged (?) fields of thermocline height within region 
## of interest. cacluate ONI in region of interest. calculate network metrics 
## from sst (Henk's suggestion) or thermocline height (like Paul)
ZC_h(version) 
ZC_oni(version)
prep_nms(version, 0.99, t_start, t_end)

# make plots
nms_plots(version)
# Out:
# using dimensions ('lat', 'lon') from data variable temperature as the horizontal dimensions for this dataset.
# /home/ivo/anaconda3/envs/ninolearn/lib/python3.6/site-packages/xesmf/frontend.py:524: FutureWarning: ``output_sizes`` should be given in the ``dask_gufunc_kwargs`` parameter. It will be removed as direct parameter in a future version.
#   keep_attrs=keep_attrs
# /home/ivo/anaconda3/envs/ninolearn/lib/python3.6/site-packages/xesmf/smm.py:93: UserWarning: Input array is not C_CONTIGUOUS. Will affect performance.
#   warnings.warn("Input array is not C_CONTIGUOUS. "
# - Read sst climatetology
# using dimensions ('lat', 'lon') from data variable temperature as the horizontal dimensions for this dataset.
# /home/ivo/anaconda3/envs/ninolearn/lib/python3.6/site-packages/xesmf/frontend.py:524: FutureWarning: ``output_sizes`` should be given in the ``dask_gufunc_kwargs`` parameter. It will be removed as direct parameter in a future version.
#   keep_attrs=keep_attrs
# WARNING:Wrong input for computation of hamming distance.
# WARNING:Wrong input for computation of corrected hamming distance.
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!

# %%
reader = data_reader(startdate=(t_start + pd.Timedelta(365,'D')) , enddate=(t_end - pd.Timedelta(365, 'D')) , lon_min = 124, lon_max = 280,
                         lat_min = -19, lat_max = 19)

oni = reader.read_csv(('oni_ZC_' +version))
h = reader.read_csv(('h_mean_ZC_' + version))

network_ssh = reader.read_statistic('network_metrics', variable='sst', dataset=('ZC_25x25_' + version), processed="anom")
c2 = network_ssh['fraction_clusters_size_2']
H = network_ssh['corrected_hamming_distance']

# %%
if h.shape[0] + c2.shape[0] - H.shape[0] - oni.shape[0] == 0:
    print('All datasets are of equal length')
# Out:
# All datasets are of equal length

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler

from ninolearn.utils import include_time_lag
from ninolearn.IO.read_processed import data_reader


def pipeline(lead_time):
    """
    Data pipeline for the processing of the data before the Deep Ensemble
    is trained.

    :type lead_time: int
    :param lead_time: The lead time in month.

    :returns: The feature "X" (at observation time), the label "y" (at lead
    time), the target season "timey" (least month)
    """
#     reader = data_reader(startdate='1952-01', enddate='1992-12', lon_min = 124, lon_max = 280,
#                          lat_min = -19, lat_max = 19)
    reader = data_reader(startdate=(t_start + oneyear), enddate=(t_end - oneyear), lon_min = 124, lon_max = 280,
                         lat_min = -19, lat_max = 19)

    # indeces
    oni = reader.read_csv(('oni_ZC_' +version))
    h = reader.read_csv(('h_mean_ZC_' + version))
    #IOD unavailable in ZC87 model 
    
    # seasonal cycle
    sc = np.cos(np.arange(len(oni))/12*2*np.pi)

    # network metrics
    network_ssh = reader.read_statistic('network_metrics', variable='sst', dataset=('ZC_25x25_'+version), processed="anom")
    c2 = network_ssh['fraction_clusters_size_2']
    H = network_ssh['corrected_hamming_distance']

    # time lag
    time_lag = 12

    # shift such that lead time corresponds to the definition of lead time
    shift = 3

    # process features
    feature_unscaled = np.stack((oni, h,
                                 c2, H), axis=1)

    # scale each feature
    scalerX = StandardScaler()
    Xorg = scalerX.fit_transform(feature_unscaled)

    # set nans to 0.
    Xorg = np.nan_to_num(Xorg)

    # arange the feature array
    X = Xorg[:-lead_time-shift,:]
#     X = include_time_lag(X, max_lag=time_lag)
    X = include_time_lag(X, n_lags =12) 


    # arange label
    yorg = oni.values
    y = yorg[lead_time + time_lag + shift:]

    # get the time axis of the label
    timey = oni.index[lead_time + time_lag + shift:]

    return X, y, timey

# %% [markdown]
# ## Split the data set
#
# For the training and testing of machine learning models it is crucial to split the data set into:
#
# 1. __Train data set__ which is used to train the weights of the neural network
#
# 2. __Validation data set__ which is used to check for overfitting (e.g. when using early stopping) and to optimize the hyperparameters
#
# 3. __Test data set__ which is used to to evaluate the trained model.
#
# __NOTE:__ It is important to understand that hyperparamters must be tuned so that the result is best for the Validation data set and __not__ for the test data set. Otherwise you can not rule out the case that the specific hyperparameter setting just works good for the specific test data set but is not generally a good hyperparameter setting.
#
# In the following cell the train and the validation data set are still one data set, because this array will be later splitted into two arrays when th model is fitted.

# %%
import keras.backend as K
from ninolearn.learn.models.dem import DEM

# clear memory from previous sessions
K.clear_session()

# define the lead time
lead_time = leadtime

# get the features (X), the label (y) and 
# the time axis of the label (timey)
X, y, timey = pipeline(lead_time)

# split the data set into 
# test_indeces = (timey>='1987-01-01') & (timey<='1993-12-01')
test_indeces = (timey>=t_end - pd.Timedelta(5*365, 'D')) & (timey<=t_end)

train_val_indeces = np.invert(test_indeces)

train_val_X, train_val_y, train_val_timey = X[train_val_indeces,:], y[train_val_indeces], timey[train_val_indeces]
testX, testy, testtimey = X[test_indeces,:], y[test_indeces], timey[test_indeces]

# %% [markdown]
# ## Fit the model
#
# Now it is time to train the model! For this a random search is used for all keyword arguments that are passed in a *list* to the DEM.set_parameters() method.

# %%
# initiated an instance of the DEM (Deep Ensemble Model) class
model = DEM()

# Set parameters
model.set_hyperparameters(searchtype='linear', layers=1, neurons=16, dropout=[0.1, 0.5], noise_in=[0.1,0.5], noise_sigma=[0.1,0.5],
                     noise_mu=[0.1,0.5], l1_hidden=[0.0, 0.2], l2_hidden=[0., 0.2],
                     l1_mu=[0.0, 0.2], l2_mu=[0.0, 0.2], l1_sigma=[0.0, 0.2],
                     l2_sigma=[0.0, 0.2], lr=[0.0001,0.01], batch_size=100, epochs=500, n_segments=5,
                     n_members_segment=1, patience=30, verbose=0, pdf='normal', activation = 'relu')

# Use a random search to find the optimal hyperparameters

model.fit_RandomizedSearch(train_val_X, train_val_y, train_val_timey, n_iter=20)
# Out:
# Search iteration Nr 1/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00066: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 1.5119 - nll_gaussian: 0.6891
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00057: early stopping
# 2/2 [==============================] - 0s 6ms/step - loss: 1.3684 - nll_gaussian: 0.4343
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00147: early stopping
# 2/2 [==============================] - 0s 3ms/step - loss: 1.8986 - nll_gaussian: 0.3537
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00037: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 1.2720 - nll_gaussian: 0.4695
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00212: early stopping
# 2/2 [==============================] - 0s 3ms/step - loss: 2.0987 - nll_gaussian: 0.7476
# Loss: 0.5388225615024567
# Computation time: 57.6s
# New best hyperparameters
# Mean loss: 0.5388225615024567
# {'layers': 1, 'neurons': 16, 'dropout': 0.23091003915732977, 'noise_in': 0.3574744331023648, 'noise_sigma': 0.3391026243467522, 'noise_mu': 0.48528221842417896, 'l1_hidden': 0.004806006705345034, 'l2_hidden': 0.11252271837465444, 'l1_mu': 0.08138362009587619, 'l2_mu': 0.09007197590129175, 'l1_sigma': 0.18216807754601191, 'l2_sigma': 0.04756913189589425, 'lr': 0.009203858793786539, 'batch_size': 100, 'epochs': 500, 'n_segments': 5, 'n_members_segment': 1, 'patience': 30, 'verbose': 0, 'pdf': 'normal', 'activation': 'relu', 'n_members': 5}
# Search iteration Nr 2/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00041: early stopping
# 2/2 [==============================] - 0s 3ms/step - loss: 6.7064 - nll_gaussian: 0.9273
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00046: early stopping
# 2/2 [==============================] - 0s 3ms/step - loss: 7.8722 - nll_gaussian: 0.4955
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00052: early stopping
# 2/2 [==============================] - 0s 4ms/step - loss: 9.5365 - nll_gaussian: 1.3455
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00051: early stopping
# 2/2 [==============================] - 0s 1ms/step - loss: 8.4296 - nll_gaussian: 0.4047
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00169: early stopping
# 2/2 [==============================] - 0s 3ms/step - loss: 13.1192 - nll_gaussian: 1.2206
# Loss: 0.8787295162677765
# Computation time: 41.8s
# Search iteration Nr 3/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00072: early stopping
# 2/2 [==============================] - 0s 1ms/step - loss: 1.8460 - nll_gaussian: 0.2792
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00081: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 2.6856 - nll_gaussian: 0.3702
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00090: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 1.6384 - nll_gaussian: 0.4780
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00076: early stopping
# 2/2 [==============================] - 0s 3ms/step - loss: 1.3240 - nll_gaussian: 0.2532
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00102: early stopping
# 2/2 [==============================] - 0s 9ms/step - loss: 1.2617 - nll_gaussian: 0.4141
# Loss: 0.35893155336380006
# Computation time: 45.0s
# New best hyperparameters
# Mean loss: 0.35893155336380006
# {'layers': 1, 'neurons': 16, 'dropout': 0.38690254677617053, 'noise_in': 0.2254947514865885, 'noise_sigma': 0.20543363954091617, 'noise_mu': 0.15312008078594733, 'l1_hidden': 0.1189607848029892, 'l2_hidden': 0.010818502833278254, 'l1_mu': 0.06325980546282438, 'l2_mu': 0.0976683704001971, 'l1_sigma': 0.027997817836520403, 'l2_sigma': 0.1980666991407625, 'lr': 0.0074556410191846285, 'batch_size': 100, 'epochs': 500, 'n_segments': 5, 'n_members_segment': 1, 'patience': 30, 'verbose': 0, 'pdf': 'normal', 'activation': 'relu', 'n_members': 5}
# Search iteration Nr 4/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00055: early stopping
# 2/2 [==============================] - 0s 6ms/step - loss: 9.1539 - nll_gaussian: 0.7996
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00087: early stopping
# 2/2 [==============================] - 0s 6ms/step - loss: 11.2016 - nll_gaussian: 0.7618
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00040: early stopping
# 2/2 [==============================] - 0s 12ms/step - loss: 8.0314 - nll_gaussian: 1.6818
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00040: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 7.2473 - nll_gaussian: 0.8337
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00250: early stopping
# 2/2 [==============================] - 0s 8ms/step - loss: 14.2836 - nll_gaussian: 1.0761
# Loss: 1.0306003212928772
# Computation time: 44.7s
# Search iteration Nr 5/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00120: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 5.3395 - nll_gaussian: 1.0441
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00347: early stopping
# 2/2 [==============================] - 0s 1ms/step - loss: 5.5785 - nll_gaussian: 0.4512
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00118: early stopping
# 2/2 [==============================] - 0s 8ms/step - loss: 4.5676 - nll_gaussian: 0.6991
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00042: early stopping
# 2/2 [==============================] - 0s 15ms/step - loss: 3.3619 - nll_gaussian: 0.7694
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00220: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 5.0279 - nll_gaussian: 0.4543
# Loss: 0.6836211085319519
# Computation time: 73.8s
# Search iteration Nr 6/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00085: early stopping
# 2/2 [==============================] - 0s 4ms/step - loss: 0.7784 - nll_gaussian: 0.2920
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00123: early stopping
# 2/2 [==============================] - 0s 3ms/step - loss: 0.5984 - nll_gaussian: 0.0022
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00088: early stopping
# 2/2 [==============================] - 0s 3ms/step - loss: 1.0778 - nll_gaussian: 0.3423
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00063: early stopping
# 2/2 [==============================] - 0s 15ms/step - loss: 1.2273 - nll_gaussian: 0.3042
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00091: early stopping
# 2/2 [==============================] - 0s 1ms/step - loss: 1.0477 - nll_gaussian: 0.3584
# Loss: 0.2598214041441679
# Computation time: 40.7s
# New best hyperparameters
# Mean loss: 0.2598214041441679
# {'layers': 1, 'neurons': 16, 'dropout': 0.40388650610529264, 'noise_in': 0.20131280095578097, 'noise_sigma': 0.12978496850950572, 'noise_mu': 0.2892850200989491, 'l1_hidden': 0.05121632430547496, 'l2_hidden': 0.13103165392123592, 'l1_mu': 0.03544366279471516, 'l2_mu': 0.0912391173165808, 'l1_sigma': 0.12083512409162034, 'l2_sigma': 0.06135663497444255, 'lr': 0.0038615644220386146, 'batch_size': 100, 'epochs': 500, 'n_segments': 5, 'n_members_segment': 1, 'patience': 30, 'verbose': 0, 'pdf': 'normal', 'activation': 'relu', 'n_members': 5}
# Search iteration Nr 7/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00128: early stopping
# 2/2 [==============================] - 0s 6ms/step - loss: 3.6571 - nll_gaussian: 0.4787
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00071: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 4.1267 - nll_gaussian: 0.3697
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00063: early stopping
# 2/2 [==============================] - 0s 7ms/step - loss: 2.1067 - nll_gaussian: 0.7915
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00076: early stopping
# 2/2 [==============================] - 0s 6ms/step - loss: 4.1944 - nll_gaussian: 0.4143
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00136: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 1.7906 - nll_gaussian: 0.5373
# Loss: 0.5182756066322327
# Computation time: 44.6s
# Search iteration Nr 8/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00214: early stopping
# 2/2 [==============================] - 0s 1ms/step - loss: 9.1591 - nll_gaussian: 0.6843
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00064: early stopping
# 2/2 [==============================] - 0s 6ms/step - loss: 6.5465 - nll_gaussian: 1.4125
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00153: early stopping
# 2/2 [==============================] - 0s 3ms/step - loss: 8.8545 - nll_gaussian: 1.6933
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00083: early stopping
# 2/2 [==============================] - 0s 8ms/step - loss: 6.0172 - nll_gaussian: 0.8679
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00043: early stopping
# 2/2 [==============================] - 0s 6ms/step - loss: 5.4180 - nll_gaussian: 2.2040
# Loss: 1.3723952412605285
# Computation time: 76.8s
# Search iteration Nr 9/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00064: early stopping
# 2/2 [==============================] - 0s 5ms/step - loss: 3.2226 - nll_gaussian: 0.3653
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00051: early stopping
# 2/2 [==============================] - 0s 4ms/step - loss: 3.2449 - nll_gaussian: 0.4810
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00059: early stopping
# 2/2 [==============================] - 0s 6ms/step - loss: 3.4629 - nll_gaussian: 0.3762
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00042: early stopping
# 2/2 [==============================] - 0s 13ms/step - loss: 3.7413 - nll_gaussian: 0.4338
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00109: early stopping
# 2/2 [==============================] - 0s 6ms/step - loss: 4.3441 - nll_gaussian: 0.5849
# Loss: 0.4482376456260681
# Computation time: 49.9s
# Search iteration Nr 10/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00047: early stopping
# 2/2 [==============================] - 0s 7ms/step - loss: 4.4080 - nll_gaussian: 0.9654
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00100: early stopping
# 2/2 [==============================] - 0s 11ms/step - loss: 7.3309 - nll_gaussian: 0.2117
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00115: early stopping
# 2/2 [==============================] - 0s 4ms/step - loss: 6.2046 - nll_gaussian: 0.4968
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00045: early stopping
# 2/2 [==============================] - 0s 4ms/step - loss: 4.2931 - nll_gaussian: 0.5829
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00102: early stopping
# 2/2 [==============================] - 0s 4ms/step - loss: 5.6038 - nll_gaussian: 0.6834
# Loss: 0.5880380123853683
# Computation time: 64.6s
# Search iteration Nr 11/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00069: early stopping
# 2/2 [==============================] - 0s 3ms/step - loss: 3.6858 - nll_gaussian: 1.7050
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00244: early stopping
# 2/2 [==============================] - 0s 3ms/step - loss: 3.4819 - nll_gaussian: 1.3730
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00160: early stopping
# 2/2 [==============================] - 0s 3ms/step - loss: 4.7805 - nll_gaussian: 2.4268
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00120: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 3.0500 - nll_gaussian: 1.0030
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00146: early stopping
# 2/2 [==============================] - 0s 3ms/step - loss: 4.3478 - nll_gaussian: 2.2634
# Loss: 1.754246425628662
# Computation time: 87.0s
# Search iteration Nr 12/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00173: early stopping
# 2/2 [==============================] - 0s 3ms/step - loss: 2.1244 - nll_gaussian: 0.2830
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00115: early stopping
# 2/2 [==============================] - 0s 3ms/step - loss: 2.9163 - nll_gaussian: 0.3591
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00080: early stopping
# 2/2 [==============================] - 0s 4ms/step - loss: 5.5953 - nll_gaussian: 1.2809
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00065: early stopping
# 2/2 [==============================] - 0s 3ms/step - loss: 4.5589 - nll_gaussian: 0.5447
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00135: early stopping
# 2/2 [==============================] - 0s 3ms/step - loss: 10.1889 - nll_gaussian: 0.3688
# Loss: 0.5672927618026733
# Computation time: 52.4s
# Search iteration Nr 13/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00321: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 4.1163 - nll_gaussian: 1.5983
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00092: early stopping
# 2/2 [==============================] - 0s 3ms/step - loss: 3.9489 - nll_gaussian: 1.6761
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00240: early stopping
# 2/2 [==============================] - 0s 9ms/step - loss: 5.1666 - nll_gaussian: 2.3412
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00145: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 3.5067 - nll_gaussian: 1.0298
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00117: early stopping
# 2/2 [==============================] - 0s 3ms/step - loss: 5.0899 - nll_gaussian: 2.4522
# Loss: 1.8195075511932373
# Computation time: 80.6s
# Search iteration Nr 14/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00101: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 2.3201 - nll_gaussian: 0.7863
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00044: early stopping
# 2/2 [==============================] - 0s 3ms/step - loss: 2.2495 - nll_gaussian: 1.3904
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00112: early stopping
# 2/2 [==============================] - 0s 4ms/step - loss: 3.2949 - nll_gaussian: 0.8167
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00090: early stopping
# 2/2 [==============================] - 0s 3ms/step - loss: 2.1768 - nll_gaussian: 0.2418
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00064: early stopping
# 2/2 [==============================] - 0s 4ms/step - loss: 2.4135 - nll_gaussian: 0.9740
# Loss: 0.8418457746505738
# Computation time: 41.3s
# Search iteration Nr 15/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00057: early stopping
# 2/2 [==============================] - 0s 3ms/step - loss: 1.6622 - nll_gaussian: 0.5427
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00053: early stopping
# 2/2 [==============================] - 0s 3ms/step - loss: 1.6984 - nll_gaussian: 0.3449
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00068: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 3.0917 - nll_gaussian: 0.4360
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00045: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 2.9177 - nll_gaussian: 0.3714
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00047: early stopping
# 2/2 [==============================] - 0s 4ms/step - loss: 3.3252 - nll_gaussian: 0.5289
# Loss: 0.444802063703537
# Computation time: 31.5s
# Search iteration Nr 16/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00095: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 0.7992 - nll_gaussian: 0.2940
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00117: early stopping
# 2/2 [==============================] - 0s 1ms/step - loss: 0.6699 - nll_gaussian: 0.1305
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00092: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 0.9583 - nll_gaussian: 0.3487
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00075: early stopping
# 2/2 [==============================] - 0s 8ms/step - loss: 1.0008 - nll_gaussian: 0.2243
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00088: early stopping
# 2/2 [==============================] - 0s 3ms/step - loss: 0.9733 - nll_gaussian: 0.3707
# Loss: 0.2736292123794556
# Computation time: 46.4s
# Search iteration Nr 17/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00071: early stopping
# 2/2 [==============================] - 0s 4ms/step - loss: 5.1744 - nll_gaussian: 1.7209
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00056: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 4.7432 - nll_gaussian: 1.5212
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00288: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 5.2699 - nll_gaussian: 1.7640
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00225: early stopping
# 2/2 [==============================] - 0s 4ms/step - loss: 4.7057 - nll_gaussian: 0.6902
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00058: early stopping
# 2/2 [==============================] - 0s 4ms/step - loss: 4.1375 - nll_gaussian: 2.3329
# Loss: 1.6058589100837708
# Computation time: 66.6s
# Search iteration Nr 18/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00060: early stopping
# 2/2 [==============================] - 0s 1ms/step - loss: 5.3118 - nll_gaussian: 1.3484
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00035: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 5.0657 - nll_gaussian: 1.6362
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00031: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 6.3066 - nll_gaussian: 2.7540
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00084: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 5.0025 - nll_gaussian: 0.9937
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00053: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 6.3220 - nll_gaussian: 2.6473
# Loss: 1.8759114027023316
# Computation time: 28.3s
# Search iteration Nr 19/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00091: early stopping
# 2/2 [==============================] - 0s 3ms/step - loss: 10.1880 - nll_gaussian: 0.7988
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00107: early stopping
# 2/2 [==============================] - 0s 6ms/step - loss: 9.5572 - nll_gaussian: 0.3485
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00075: early stopping
# 2/2 [==============================] - 0s 3ms/step - loss: 8.7847 - nll_gaussian: 1.4576
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00047: early stopping
# 2/2 [==============================] - 0s 4ms/step - loss: 6.7572 - nll_gaussian: 1.0705
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00150: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 10.0068 - nll_gaussian: 0.3611
# Loss: 0.8073124051094055
# Computation time: 47.2s
# Search iteration Nr 20/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00056: early stopping
# 2/2 [==============================] - 0s 3ms/step - loss: 2.6119 - nll_gaussian: 1.1993
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00092: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 2.8734 - nll_gaussian: 0.6254
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00040: early stopping
# 2/2 [==============================] - 0s 1ms/step - loss: 3.1679 - nll_gaussian: 2.2045
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00174: early stopping
# 2/2 [==============================] - 0s 3ms/step - loss: 2.2205 - nll_gaussian: 0.3116
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00047: early stopping
# 2/2 [==============================] - 0s 4ms/step - loss: 3.2105 - nll_gaussian: 1.8226
# Loss: 1.2326960921287538
# Computation time: 42.0s
# Refit the model with best hyperparamters
# {'layers': 1, 'neurons': 16, 'dropout': 0.40388650610529264, 'noise_in': 0.20131280095578097, 'noise_sigma': 0.12978496850950572, 'noise_mu': 0.2892850200989491, 'l1_hidden': 0.05121632430547496, 'l2_hidden': 0.13103165392123592, 'l1_mu': 0.03544366279471516, 'l2_mu': 0.0912391173165808, 'l1_sigma': 0.12083512409162034, 'l2_sigma': 0.06135663497444255, 'lr': 0.0038615644220386146, 'batch_size': 100, 'epochs': 500, 'n_segments': 5, 'n_members_segment': 1, 'patience': 30, 'verbose': 0, 'pdf': 'normal', 'activation': 'relu', 'n_members': 5}
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00071: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 0.8289 - nll_gaussian: 0.3080
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00112: early stopping
# 2/2 [==============================] - 0s 4ms/step - loss: 0.5741 - nll_gaussian: 0.0100
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00097: early stopping
# 2/2 [==============================] - 0s 4ms/step - loss: 1.0104 - nll_gaussian: 0.3905
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00061: early stopping
# 2/2 [==============================] - 0s 1ms/step - loss: 1.1637 - nll_gaussian: 0.2928
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00093: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 1.0390 - nll_gaussian: 0.3870
# Loss: 0.2776606477797031
# Computation time: 44.3s
# best loss search: 0.2598214041441679
# loss refitting : 0.2776606477797031

# %% [markdown]
# ## Make predictions for the test data set
# Now we can use the trained models to make predicitons on the test data set to evaluate how good the model perfoms on a data set that it never saw before.

# %%
pred_mean, pred_std = model.predict(testX)

# %%
pred_mean.shape
# Out:
# (48,)

# %% [markdown]
# ## Plot the prediction
# Let's see how the predicion is looking like

# %%
import matplotlib.pyplot as plt
from ninolearn.plot.prediction import plot_prediction
import pandas as pd
from ninolearn.pathes import plotdir

from os.path import join


plt.subplots(figsize=(15,3.5))
plt.axhspan(-0.5,
            -6,
            facecolor='blue',
            alpha=0.1,zorder=0)

plt.axhspan(0.5,
            6,
            facecolor='red',
            alpha=0.1,zorder=0)

plt.xlim(testtimey[0], testtimey[-1])
plt.ylim(-3,3)

# plot the prediction
plot_prediction(testtimey, pred_mean, std=pred_std, facecolor='royalblue', line_color='navy')

# plot the observation
plt.plot(timey, y, "r", label = 'observation')
plt.legend()

plt.savefig(join(plotdir, f'predicVSobs_{version}_{lead_time}lead'))

plt.show()

# %% [markdown]
# ## Evaluate the model
#
# We can evaluate the model a bit more quantitatively using the loss function that was used to train the model, namely the negative-log-likelihood of the Gaussian and the correlation between the predicted mean and the observed ONI index.

# %%
from ninolearn.plot.evaluation import plot_correlation, plot_confMat, plot_seasonal_skill

loss = model.evaluate(testy, pred_mean, pred_std)
print(f"Loss (Negative-Log-Likelihood): {loss}")

# make a plot of the seasonal correaltion
# note: - pd.tseries.offsets.MonthBegin(1) appears to ensure that the correlations are plotted
# agains the correct season
plot_correlation(testy, pred_mean, testtimey - pd.tseries.offsets.MonthBegin(1), title="")

plot_seasonal_skill(leadtime, r_seas)

# plt.savefig(join(plotdir, f'correlation_{version}_{lead_time}lead'))
# Out:
# Loss (Negative-Log-Likelihood): 0.37748529855651397

# %%
from ninolearn.learn.fit import n_decades, lead_times, decade_color, decade_name
from ninolearn.learn.evaluation import evaluation_correlation, evaluation_decadal_correlation, evaluation_seasonal_correlation
from ninolearn.learn.fit import cross_hindcast_dem

cross_hindcast_dem(model, pipeline, 'DEM')

r_seas, p_seas = evaluation_seasonal_correlation('DEM', variable_name='prediction')

plot_seasonal_skill(lead_times, r_seas,  vmin=0, vmax=1)
plt.contour(np.arange(1,13),lead_times, p_seas, levels=[0.01, 0.05, 0.1], linestyles=['solid', 'dashed', 'dotted'], colors='k')
plt.title('Correlation skill')
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/ninolearn/lib/python3.6/site-packages/xarray/backends/file_manager.py in _acquire_with_cache_info(self, needs_lock)
#     198             try:
# --> 199                 file = self._cache[self._key]
#     200             except KeyError:
#
# ~/anaconda3/envs/ninolearn/lib/python3.6/site-packages/xarray/backends/lru_cache.py in __getitem__(self, key)
#      52         with self._lock:
# ---> 53             value = self._cache[key]
#      54             self._cache.move_to_end(key)
#
# KeyError: [<class 'netCDF4._netCDF4.Dataset'>, ('/home/ivo/Documents/GitHub/ninolearn/research/ivo_thesis/data/processed/DEM_std_estimate.nc',), 'r', (('clobber', True), ('diskless', False), ('format', 'NETCDF4'), ('persist', False))]
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-19-08bf7f8c5693> in <module>
#       3 from ninolearn.learn.fit import cross_hindcast_dem
#       4
# ----> 5 cross_hindcast_dem(model, pipeline, 'DEM')
#       6
#       7 r_seas, p_seas = evaluation_seasonal_correlation('DEM', variable_name='prediction')
#
# ~/Documents/GitHub/ninolearn/ninolearn/learn/fit.py in cross_hindcast_dem(model, pipeline, model_name)
#     164     #cross_hindcast(model, pipeline, model_name)
#     165
# --> 166     std_estimate = xr.open_dataarray(join(processeddir, f'{model_name}_std_estimate.nc'))
#     167
#     168     first_lead_loop = True
#
# ~/anaconda3/envs/ninolearn/lib/python3.6/site-packages/xarray/backends/api.py in open_dataarray(filename_or_obj, group, decode_cf, mask_and_scale, decode_times, autoclose, concat_characters, decode_coords, engine, chunks, lock, cache, drop_variables, backend_kwargs, use_cftime, decode_timedelta)
#     685         backend_kwargs=backend_kwargs,
#     686         use_cftime=use_cftime,
# --> 687         decode_timedelta=decode_timedelta,
#     688     )
#     689
#
# ~/anaconda3/envs/ninolearn/lib/python3.6/site-packages/xarray/backends/api.py in open_dataset(filename_or_obj, group, decode_cf, mask_and_scale, decode_times, autoclose, concat_characters, decode_coords, engine, chunks, lock, cache, drop_variables, backend_kwargs, use_cftime, decode_timedelta)
#     507         if engine == "netcdf4":
#     508             store = backends.NetCDF4DataStore.open(
# --> 509                 filename_or_obj, group=group, lock=lock, **backend_kwargs
#     510             )
#     511         elif engine == "scipy":
#
# ~/anaconda3/envs/ninolearn/lib/python3.6/site-packages/xarray/backends/netCDF4_.py in open(cls, filename, mode, format, group, clobber, diskless, persist, lock, lock_maker, autoclose)
#     356             netCDF4.Dataset, filename, mode=mode, kwargs=kwargs
#     357         )
# --> 358         return cls(manager, group=group, mode=mode, lock=lock, autoclose=autoclose)
#     359
#     360     def _acquire(self, needs_lock=True):
#
# ~/anaconda3/envs/ninolearn/lib/python3.6/site-packages/xarray/backends/netCDF4_.py in __init__(self, manager, group, mode, lock, autoclose)
#     312         self._group = group
#     313         self._mode = mode
# --> 314         self.format = self.ds.data_model
#     315         self._filename = self.ds.filepath()
#     316         self.is_remote = is_remote_uri(self._filename)
#
# ~/anaconda3/envs/ninolearn/lib/python3.6/site-packages/xarray/backends/netCDF4_.py in ds(self)
#     365     @property
#     366     def ds(self):
# --> 367         return self._acquire()
#     368
#     369     def open_store_variable(self, name, var):
#
# ~/anaconda3/envs/ninolearn/lib/python3.6/site-packages/xarray/backends/netCDF4_.py in _acquire(self, needs_lock)
#     359
#     360     def _acquire(self, needs_lock=True):
# --> 361         with self._manager.acquire_context(needs_lock) as root:
#     362             ds = _nc4_require_group(root, self._group, self._mode)
#     363         return ds
#
# ~/anaconda3/envs/ninolearn/lib/python3.6/contextlib.py in __enter__(self)
#      79     def __enter__(self):
#      80         try:
# ---> 81             return next(self.gen)
#      82         except StopIteration:
#      83             raise RuntimeError("generator didn't yield") from None
#
# ~/anaconda3/envs/ninolearn/lib/python3.6/site-packages/xarray/backends/file_manager.py in acquire_context(self, needs_lock)
#     185     def acquire_context(self, needs_lock=True):
#     186         """Context manager for acquiring a file."""
# --> 187         file, cached = self._acquire_with_cache_info(needs_lock)
#     188         try:
#     189             yield file
#
# ~/anaconda3/envs/ninolearn/lib/python3.6/site-packages/xarray/backends/file_manager.py in _acquire_with_cache_info(self, needs_lock)
#     203                     kwargs = kwargs.copy()
#     204                     kwargs["mode"] = self._mode
# --> 205                 file = self._opener(*self._args, **kwargs)
#     206                 if self._mode == "w":
#     207                     # ensure file doesn't get overriden when opened again
#
# netCDF4/_netCDF4.pyx in netCDF4._netCDF4.Dataset.__init__()
#
# netCDF4/_netCDF4.pyx in netCDF4._netCDF4._ensure_nc_success()
#
# FileNotFoundError: [Errno 2] No such file or directory: b'/home/ivo/Documents/GitHub/ninolearn/research/ivo_thesis/data/processed/DEM_std_estimate.nc'
