# %% [markdown]
# # Deep ensemble for ENSO-forecasting
#
# In this tutorial you learn how to use a neural network model called Deep Ensemble (DE) for the ENSO forecasting. This network architecture was initially developed [Lakshminarayanan et al. (2017)](https://papers.nips.cc/paper/7219-simple-and-scalable-predictive-uncertainty-estimation-using-deep-ensembles.pdf).
#
# DEs are feed foreword neural networks that predict the mean and the standard deviation of a Gaussian. Hence, their predicion comes with an uncertainty estimation which is a valuable feature for ENSO-forecasting.

# %% [markdown]
# ## Create a data pipe line
#
# At first, we define a data pipeline. This is in general quite useful to keep your code clean and also to reuse the pipeline for later purpose.
#
# The data pipeline generates returns:
#
# 1. The feature array
#
# 2. The label array
#
# 3. The time  array corresponding to the time of the label
#
# NOTE (again): Lead time is defined as the time that passed between the last observed and the first date of the target season. Hence, negative appear, e.g. if you compare the DJF season with the target season JFM, you have a lead time of -2 month (Last observed date: Feburary 28/29, First date of the target season January 1).

# %%
from ninolearn.IO.read_processed import data_reader
from ninolearn.IO.read_raw import ZC_simple_read
import numpy as np
import pandas as pd

oneyear= pd.Timedelta(365, 'D')

# %%
version = 'mu39v3'
leadtime = 12

# t_start is defined using a funky timedelta because the starting date of the network analysis data is the last month
# of its start year which is 1951-12 therefore the time must start in 1952 with some months added for values lost in 
# interpolation. TODO: fix this by backwards interpolating the first values of the year and finding out what is happening 
# with the nms
times = np.unique(ZC_simple_read(version)['time'])

t_start = times[0] + pd.Timedelta((2*365 + 90),'D')
t_end = times[-1] - pd.Timedelta(90,'D')

print(f'tstart = {t_start} and tend = {t_end}')
# Out:
# tstart = 1952-04-07 14:17:30 and tend = 1994-08-26 03:33:20

# %%
from ninolearn.IO.read_raw import ZC_raw, ZC_h, ZC_oni
from ninolearn.preprocess.prepare import prep_nms
from ninolearn.plot.ZC_dem_plots import nms_plots
## read raw ZC data and save to 1x1 grid file in processeddir
## also makes field of h and sst
ZC_raw(version)

## calculates monthly averaged (?) fields of thermocline height within region 
## of interest. cacluate ONI in region of interest. calculate network metrics 
## from sst (Henk's suggestion) or thermocline height (like Paul)
ZC_h(version) 
ZC_oni(version)
prep_nms(version, 0.99, t_start, t_end)

# make plots
nms_plots(version)
# Out:
# using dimensions ('lat', 'lon') from data variable temperature as the horizontal dimensions for this dataset.
# /home/ivo/anaconda3/envs/ninolearn/lib/python3.6/site-packages/xesmf/frontend.py:524: FutureWarning: ``output_sizes`` should be given in the ``dask_gufunc_kwargs`` parameter. It will be removed as direct parameter in a future version.
#   keep_attrs=keep_attrs
# /home/ivo/anaconda3/envs/ninolearn/lib/python3.6/site-packages/xesmf/smm.py:93: UserWarning: Input array is not C_CONTIGUOUS. Will affect performance.
#   warnings.warn("Input array is not C_CONTIGUOUS. "
# - Read sst climatetology
# using dimensions ('lat', 'lon') from data variable temperature as the horizontal dimensions for this dataset.
# /home/ivo/anaconda3/envs/ninolearn/lib/python3.6/site-packages/xesmf/frontend.py:524: FutureWarning: ``output_sizes`` should be given in the ``dask_gufunc_kwargs`` parameter. It will be removed as direct parameter in a future version.
#   keep_attrs=keep_attrs
# WARNING:c2 variable equal to 0!
# WARNING:Wrong input for computation of hamming distance.
# WARNING:Wrong input for computation of corrected hamming distance.
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!

# %%
reader = data_reader(startdate=(t_start + pd.Timedelta(365,'D')) , enddate=(t_end - pd.Timedelta(2*365, 'D')) , lon_min = 124, lon_max = 280,
                         lat_min = -19, lat_max = 19)

oni = reader.read_csv(('oni_ZC_' +version))
h = reader.read_csv(('h_mean_ZC_' + version))

network_ssh = reader.read_statistic('network_metrics', variable='sst', dataset=('ZC_25x25_' + version), processed="anom")
c2 = network_ssh['fraction_clusters_size_2']
H = network_ssh['corrected_hamming_distance']

# %%
if h.shape[0] + c2.shape[0] - H.shape[0] - oni.shape[0] == 0:
    print('All datasets are of equal length')
# Out:
# All datasets are of equal length

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler

from ninolearn.utils import include_time_lag
from ninolearn.IO.read_processed import data_reader


def pipeline(lead_time):
    """
    Data pipeline for the processing of the data before the Deep Ensemble
    is trained.

    :type lead_time: int
    :param lead_time: The lead time in month.

    :returns: The feature "X" (at observation time), the label "y" (at lead
    time), the target season "timey" (least month)
    """
#     reader = data_reader(startdate='1952-01', enddate='1992-12', lon_min = 124, lon_max = 280,
#                          lat_min = -19, lat_max = 19)
    reader = data_reader(startdate=(t_start + oneyear), enddate=(t_end - 2*oneyear), lon_min = 124, lon_max = 280,
                         lat_min = -19, lat_max = 19)

    # indeces
    oni = reader.read_csv(('oni_ZC_' +version))
    h = reader.read_csv(('h_mean_ZC_' + version))
    #IOD unavailable in ZC87 model 
    
    # seasonal cycle
    sc = np.cos(np.arange(len(oni))/12*2*np.pi)

    # network metrics
    network_ssh = reader.read_statistic('network_metrics', variable='sst', dataset=('ZC_25x25_'+version), processed="anom")
    c2 = network_ssh['fraction_clusters_size_2']
    H = network_ssh['corrected_hamming_distance']

    # time lag
    time_lag = 12

    # shift such that lead time corresponds to the definition of lead time
    shift = 3

    # process features
    feature_unscaled = np.stack((oni, h,
                                 c2, H), axis=1)

    # scale each feature
    scalerX = StandardScaler()
    Xorg = scalerX.fit_transform(feature_unscaled)

    # set nans to 0.
    Xorg = np.nan_to_num(Xorg)

    # arange the feature array
    X = Xorg[:-lead_time-shift,:] # this chops of a bit at the end because matching labels will be offset by 
    # this amount. e.g. if our data runs until 2012 we need to remove X values for 2012 because we will use december 2011
    # to predict december 2012 
    
#     X = include_time_lag(X, max_lag=time_lag)
    X = include_time_lag(X, n_lags =time_lag)  # staggers the data with 1 month shifts so at each moment of input also
    # nlags amount of months before is available to the AI

    # arange label
    yorg = oni.values
    y = yorg[lead_time + time_lag + shift:] # labels offset by lead_time to predict into the future and time_lag 
    # because the include_time_lag function shifts X values forward by an amount n_lags=time_lag

    # get the time axis of the label
    timey = oni.index[lead_time + time_lag + shift:]

    return X, y, timey

# %% [markdown]
# ## Split the data set
#
# For the training and testing of machine learning models it is crucial to split the data set into:
#
# 1. __Train data set__ which is used to train the weights of the neural network
#
# 2. __Validation data set__ which is used to check for overfitting (e.g. when using early stopping) and to optimize the hyperparameters
#
# 3. __Test data set__ which is used to to evaluate the trained model.
#
# __NOTE:__ It is important to understand that hyperparamters must be tuned so that the result is best for the Validation data set and __not__ for the test data set. Otherwise you can not rule out the case that the specific hyperparameter setting just works good for the specific test data set but is not generally a good hyperparameter setting.
#
# In the following cell the train and the validation data set are still one data set, because this array will be later splitted into two arrays when th model is fitted.

# %%
import keras.backend as K
from ninolearn.learn.models.dem import DEM

# clear memory from previous sessions
K.clear_session()

# define the lead time
lead_time = leadtime

# get the features (X), the label (y) and 
# the time axis of the label (timey)
X, y, timey = pipeline(lead_time)

# split the data set into 
# test_indeces = (timey>='1987-01-01') & (timey<='1993-12-01')
test_indeces = (timey>=t_end - pd.Timedelta(5*365, 'D')) & (timey<=t_end)

train_val_indeces = np.invert(test_indeces)

train_val_X, train_val_y, train_val_timey = X[train_val_indeces,:], y[train_val_indeces], timey[train_val_indeces]
testX, testy, testtimey = X[test_indeces,:], y[test_indeces], timey[test_indeces]

# %%
print(y.shape, X.shape, timey.shape)
print('shapes of the data, labels and time axis is predictable, since there are now 4 features and 12 lags \
    making for 48 columns. The labels are offset from the input data by the lead time ')
# Out:
# (445,) (445, 48) (445,)
# shapes of the data, labels and time axis is predictable, since there are now 4 features and 12 lags     making for 48 columns. The labels are offset from the input data by the lead time

# %% [markdown]
# ## Fit the model
#
# Now it is time to train the model! For this a random search is used for all keyword arguments that are passed in a *list* to the DEM.set_parameters() method.

# %%
# initiated an instance of the DEM (Deep Ensemble Model) class
model = DEM()

# Set parameters
model.set_hyperparameters(searchtype='linear', layers=1, neurons=16, dropout=[0.1, 0.5], noise_in=[0.1,0.5], noise_sigma=[0.1,0.5],
                     noise_mu=[0.1,0.5], l1_hidden=[0.0, 0.2], l2_hidden=[0., 0.2],
                     l1_mu=[0.0, 0.2], l2_mu=[0.0, 0.2], l1_sigma=[0.0, 0.2],
                     l2_sigma=[0.0, 0.2], lr=[0.0001,0.01], batch_size=100, epochs=500, n_segments=5,
                     n_members_segment=1, patience=30, verbose=0, pdf='normal', activation = 'relu')

# Use a random search to find the optimal hyperparameters

model.fit_RandomizedSearch(train_val_X, train_val_y, train_val_timey, n_iter=20)
# Out:
# Search iteration Nr 1/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00045: early stopping
# 3/3 [==============================] - 0s 7ms/step - loss: 7.1185 - nll_gaussian: 0.9287
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00048: early stopping
# 3/3 [==============================] - 0s 2ms/step - loss: 8.3718 - nll_gaussian: 0.4106
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00050: early stopping
# 3/3 [==============================] - 0s 3ms/step - loss: 7.1523 - nll_gaussian: 0.2194
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00061: early stopping
# 3/3 [==============================] - 0s 2ms/step - loss: 13.9409 - nll_gaussian: 0.4487
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00047: early stopping
# 3/3 [==============================] - 0s 42ms/step - loss: 8.0905 - nll_gaussian: 0.5128
# Loss: 0.5040226995944976
# Computation time: 78.0s
# New best hyperparameters
# Mean loss: 0.5040226995944976
# {'layers': 1, 'neurons': 16, 'dropout': 0.22358842114247446, 'noise_in': 0.2644183996938484, 'noise_sigma': 0.33679040219775064, 'noise_mu': 0.49954188147350354, 'l1_hidden': 0.1355112401449005, 'l2_hidden': 0.16114080262858785, 'l1_mu': 0.030494956412753817, 'l2_mu': 0.17429509762427634, 'l1_sigma': 0.10602656333110705, 'l2_sigma': 0.07631141166694842, 'lr': 0.009293580272953121, 'batch_size': 100, 'epochs': 500, 'n_segments': 5, 'n_members_segment': 1, 'patience': 30, 'verbose': 0, 'pdf': 'normal', 'activation': 'relu', 'n_members': 5}
# Search iteration Nr 2/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00071: early stopping
# 3/3 [==============================] - 0s 2ms/step - loss: 1.6816 - nll_gaussian: 0.8244
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00057: early stopping
# 3/3 [==============================] - 0s 4ms/step - loss: 1.4518 - nll_gaussian: 0.6806
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00032: early stopping
# 3/3 [==============================] - 0s 10ms/step - loss: 1.7756 - nll_gaussian: 1.3195
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00055: early stopping
# 3/3 [==============================] - 0s 4ms/step - loss: 1.7391 - nll_gaussian: 1.0560
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00094: early stopping
# 3/3 [==============================] - 0s 3ms/step - loss: 1.5123 - nll_gaussian: 0.4639
# Loss: 0.8688885390758514
# Computation time: 90.8s
# Search iteration Nr 3/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00134: early stopping
# 3/3 [==============================] - 0s 13ms/step - loss: 1.2037 - nll_gaussian: 0.3736
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00134: early stopping
# 3/3 [==============================] - 0s 2ms/step - loss: 1.2781 - nll_gaussian: 0.2638
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00080: early stopping
# 3/3 [==============================] - 0s 3ms/step - loss: 1.0379 - nll_gaussian: 0.1898
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00100: early stopping
# 3/3 [==============================] - 0s 3ms/step - loss: 1.3582 - nll_gaussian: 0.4114
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00072: early stopping
# 3/3 [==============================] - 0s 7ms/step - loss: 1.6254 - nll_gaussian: 0.2874
# Loss: 0.30520492494106294
# Computation time: 130.8s
# New best hyperparameters
# Mean loss: 0.30520492494106294
# {'layers': 1, 'neurons': 16, 'dropout': 0.39848636623011924, 'noise_in': 0.33988719697377917, 'noise_sigma': 0.2243404119089424, 'noise_mu': 0.14681379691884422, 'l1_hidden': 0.044035960113517694, 'l2_hidden': 0.19671990584620558, 'l1_mu': 0.1711805525257014, 'l2_mu': 0.05723761704017687, 'l1_sigma': 0.045254905534319594, 'l2_sigma': 0.03857985998177696, 'lr': 0.0040585310232726145, 'batch_size': 100, 'epochs': 500, 'n_segments': 5, 'n_members_segment': 1, 'patience': 30, 'verbose': 0, 'pdf': 'normal', 'activation': 'relu', 'n_members': 5}
# Search iteration Nr 4/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00073: early stopping
# 3/3 [==============================] - 0s 5ms/step - loss: 4.3313 - nll_gaussian: 1.7198
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00070: early stopping
# 3/3 [==============================] - 0s 22ms/step - loss: 3.7274 - nll_gaussian: 1.2254
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00173: early stopping
# 3/3 [==============================] - 0s 3ms/step - loss: 4.6208 - nll_gaussian: 0.5613
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00093: early stopping
# 3/3 [==============================] - 0s 6ms/step - loss: 4.1866 - nll_gaussian: 1.1926
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00052: early stopping
# 3/3 [==============================] - 0s 11ms/step - loss: 4.3011 - nll_gaussian: 1.6874
# Loss: 1.2772978663444519
# Computation time: 135.6s
# Search iteration Nr 5/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00046: early stopping
# 3/3 [==============================] - 0s 8ms/step - loss: 3.2048 - nll_gaussian: 0.6953
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00060: early stopping
# 3/3 [==============================] - 0s 5ms/step - loss: 3.9447 - nll_gaussian: 0.2535
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00035: early stopping
# 3/3 [==============================] - 0s 4ms/step - loss: 2.6933 - nll_gaussian: 0.3207
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00044: early stopping
# 3/3 [==============================] - 0s 2ms/step - loss: 2.7824 - nll_gaussian: 0.4663
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00043: early stopping
# 3/3 [==============================] - 0s 4ms/step - loss: 2.1801 - nll_gaussian: 0.2934
# Loss: 0.4058426558971405
# Computation time: 84.6s
# Search iteration Nr 6/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00039: early stopping
# 3/3 [==============================] - 0s 2ms/step - loss: 1.3864 - nll_gaussian: 1.0385
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00038: early stopping
# 3/3 [==============================] - 0s 1ms/step - loss: 1.2166 - nll_gaussian: 0.7555
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00037: early stopping
# 3/3 [==============================] - 0s 12ms/step - loss: 1.2725 - nll_gaussian: 0.7453
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00040: early stopping
# 3/3 [==============================] - 0s 5ms/step - loss: 1.3330 - nll_gaussian: 0.9203
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00040: early stopping
# 3/3 [==============================] - 0s 3ms/step - loss: 1.2977 - nll_gaussian: 0.9251
# Loss: 0.8769398212432862
# Computation time: 82.9s
# Search iteration Nr 7/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00077: early stopping
# 3/3 [==============================] - 0s 2ms/step - loss: 9.5530 - nll_gaussian: 0.9820
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00059: early stopping
# 3/3 [==============================] - 0s 2ms/step - loss: 8.3697 - nll_gaussian: 0.5063
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00060: early stopping
# 3/3 [==============================] - 0s 2ms/step - loss: 10.4041 - nll_gaussian: 0.6175
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00125: early stopping
# 3/3 [==============================] - 0s 7ms/step - loss: 16.3425 - nll_gaussian: 0.4829
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00077: early stopping
# 3/3 [==============================] - 0s 4ms/step - loss: 9.8422 - nll_gaussian: 0.5224
# Loss: 0.6222091019153595
# Computation time: 130.5s
# Search iteration Nr 8/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00120: early stopping
# 3/3 [==============================] - 0s 2ms/step - loss: 5.3247 - nll_gaussian: 0.5989
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00125: early stopping
# 3/3 [==============================] - 0s 2ms/step - loss: 6.7631 - nll_gaussian: 0.4156
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00062: early stopping
# 3/3 [==============================] - 0s 8ms/step - loss: 4.6699 - nll_gaussian: 0.9522
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00179: early stopping
# 3/3 [==============================] - 0s 3ms/step - loss: 7.0435 - nll_gaussian: 0.6277
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00082: early stopping
# 3/3 [==============================] - 0s 5ms/step - loss: 5.2071 - nll_gaussian: 0.3210
# Loss: 0.583069133758545
# Computation time: 158.8s
# Search iteration Nr 9/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00073: early stopping
# 3/3 [==============================] - 0s 2ms/step - loss: 0.4646 - nll_gaussian: -0.0072
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00075: early stopping
# 3/3 [==============================] - 0s 4ms/step - loss: 0.4547 - nll_gaussian: -0.1379
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00076: early stopping
# 3/3 [==============================] - 0s 4ms/step - loss: 0.4533 - nll_gaussian: -0.1498
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00059: early stopping
# 3/3 [==============================] - 0s 15ms/step - loss: 0.9770 - nll_gaussian: 0.2854
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00071: early stopping
# 3/3 [==============================] - 0s 4ms/step - loss: 0.4823 - nll_gaussian: -0.0696
# Loss: -0.015828312933444978
# Computation time: 114.5s
# New best hyperparameters
# Mean loss: -0.015828312933444978
# {'layers': 1, 'neurons': 16, 'dropout': 0.11587380939134545, 'noise_in': 0.4539383153389416, 'noise_sigma': 0.1017393095641475, 'noise_mu': 0.2217697189451797, 'l1_hidden': 0.08005203944651534, 'l2_hidden': 0.08107514861775228, 'l1_mu': 0.12523723276346618, 'l2_mu': 0.040953984678998315, 'l1_sigma': 0.030948320472243607, 'l2_sigma': 0.06409253778958471, 'lr': 0.00556541398440512, 'batch_size': 100, 'epochs': 500, 'n_segments': 5, 'n_members_segment': 1, 'patience': 30, 'verbose': 0, 'pdf': 'normal', 'activation': 'relu', 'n_members': 5}
# Search iteration Nr 10/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00195: early stopping
# 3/3 [==============================] - 0s 22ms/step - loss: 0.8475 - nll_gaussian: 0.3804
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00161: early stopping
# 3/3 [==============================] - 0s 3ms/step - loss: 0.7570 - nll_gaussian: 0.1582
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00255: early stopping
# 3/3 [==============================] - 0s 2ms/step - loss: 0.7047 - nll_gaussian: 0.2730
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00222: early stopping
# 3/3 [==============================] - 0s 4ms/step - loss: 1.1533 - nll_gaussian: 0.5774
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00168: early stopping
# 3/3 [==============================] - 0s 6ms/step - loss: 0.8407 - nll_gaussian: 0.2790
# Loss: 0.33359933495521543
# Computation time: 241.4s
# Search iteration Nr 11/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00166: early stopping
# 3/3 [==============================] - 0s 7ms/step - loss: 0.7375 - nll_gaussian: 0.1244
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00172: early stopping
# 3/3 [==============================] - 0s 3ms/step - loss: 0.5920 - nll_gaussian: 0.0608
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00143: early stopping
# 3/3 [==============================] - 0s 3ms/step - loss: 0.6300 - nll_gaussian: 0.0804
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00105: early stopping
# 3/3 [==============================] - 0s 2ms/step - loss: 1.1227 - nll_gaussian: 0.4505
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00235: early stopping
# 3/3 [==============================] - 0s 9ms/step - loss: 0.8182 - nll_gaussian: 0.0530
# Loss: 0.15382089018821715
# Computation time: 200.9s
# Search iteration Nr 12/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00049: early stopping
# 3/3 [==============================] - 0s 5ms/step - loss: 8.3162 - nll_gaussian: 0.8790
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00053: early stopping
# 3/3 [==============================] - 0s 3ms/step - loss: 9.0767 - nll_gaussian: 0.5440
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00046: early stopping
# 3/3 [==============================] - 0s 3ms/step - loss: 7.5148 - nll_gaussian: 0.6599
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00057: early stopping
# 3/3 [==============================] - 0s 6ms/step - loss: 7.1548 - nll_gaussian: 0.7269
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00031: early stopping
# 3/3 [==============================] - 0s 2ms/step - loss: 5.8550 - nll_gaussian: 2.3361
# Loss: 1.0291535973548889
# Computation time: 92.4s
# Search iteration Nr 13/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00092: early stopping
# 3/3 [==============================] - 0s 3ms/step - loss: 4.4259 - nll_gaussian: 0.6373
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00153: early stopping
# 3/3 [==============================] - 0s 2ms/step - loss: 5.5813 - nll_gaussian: 0.4408
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00061: early stopping
# 3/3 [==============================] - 0s 1ms/step - loss: 4.3589 - nll_gaussian: 0.4419
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00169: early stopping
# 3/3 [==============================] - 0s 3ms/step - loss: 5.8590 - nll_gaussian: 0.5355
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00093: early stopping
# 3/3 [==============================] - 0s 3ms/step - loss: 5.2874 - nll_gaussian: 0.3602
# Loss: 0.4831466913223267
# Computation time: 136.1s
# Search iteration Nr 14/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00032: early stopping
# 3/3 [==============================] - 0s 5ms/step - loss: 2.6746 - nll_gaussian: 2.4940
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00068: early stopping
# 3/3 [==============================] - 0s 14ms/step - loss: 1.6349 - nll_gaussian: 1.2980
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00175: early stopping
# 3/3 [==============================] - 0s 6ms/step - loss: 1.6470 - nll_gaussian: 1.3214
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00090: early stopping
# 3/3 [==============================] - 0s 7ms/step - loss: 2.2849 - nll_gaussian: 1.8961
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00034: early stopping
# 3/3 [==============================] - 0s 3ms/step - loss: 2.4533 - nll_gaussian: 2.0362
# Loss: 1.8091292142868043
# Computation time: 84.6s
# Search iteration Nr 15/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00039: early stopping
# 3/3 [==============================] - 0s 3ms/step - loss: 2.5420 - nll_gaussian: 0.3283
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00080: early stopping
# 3/3 [==============================] - 0s 9ms/step - loss: 4.0478 - nll_gaussian: 0.2741
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00038: early stopping
# 3/3 [==============================] - 0s 6ms/step - loss: 2.9192 - nll_gaussian: 0.3406
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00048: early stopping
# 3/3 [==============================] - 0s 6ms/step - loss: 3.6462 - nll_gaussian: 0.4783
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00061: early stopping
# 3/3 [==============================] - 0s 5ms/step - loss: 3.2766 - nll_gaussian: 0.3410
# Loss: 0.3524749457836151
# Computation time: 68.0s
# Search iteration Nr 16/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00152: early stopping
# 3/3 [==============================] - 0s 8ms/step - loss: 3.2689 - nll_gaussian: 1.6394
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00074: early stopping
# 3/3 [==============================] - 0s 7ms/step - loss: 2.4643 - nll_gaussian: 1.1461
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00088: early stopping
# 3/3 [==============================] - 0s 6ms/step - loss: 2.5037 - nll_gaussian: 1.1879
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00121: early stopping
# 3/3 [==============================] - 0s 3ms/step - loss: 2.9637 - nll_gaussian: 1.6133
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00094: early stopping
# 3/3 [==============================] - 0s 1ms/step - loss: 3.0804 - nll_gaussian: 1.5964
# Loss: 1.436631941795349
# Computation time: 101.2s
# Search iteration Nr 17/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00040: early stopping
# 3/3 [==============================] - 0s 5ms/step - loss: 4.1573 - nll_gaussian: 0.6395
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00082: early stopping
# 3/3 [==============================] - 0s 3ms/step - loss: 4.2048 - nll_gaussian: 0.2455
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00050: early stopping
# 3/3 [==============================] - 0s 6ms/step - loss: 3.7756 - nll_gaussian: 0.2326
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00034: early stopping
# 3/3 [==============================] - 0s 3ms/step - loss: 3.8553 - nll_gaussian: 1.8164
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00055: early stopping
# 3/3 [==============================] - 0s 1ms/step - loss: 4.8299 - nll_gaussian: 0.6384
# Loss: 0.7144825369119644
# Computation time: 56.7s
# Search iteration Nr 18/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00279: early stopping
# 3/3 [==============================] - 0s 6ms/step - loss: 0.9802 - nll_gaussian: 0.2258
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00259: early stopping
# 3/3 [==============================] - 0s 6ms/step - loss: 0.7149 - nll_gaussian: 0.0631
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00183: early stopping
# 3/3 [==============================] - 0s 8ms/step - loss: 0.8046 - nll_gaussian: 0.0580
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00211: early stopping
# 3/3 [==============================] - 0s 2ms/step - loss: 1.1222 - nll_gaussian: 0.4763
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00313: early stopping
# 3/3 [==============================] - 0s 2ms/step - loss: 0.7405 - nll_gaussian: 0.1756
# Loss: 0.19977544173598288
# Computation time: 213.1s
# Search iteration Nr 19/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00164: early stopping
# 3/3 [==============================] - 0s 6ms/step - loss: 0.9244 - nll_gaussian: 0.4859
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00043: early stopping
# 3/3 [==============================] - 0s 6ms/step - loss: 1.1444 - nll_gaussian: 0.6983
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00044: early stopping
# 3/3 [==============================] - 0s 3ms/step - loss: 1.1258 - nll_gaussian: 0.6815
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00111: early stopping
# 3/3 [==============================] - 0s 2ms/step - loss: 1.1267 - nll_gaussian: 0.4526
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00042: early stopping
# 3/3 [==============================] - 0s 2ms/step - loss: 1.3640 - nll_gaussian: 0.8523
# Loss: 0.6341390907764435
# Computation time: 78.8s
# Search iteration Nr 20/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00046: early stopping
# 3/3 [==============================] - 0s 7ms/step - loss: 3.5340 - nll_gaussian: 2.3069
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00060: early stopping
# 3/3 [==============================] - 0s 2ms/step - loss: 2.6953 - nll_gaussian: 0.7927
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00073: early stopping
# 3/3 [==============================] - 0s 4ms/step - loss: 2.9934 - nll_gaussian: 0.7248
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00074: early stopping
# 3/3 [==============================] - 0s 3ms/step - loss: 4.3318 - nll_gaussian: 1.7873
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00258: early stopping
# 3/3 [==============================] - 0s 5ms/step - loss: 4.6720 - nll_gaussian: 0.3713
# Loss: 1.1966102600097657
# Computation time: 96.1s
# Refit the model with best hyperparamters
# {'layers': 1, 'neurons': 16, 'dropout': 0.11587380939134545, 'noise_in': 0.4539383153389416, 'noise_sigma': 0.1017393095641475, 'noise_mu': 0.2217697189451797, 'l1_hidden': 0.08005203944651534, 'l2_hidden': 0.08107514861775228, 'l1_mu': 0.12523723276346618, 'l2_mu': 0.040953984678998315, 'l1_sigma': 0.030948320472243607, 'l2_sigma': 0.06409253778958471, 'lr': 0.00556541398440512, 'batch_size': 100, 'epochs': 500, 'n_segments': 5, 'n_members_segment': 1, 'patience': 30, 'verbose': 0, 'pdf': 'normal', 'activation': 'relu', 'n_members': 5}
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00071: early stopping
# 3/3 [==============================] - 0s 8ms/step - loss: 0.5889 - nll_gaussian: -0.0124
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00104: early stopping
# 3/3 [==============================] - 0s 5ms/step - loss: 0.4367 - nll_gaussian: -0.1443
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00126: early stopping
# 3/3 [==============================] - 0s 6ms/step - loss: 0.4406 - nll_gaussian: -0.1362
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00059: early stopping
# 3/3 [==============================] - 0s 2ms/step - loss: 1.0040 - nll_gaussian: 0.3305
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00125: early stopping
# 3/3 [==============================] - 0s 5ms/step - loss: 0.4294 - nll_gaussian: -0.0630
# Loss: -0.005057673156261444
# Computation time: 109.9s
# best loss search: -0.015828312933444978
# loss refitting : -0.005057673156261444

# %% [markdown]
# ## Make predictions for the test data set
# Now we can use the trained models to make predicitons on the test data set to evaluate how good the model perfoms on a data set that it never saw before.

# %%
pred_mean, pred_std = model.predict(testX)

# %%
# from ninolearn.learn.fit import cross_hindcast_dem, cross_hindcast
# cross_hindcast(model, pipeline, 'DEM')
# # cross_hindcast_dem(model, pipeline, 'DEM')

# %% [markdown]
# ## Plot the prediction
# Let's see how the predicion is looking like

# %%
import matplotlib.pyplot as plt
from ninolearn.plot.prediction import plot_prediction
import pandas as pd
from ninolearn.pathes import plotdir

from os.path import join


plt.subplots(figsize=(15,3.5))
plt.axhspan(-0.5,
            -6,
            facecolor='blue',
            alpha=0.1,zorder=0)

plt.axhspan(0.5,
            6,
            facecolor='red',
            alpha=0.1,zorder=0)

plt.xlim(testtimey[0], testtimey[-1])
plt.ylim(-3,3)

# plot the prediction
plot_prediction(testtimey, pred_mean, std=pred_std, facecolor='royalblue', line_color='navy')

# plot the observation
plt.plot(timey, y, "r", label = 'observation')
plt.legend()

plt.savefig(join(plotdir, f'predicVSobs_{version}_{lead_time}lead'))

plt.show()

# %% [markdown]
# ## Evaluate the model
#
# We can evaluate the model a bit more quantitatively using the loss function that was used to train the model, namely the negative-log-likelihood of the Gaussian and the correlation between the predicted mean and the observed ONI index.

# %%
from ninolearn.plot.evaluation import plot_correlation, plot_confMat, plot_seasonal_skill

loss = model.evaluate(testy, pred_mean, pred_std)
print(f"Loss (Negative-Log-Likelihood): {loss}")

# make a plot of the seasonal correaltion
# note: - pd.tseries.offsets.MonthBegin(1) appears to ensure that the correlations are plotted
# agains the correct season
plot_correlation(testy, pred_mean, testtimey - pd.tseries.offsets.MonthBegin(1), title="")

# plot_seasonal_skill(leadtime, r_seas)

# plt.savefig(join(plotdir, f'correlation_{version}_{lead_time}lead'))
# Out:
# Loss (Negative-Log-Likelihood): -0.04688064674716205

# %%
cross_hindcast_dem(model, pipeline, 'DEM')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-ca17ff52c8c9> in <module>
# ----> 1 cross_hindcast_dem(model, pipeline, 'DEM')
#
# NameError: name 'cross_hindcast_dem' is not defined

# %%
from ninolearn.learn.fit import n_decades, lead_times, decade_color, decade_name
from ninolearn.learn.evaluation import evaluation_correlation, evaluation_decadal_correlation, evaluation_seasonal_correlation
from ninolearn.learn.fit import cross_hindcast_dem

cross_hindcast_dem(model, pipeline, 'DEM')

r_seas, p_seas = evaluation_seasonal_correlation('DEM', variable_name='prediction')

plot_seasonal_skill(lead_times, r_seas,  vmin=0, vmax=1)
plt.contour(np.arange(1,13),lead_times, p_seas, levels=[0.01, 0.05, 0.1], linestyles=['solid', 'dashed', 'dotted'], colors='k')
plt.title('Correlation skill')
plt.tight_layout()
