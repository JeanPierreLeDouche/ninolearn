# %% [markdown]
# # Deep ensemble for ENSO-forecasting
#
# In this tutorial you learn how to use a neural network model called Deep Ensemble (DE) for the ENSO forecasting. This network architecture was initially developed [Lakshminarayanan et al. (2017)](https://papers.nips.cc/paper/7219-simple-and-scalable-predictive-uncertainty-estimation-using-deep-ensembles.pdf).
#
# DEs are feed foreword neural networks that predict the mean and the standard deviation of a Gaussian. Hence, their predicion comes with an uncertainty estimation which is a valuable feature for ENSO-forecasting.

# %% [markdown]
# ## Create a data pipe line
#
# At first, we define a data pipeline. This is in general quite useful to keep your code clean and also to reuse the pipeline for later purpose.
#
# The data pipeline generates returns:
#
# 1. The feature array
#
# 2. The label array
#
# 3. The time  array corresponding to the time of the label
#
# NOTE (again): Lead time is defined as the time that passed between the last observed and the first date of the target season. Hence, negative appear, e.g. if you compare the DJF season with the target season JFM, you have a lead time of -2 month (Last observed date: Feburary 28/29, First date of the target season January 1).

# %%
from ninolearn.IO.read_processed import data_reader
from ninolearn.IO.read_raw import ZC_simple_read
from ninolearn.utils import include_time_lag

import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler

oneyear= pd.Timedelta(365, 'D')

# %%
version = 'mu27_2'
leadtime = 24

# t_start is defined using a funky timedelta because the starting date of the network analysis data is the last month
# of its start year which is 1951-12 therefore the time must start in 1952 with some months added for values lost in 
# interpolation. TODO: fix this by backwards interpolating the first values of the year and finding out what is happening 
# with the nms
times = np.unique(ZC_simple_read(version)['time'])

t_start = times[0] + pd.Timedelta((2*365 + 90),'D')
t_end = times[-1] - pd.Timedelta(90,'D')

print(f'tstart = {t_start} and tend = {t_end}')
# Out:
# tstart = 1952-04-15 04:35:00 and tend = 1970-01-04 00:46:40

# %%
from ninolearn.IO.read_raw import ZC_raw, ZC_h, ZC_oni
from ninolearn.preprocess.prepare import prep_nms
from ninolearn.plot.ZC_dem_plots import nms_plots
## read raw ZC data and save to 1x1 grid file in processeddir
## also makes field of h and sst
ZC_raw(version)

## calculates monthly averaged (?) fields of thermocline height within region 
## of interest. cacluate ONI in region of interest. calculate network metrics 
## from sst (Henk's suggestion) or thermocline height (like Paul)
ZC_h(version) 
ZC_oni(version)
prep_nms(version, 0.99, t_start, t_end)

# make plots
nms_plots(version)
# Out:
# using dimensions ('lat', 'lon') from data variable temperature as the horizontal dimensions for this dataset.
# /home/ivo/anaconda3/envs/ninolearn/lib/python3.6/site-packages/xesmf/frontend.py:524: FutureWarning: ``output_sizes`` should be given in the ``dask_gufunc_kwargs`` parameter. It will be removed as direct parameter in a future version.
#   keep_attrs=keep_attrs
# /home/ivo/anaconda3/envs/ninolearn/lib/python3.6/site-packages/xesmf/smm.py:93: UserWarning: Input array is not C_CONTIGUOUS. Will affect performance.
#   warnings.warn("Input array is not C_CONTIGUOUS. "
# - Read sst climatetology
# using dimensions ('lat', 'lon') from data variable temperature as the horizontal dimensions for this dataset.
# /home/ivo/anaconda3/envs/ninolearn/lib/python3.6/site-packages/xesmf/frontend.py:524: FutureWarning: ``output_sizes`` should be given in the ``dask_gufunc_kwargs`` parameter. It will be removed as direct parameter in a future version.
#   keep_attrs=keep_attrs
# WARNING:Wrong input for computation of hamming distance.
# WARNING:Wrong input for computation of corrected hamming distance.
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!
# WARNING:c2 variable equal to 0!

# %%
reader = data_reader(startdate=(t_start + pd.Timedelta(365,'D')) , enddate=(t_end - pd.Timedelta(365, 'D')) , lon_min = 124, lon_max = 280,
                         lat_min = -19, lat_max = 19)

oni = reader.read_csv(('oni_ZC_' +version))
h = reader.read_csv(('h_mean_ZC_' + version))

network_ssh = reader.read_statistic('network_metrics', variable='sst', dataset=('ZC_25x25_' + version), processed="anom")
c2 = network_ssh['fraction_clusters_size_2']
H = network_ssh['corrected_hamming_distance']

# %%
stack = np.stack((oni,h), axis =1) # stack features
scaler = StandardScaler() #to normalize
org = scaler.fit_transform(stack) # normalize
print(org.shape)

lead_time = 12
shift =3
X = org[:-lead_time-shift,:]
lagged = include_time_lag(X, n_lags=12)
# Out:
# (189, 2)

# %%
print(lagged.shape)
print(X.shape)
# Out:
# (162, 24)
# (174, 2)

# %%
if h.shape[0] + c2.shape[0] - H.shape[0] - oni.shape[0] == 0:
    print('All datasets are of equal length')
# Out:
# All datasets are of equal length

# %%
def pipeline(lead_time):
    """
    Data pipeline for the processing of the data before the Deep Ensemble
    is trained.

    :type lead_time: int
    :param lead_time: The lead time in month.

    :returns: The feature "X" (at observation time), the label "y" (at lead
    time), the target season "timey" (least month)
    """
#     reader = data_reader(startdate='1952-01', enddate='1992-12', lon_min = 124, lon_max = 280,
#                          lat_min = -19, lat_max = 19)
    reader = data_reader(startdate=(t_start + oneyear), enddate=(t_end - oneyear), lon_min = 124, lon_max = 280,
                         lat_min = -19, lat_max = 19)

    # indeces
    oni = reader.read_csv(('oni_ZC_' +version))
    h = reader.read_csv(('h_mean_ZC_' + version))
    #IOD unavailable in ZC87 model 
    
    # seasonal cycle
    sc = np.cos(np.arange(len(oni))/12*2*np.pi)

    # network metrics
    network_ssh = reader.read_statistic('network_metrics', variable='sst', dataset=('ZC_25x25_'+version), processed="anom")
    c2 = network_ssh['fraction_clusters_size_2']
    H = network_ssh['corrected_hamming_distance']

    # time lag
    time_lag = 12

    # shift such that lead time corresponds to the definition of lead time
    shift = 3

    # process features
    feature_unscaled = np.stack((oni, h,
                                 c2, H), axis=1)

    # scale each feature
    scalerX = StandardScaler()
    Xorg = scalerX.fit_transform(feature_unscaled) #normalize

    # set nans to 0.
    Xorg = np.nan_to_num(Xorg) 

    # arange the feature array
    X = Xorg[:-lead_time-shift,:] # this excludes the last months based on the lag
#     X = include_time_lag(X, max_lag=time_lag)
    X = include_time_lag(X, n_lags =12) # (!) this is weird to me (IG)


    # arange label
    yorg = oni.values
    y = yorg[lead_time + time_lag + shift:]

    # get the time axis of the label
    timey = oni.index[lead_time + time_lag + shift:]

    return X, y, timey

# %% [markdown]
# ## Split the data set
#
# For the training and testing of machine learning models it is crucial to split the data set into:
#
# 1. __Train data set__ which is used to train the weights of the neural network
#
# 2. __Validation data set__ which is used to check for overfitting (e.g. when using early stopping) and to optimize the hyperparameters
#
# 3. __Test data set__ which is used to to evaluate the trained model.
#
# __NOTE:__ It is important to understand that hyperparamters must be tuned so that the result is best for the Validation data set and __not__ for the test data set. Otherwise you can not rule out the case that the specific hyperparameter setting just works good for the specific test data set but is not generally a good hyperparameter setting.
#
# In the following cell the train and the validation data set are still one data set, because this array will be later splitted into two arrays when th model is fitted.

# %%
import keras.backend as K
from ninolearn.learn.models.dem import DEM

# clear memory from previous sessions
K.clear_session()

# define the lead time
lead_time = leadtime

# get the features (X), the label (y) and 
# the time axis of the label (timey)
X, y, timey = pipeline(lead_time)

# split the data set into 
# test_indeces = (timey>='1987-01-01') & (timey<='1993-12-01')
test_indeces = (timey>=t_end - pd.Timedelta(5*365, 'D')) & (timey<=t_end)

train_val_indeces = np.invert(test_indeces)

train_val_X, train_val_y, train_val_timey = X[train_val_indeces,:], y[train_val_indeces], timey[train_val_indeces]
testX, testy, testtimey = X[test_indeces,:], y[test_indeces], timey[test_indeces]

# %% [markdown]
# ## Fit the model
#
# Now it is time to train the model! For this a random search is used for all keyword arguments that are passed in a *list* to the DEM.set_parameters() method.

# %%
# initiated an instance of the DEM (Deep Ensemble Model) class
model = DEM()

# Set parameters
model.set_hyperparameters(searchtype='linear', layers=1, neurons=16, dropout=[0.1, 0.5], noise_in=[0.1,0.5], noise_sigma=[0.1,0.5],
                     noise_mu=[0.1,0.5], l1_hidden=[0.0, 0.2], l2_hidden=[0., 0.2],
                     l1_mu=[0.0, 0.2], l2_mu=[0.0, 0.2], l1_sigma=[0.0, 0.2],
                     l2_sigma=[0.0, 0.2], lr=[0.0001,0.01], batch_size=100, epochs=500, n_segments=5,
                     n_members_segment=1, patience=30, verbose=0, pdf='normal', activation = 'relu')

# Use a random search to find the optimal hyperparameters

model.fit_RandomizedSearch(train_val_X, train_val_y, train_val_timey, n_iter=20)
# Out:
# Search iteration Nr 1/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00201: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 4.4304 - nll_gaussian: 0.1160
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00059: early stopping
# 1/1 [==============================] - 0s 2ms/step - loss: 3.7034 - nll_gaussian: 1.5081
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00145: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 3.3093 - nll_gaussian: 0.0355
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00115: early stopping
# 1/1 [==============================] - 0s 3ms/step - loss: 4.4304 - nll_gaussian: 1.0405
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00181: early stopping
# 1/1 [==============================] - 0s 958us/step - loss: 1.7338 - nll_gaussian: 0.0221
# Loss: 0.5444178570061922
# Computation time: 179.9s
# New best hyperparameters
# Mean loss: 0.5444178570061922
# {'layers': 1, 'neurons': 16, 'dropout': 0.35495817304294175, 'noise_in': 0.3879272046412916, 'noise_sigma': 0.23760234135620273, 'noise_mu': 0.3912956617498178, 'l1_hidden': 0.18275472435217707, 'l2_hidden': 0.122994133873255, 'l1_mu': 0.0658943160973741, 'l2_mu': 0.11859198242334479, 'l1_sigma': 0.14584907985565287, 'l2_sigma': 0.10659502943972538, 'lr': 0.004849082437943449, 'batch_size': 100, 'epochs': 500, 'n_segments': 5, 'n_members_segment': 1, 'patience': 30, 'verbose': 0, 'pdf': 'normal', 'activation': 'relu', 'n_members': 5}
# Search iteration Nr 2/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00139: early stopping
# 1/1 [==============================] - 0s 2ms/step - loss: 0.4787 - nll_gaussian: -0.2592
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00112: early stopping
# 1/1 [==============================] - 0s 10ms/step - loss: 1.1024 - nll_gaussian: 0.0936
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00119: early stopping
# 1/1 [==============================] - 0s 2ms/step - loss: 1.1894 - nll_gaussian: -0.1288
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00052: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 1.6832 - nll_gaussian: 0.4728
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00167: early stopping
# 1/1 [==============================] - 0s 3ms/step - loss: 1.2054 - nll_gaussian: -0.0567
# Loss: 0.024344341456890108
# Computation time: 146.7s
# New best hyperparameters
# Mean loss: 0.024344341456890108
# {'layers': 1, 'neurons': 16, 'dropout': 0.28759747984626527, 'noise_in': 0.12240975593658168, 'noise_sigma': 0.21332816811258756, 'noise_mu': 0.25501250690448646, 'l1_hidden': 0.060639858830684436, 'l2_hidden': 0.1122324719095858, 'l1_mu': 0.029682760056524527, 'l2_mu': 0.05415424313231554, 'l1_sigma': 0.03634717253656843, 'l2_sigma': 0.10015852072424446, 'lr': 0.007411519013098767, 'batch_size': 100, 'epochs': 500, 'n_segments': 5, 'n_members_segment': 1, 'patience': 30, 'verbose': 0, 'pdf': 'normal', 'activation': 'relu', 'n_members': 5}
# Search iteration Nr 3/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00180: early stopping
# 1/1 [==============================] - 0s 4ms/step - loss: 0.5063 - nll_gaussian: -0.1976
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00186: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 1.0072 - nll_gaussian: 0.4380
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00201: early stopping
# 1/1 [==============================] - 0s 2ms/step - loss: 0.3982 - nll_gaussian: -0.2521
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00163: early stopping
# 1/1 [==============================] - 0s 2ms/step - loss: 0.9050 - nll_gaussian: 0.0415
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00204: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 0.4082 - nll_gaussian: -0.2472
# Loss: -0.04347691610455513
# Computation time: 222.5s
# New best hyperparameters
# Mean loss: -0.04347691610455513
# {'layers': 1, 'neurons': 16, 'dropout': 0.15520357133905263, 'noise_in': 0.12084392925469, 'noise_sigma': 0.16099984666393963, 'noise_mu': 0.42510977039631515, 'l1_hidden': 0.06901759598853689, 'l2_hidden': 0.13552309676637664, 'l1_mu': 0.1455054247132231, 'l2_mu': 0.05505667379461006, 'l1_sigma': 0.12404854811252722, 'l2_sigma': 0.042701340037986604, 'lr': 0.00595830959908037, 'batch_size': 100, 'epochs': 500, 'n_segments': 5, 'n_members_segment': 1, 'patience': 30, 'verbose': 0, 'pdf': 'normal', 'activation': 'relu', 'n_members': 5}
# Search iteration Nr 4/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00121: early stopping
# 1/1 [==============================] - 0s 2ms/step - loss: 2.9164 - nll_gaussian: 0.6915
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00127: early stopping
# 1/1 [==============================] - 0s 4ms/step - loss: 4.0540 - nll_gaussian: 1.7449
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00049: early stopping
# 1/1 [==============================] - 0s 4ms/step - loss: 2.8066 - nll_gaussian: 0.9674
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00031: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 3.7077 - nll_gaussian: 1.8411
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00051: early stopping
# 1/1 [==============================] - 0s 5ms/step - loss: 3.2777 - nll_gaussian: 1.3311
# Loss: 1.3152230262756348
# Computation time: 124.4s
# Search iteration Nr 5/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00048: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 1.1800 - nll_gaussian: 0.7150
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00125: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 3.1320 - nll_gaussian: 2.6418
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00037: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 1.4741 - nll_gaussian: 0.9888
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00101: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 2.1624 - nll_gaussian: 1.6988
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00094: early stopping
# 1/1 [==============================] - 0s 2ms/step - loss: 1.6920 - nll_gaussian: 1.2365
# Loss: 1.4561874389648437
# Computation time: 118.2s
# Search iteration Nr 6/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00284: early stopping
# 1/1 [==============================] - 0s 3ms/step - loss: 0.7004 - nll_gaussian: -0.1371
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00224: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 1.5047 - nll_gaussian: 0.7339
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00106: early stopping
# 1/1 [==============================] - 0s 4ms/step - loss: 0.9706 - nll_gaussian: 0.2019
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00252: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 1.3354 - nll_gaussian: 0.3044
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# 1/1 [==============================] - 0s 2ms/step - loss: 1.2674 - nll_gaussian: 0.0010
# Loss: 0.22082504809368403
# Computation time: 329.5s
# Search iteration Nr 7/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00072: early stopping
# 1/1 [==============================] - 0s 3ms/step - loss: 3.4797 - nll_gaussian: 0.8557
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00032: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 5.2185 - nll_gaussian: 2.6295
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00150: early stopping
# 1/1 [==============================] - 0s 2ms/step - loss: 3.5183 - nll_gaussian: 0.8612
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00032: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 4.2743 - nll_gaussian: 1.7696
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00038: early stopping
# 1/1 [==============================] - 0s 5ms/step - loss: 3.9851 - nll_gaussian: 1.4506
# Loss: 1.513302206993103
# Computation time: 103.1s
# Search iteration Nr 8/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00102: early stopping
# 1/1 [==============================] - 0s 6ms/step - loss: 2.1660 - nll_gaussian: 0.1658
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00110: early stopping
# 1/1 [==============================] - 0s 4ms/step - loss: 2.8844 - nll_gaussian: 1.0500
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00073: early stopping
# 1/1 [==============================] - 0s 7ms/step - loss: 1.6609 - nll_gaussian: 0.2907
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00076: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 3.2133 - nll_gaussian: 1.1845
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00212: early stopping
# 1/1 [==============================] - 0s 2ms/step - loss: 2.9435 - nll_gaussian: 0.6943
# Loss: 0.6770770967006683
# Computation time: 163.0s
# Search iteration Nr 9/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00163: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 7.3860 - nll_gaussian: -0.2080
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00044: early stopping
# 1/1 [==============================] - 0s 969us/step - loss: 6.6714 - nll_gaussian: 2.2886
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00033: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 4.3351 - nll_gaussian: 0.9673
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00031: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 5.6020 - nll_gaussian: 1.8583
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00117: early stopping
# 1/1 [==============================] - 0s 2ms/step - loss: 6.4739 - nll_gaussian: 0.5152
# Loss: 1.0842699736356736
# Computation time: 108.5s
# Search iteration Nr 10/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# 1/1 [==============================] - 0s 2ms/step - loss: 1.4973 - nll_gaussian: -0.0543
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00145: early stopping
# 1/1 [==============================] - 0s 2ms/step - loss: 4.4099 - nll_gaussian: 2.2339
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00259: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 2.0986 - nll_gaussian: 0.5757
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00157: early stopping
# 1/1 [==============================] - 0s 2ms/step - loss: 3.5341 - nll_gaussian: 1.5879
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00416: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 2.0601 - nll_gaussian: 0.3640
# Loss: 0.9414405860006809
# Computation time: 281.0s
# Search iteration Nr 11/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00099: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 2.3898 - nll_gaussian: 0.3736
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00166: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 2.4546 - nll_gaussian: 0.5108
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00191: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 2.6109 - nll_gaussian: 0.0687
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00124: early stopping
# 1/1 [==============================] - 0s 2ms/step - loss: 3.5624 - nll_gaussian: 1.0472
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00107: early stopping
# 1/1 [==============================] - 0s 5ms/step - loss: 2.1715 - nll_gaussian: 0.0879
# Loss: 0.4176250517368317
# Computation time: 136.9s
# Search iteration Nr 12/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00103: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 2.6684 - nll_gaussian: 0.8323
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00087: early stopping
# 1/1 [==============================] - 0s 3ms/step - loss: 4.3934 - nll_gaussian: 2.6257
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00192: early stopping
# 1/1 [==============================] - 0s 2ms/step - loss: 2.6886 - nll_gaussian: 0.9009
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00255: early stopping
# 1/1 [==============================] - 0s 2ms/step - loss: 3.4381 - nll_gaussian: 1.6871
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00068: early stopping
# 1/1 [==============================] - 0s 2ms/step - loss: 3.1455 - nll_gaussian: 1.4017
# Loss: 1.4895305633544922
# Computation time: 97.7s
# Search iteration Nr 13/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00242: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 1.5785 - nll_gaussian: 0.5119
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00075: early stopping
# 1/1 [==============================] - 0s 2ms/step - loss: 3.3999 - nll_gaussian: 2.5150
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00106: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 1.7642 - nll_gaussian: 0.7898
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00058: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 2.5855 - nll_gaussian: 1.7143
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00109: early stopping
# 1/1 [==============================] - 0s 2ms/step - loss: 2.1449 - nll_gaussian: 1.1968
# Loss: 1.3455772161483766
# Computation time: 79.6s
# Search iteration Nr 14/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00210: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 2.8299 - nll_gaussian: 0.5775
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00031: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 4.4034 - nll_gaussian: 2.5738
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00116: early stopping
# 1/1 [==============================] - 0s 3ms/step - loss: 2.8797 - nll_gaussian: 0.8287
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00097: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 3.6006 - nll_gaussian: 1.5874
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00075: early stopping
# 1/1 [==============================] - 0s 871us/step - loss: 3.3804 - nll_gaussian: 1.3697
# Loss: 1.3874231696128845
# Computation time: 72.3s
# Search iteration Nr 15/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00106: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 3.2440 - nll_gaussian: 0.1396
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00032: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 4.2333 - nll_gaussian: 2.6782
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00091: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 3.3453 - nll_gaussian: 0.2047
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00059: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 3.6265 - nll_gaussian: 1.1956
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00215: early stopping
# 1/1 [==============================] - 0s 2ms/step - loss: 3.2700 - nll_gaussian: 0.1414
# Loss: 0.8719100534915925
# Computation time: 68.2s
# Search iteration Nr 16/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00109: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 0.4646 - nll_gaussian: -0.0978
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00106: early stopping
# 1/1 [==============================] - 0s 2ms/step - loss: 0.9902 - nll_gaussian: 0.4572
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00119: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 0.4463 - nll_gaussian: -0.1141
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00088: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 1.1135 - nll_gaussian: 0.4962
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00102: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 0.4238 - nll_gaussian: -0.0509
# Loss: 0.13810988739132882
# Computation time: 75.2s
# Search iteration Nr 17/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00205: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 3.0700 - nll_gaussian: 0.7379
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00188: early stopping
# 1/1 [==============================] - 0s 2ms/step - loss: 4.9496 - nll_gaussian: 2.5301
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00034: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 3.2561 - nll_gaussian: 0.9513
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00033: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 4.0985 - nll_gaussian: 1.7306
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00155: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 3.6094 - nll_gaussian: 1.2503
# Loss: 1.4400221467018128
# Computation time: 79.7s
# Search iteration Nr 18/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00062: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 5.4483 - nll_gaussian: 0.6687
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00145: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 8.2518 - nll_gaussian: 1.0584
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00054: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 4.8527 - nll_gaussian: 0.8366
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00090: early stopping
# 1/1 [==============================] - 0s 997us/step - loss: 6.3707 - nll_gaussian: 0.6348
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00064: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 5.2930 - nll_gaussian: 0.8849
# Loss: 0.8166607975959778
# Computation time: 41.1s
# Search iteration Nr 19/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00046: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 2.3149 - nll_gaussian: 0.8165
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00149: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 3.9471 - nll_gaussian: 2.1898
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00143: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 2.5351 - nll_gaussian: 0.9322
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00069: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 3.2714 - nll_gaussian: 1.7168
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00040: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 2.9666 - nll_gaussian: 1.4460
# Loss: 1.4202558040618896
# Computation time: 43.0s
# Search iteration Nr 20/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00100: early stopping
# 1/1 [==============================] - 0s 2ms/step - loss: 0.7884 - nll_gaussian: -0.0437
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00173: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 1.2116 - nll_gaussian: 0.6460
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00103: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 1.0224 - nll_gaussian: 0.0167
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00078: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 1.6862 - nll_gaussian: 1.1353
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00114: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 1.1484 - nll_gaussian: 0.2541
# Loss: 0.4016741197556257
# Computation time: 46.5s
# Refit the model with best hyperparamters
# {'layers': 1, 'neurons': 16, 'dropout': 0.15520357133905263, 'noise_in': 0.12084392925469, 'noise_sigma': 0.16099984666393963, 'noise_mu': 0.42510977039631515, 'l1_hidden': 0.06901759598853689, 'l2_hidden': 0.13552309676637664, 'l1_mu': 0.1455054247132231, 'l2_mu': 0.05505667379461006, 'l1_sigma': 0.12404854811252722, 'l2_sigma': 0.042701340037986604, 'lr': 0.00595830959908037, 'batch_size': 100, 'epochs': 500, 'n_segments': 5, 'n_members_segment': 1, 'patience': 30, 'verbose': 0, 'pdf': 'normal', 'activation': 'relu', 'n_members': 5}
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00155: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 0.4443 - nll_gaussian: -0.2295
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00178: early stopping
# 1/1 [==============================] - 0s 912us/step - loss: 0.9442 - nll_gaussian: 0.3781
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00173: early stopping
# 1/1 [==============================] - 0s 982us/step - loss: 0.4124 - nll_gaussian: -0.2432
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00088: early stopping
# 1/1 [==============================] - 0s 983us/step - loss: 1.3699 - nll_gaussian: 0.7470
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00179: early stopping
# 1/1 [==============================] - 0s 1ms/step - loss: 0.5055 - nll_gaussian: -0.1593
# Loss: 0.09861317873001099
# Computation time: 61.3s
# best loss search: -0.04347691610455513
# loss refitting : 0.09861317873001099

# %% [markdown]
# ## Make predictions for the test data set
# Now we can use the trained models to make predicitons on the test data set to evaluate how good the model perfoms on a data set that it never saw before.

# %%
pred_mean, pred_std = model.predict(testX)

# %% [markdown]
# ## Plot the prediction
# Let's see how the predicion is looking like

# %%
import matplotlib.pyplot as plt
from ninolearn.plot.prediction import plot_prediction
import pandas as pd
from ninolearn.pathes import plotdir

from os.path import join


plt.subplots(figsize=(15,3.5))
plt.axhspan(-0.5,
            -6,
            facecolor='blue',
            alpha=0.1,zorder=0)

plt.axhspan(0.5,
            6,
            facecolor='red',
            alpha=0.1,zorder=0)

plt.xlim(testtimey[0], testtimey[-1])
plt.ylim(-3,3)

# plot the prediction
plot_prediction(testtimey, pred_mean, std=pred_std, facecolor='royalblue', line_color='navy')

# plot the observation
plt.plot(timey, y, "r", label = 'observation')
plt.legend()

plt.savefig(join(plotdir, f'predicVSobs_{version}_{lead_time}lead'))

plt.show()

# %% [markdown]
# ## Evaluate the model
#
# We can evaluate the model a bit more quantitatively using the loss function that was used to train the model, namely the negative-log-likelihood of the Gaussian and the correlation between the predicted mean and the observed ONI index.

# %%
from ninolearn.plot.evaluation import plot_correlation

loss = model.evaluate(testy, pred_mean, pred_std)
print(f"Loss (Negative-Log-Likelihood): {loss}")

# make a plot of the seasonal correaltion
# note: - pd.tseries.offsets.MonthBegin(1) appears to ensure that the correlations are plotted
# agains the correct season
plot_correlation(testy, pred_mean, testtimey - pd.tseries.offsets.MonthBegin(1), title="")

plt.savefig(join(plotdir, f'correlation_{version}_{lead_time}lead'))
# Out:
# Loss (Negative-Log-Likelihood): 0.7087833095511105
