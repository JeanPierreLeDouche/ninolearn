# %% [markdown]
# # Deep ensemble for ENSO-forecasting
#
# In this tutorial you learn how to use a neural network model called Deep Ensemble (DE) for the ENSO forecasting. This network architecture was initially developed [Lakshminarayanan et al. (2017)](https://papers.nips.cc/paper/7219-simple-and-scalable-predictive-uncertainty-estimation-using-deep-ensembles.pdf).
#
# DEs are feed foreword neural networks that predict the mean and the standard deviation of a Gaussian. Hence, their predicion comes with an uncertainty estimation which is a valuable feature for ENSO-forecasting.

# %% [markdown]
# ## Create a data pipe line
#
# At first, we define a data pipeline. This is in general quite useful to keep your code clean and also to reuse the pipeline for later purpose.
#
# The data pipeline generates returns:
#
# 1. The feature array
#
# 2. The label array
#
# 3. The time  array corresponding to the time of the label
#
# NOTE (again): Lead time is defined as the time that passed between the last observed and the first date of the target season. Hence, negative appear, e.g. if you compare the DJF season with the target season JFM, you have a lead time of -2 month (Last observed date: Feburary 28/29, First date of the target season January 1).

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler

from ninolearn.utils import include_time_lag
from ninolearn.IO.read_processed import data_reader

def pipeline(lead_time):
    """
    Data pipeline for the processing of the data before the Deep Ensemble
    is trained.

    :type lead_time: int
    :param lead_time: The lead time in month.

    :returns: The feature "X" (at observation time), the label "y" (at lead
    time), the target season "timey" (least month)
    """
    reader = data_reader(startdate='1980-01', enddate='2018-12')

    # indeces
    oni = reader.read_csv('oni')
    iod = reader.read_csv('iod')
    wwv = reader.read_csv('wwv')
    # seasonal cycle
    sc = np.cos(np.arange(len(oni))/12*2*np.pi)

    
    # network metrics
    network_ssh = reader.read_statistic('network_metrics', variable='sst', dataset='ERSSTv5', processed="anom")
    c2 = network_ssh['fraction_clusters_size_2']
    H = network_ssh['corrected_hamming_distance']

    # time lag
    time_lag = 12

    # shift such that lead time corresponds to the definition of lead time
    shift = 3

    # process features
    feature_unscaled = np.stack((oni, sc, wwv, iod,
                                 c2, H), axis=1)

    # scale each feature
    scalerX = StandardScaler()
    Xorg = scalerX.fit_transform(feature_unscaled)

    # set nans to 0.
    Xorg = np.nan_to_num(Xorg)

    # arange the feature array
    X = Xorg[:-lead_time-shift,:]
#     X = include_time_lag(X, max_lag=time_lag)
    X = include_time_lag(X, n_lags =12) 


    # arange label
    yorg = oni.values
    y = yorg[lead_time + time_lag + shift:]

    # get the time axis of the label
    timey = oni.index[lead_time + time_lag + shift:]

    return X, y, timey

# %%
reader = data_reader(startdate='1980-01', enddate='2018-12')
wwv = reader.read_csv('wwv')
print(wwv)
# Out:
# time
# 1980-01-01    7.657363e+13
# 1980-02-01    7.004931e+13
# 1980-03-01    5.240853e+13
# 1980-04-01    4.008869e+13
# 1980-05-01    4.020975e+13
#                   ...
# 2018-08-01    1.782704e+14
# 2018-09-01    1.931420e+14
# 2018-10-01    2.047508e+14
# 2018-11-01    1.881977e+14
# 2018-12-01    1.529808e+14
# Name: anom, Length: 468, dtype: float64

# %% [markdown]
# ## Split the data set
#
# For the training and testing of machine learning models it is crucial to split the data set into:
#
# 1. __Train data set__ which is used to train the weights of the neural network
#
# 2. __Validation data set__ which is used to check for overfitting (e.g. when using early stopping) and to optimize the hyperparameters
#
# 3. __Test data set__ which is used to to evaluate the trained model.
#
# __NOTE:__ It is important to understand that hyperparamters must be tuned so that the result is best for the Validation data set and __not__ for the test data set. Otherwise you can not rule out the case that the specific hyperparameter setting just works good for the specific test data set but is not generally a good hyperparameter setting.
#
# In the following cell the train and the validation data set are still one data set, because this array will be later splitted into two arrays when th model is fitted.

# %%
import keras.backend as K
from ninolearn.learn.models.dem import DEM

# clear memory from previous sessions
K.clear_session()

# define the lead time
lead_time = 3

# get the features (X), the label (y) and 
# the time axis of the label (timey)
X, y, timey = pipeline(lead_time)

# split the data set into 
test_indeces = (timey>='2001-01-01') & (timey<='2018-12-01')
train_val_indeces = np.invert(test_indeces)

train_val_X, train_val_y, train_val_timey = X[train_val_indeces,:], y[train_val_indeces], timey[train_val_indeces]
testX, testy, testtimey = X[test_indeces,:], y[test_indeces], timey[test_indeces]

# %% [markdown]
# ## Fit the model
#
# Now it is time to train the model! For this a random search is used for all keyword arguments that are passed in a *list* to the DEM.set_parameters() method.

# %%
# initiated an instance of the DEM (Deep Ensemble Model) class
model = DEM()

# Set parameters
model.set_hyperparameters(searchtype='linear', layers=1, neurons=16, dropout=[0.1, 0.5], noise_in=[0.1,0.5], noise_sigma=[0.1,0.5],
                     noise_mu=[0.1,0.5], l1_hidden=[0.0, 0.2], l2_hidden=[0., 0.2],
                     l1_mu=[0.0, 0.2], l2_mu=[0.0, 0.2], l1_sigma=[0.0, 0.2],
                     l2_sigma=[0.0, 0.2], lr=[0.0001,0.01], batch_size=100, epochs=500, n_segments=5,
                     n_members_segment=1, patience=30, verbose=0, pdf='normal', activation = 'relu')

# Use a random search to find the optimal hyperparameters

model.fit_RandomizedSearch(train_val_X, train_val_y, train_val_timey, n_iter=20)
# Out:
# Search iteration Nr 1/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00076: early stopping
# 2/2 [==============================] - 0s 5ms/step - loss: 6.4014 - nll_gaussian: -0.0221
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00046: early stopping
# 2/2 [==============================] - 0s 6ms/step - loss: 4.7167 - nll_gaussian: 0.6950
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00039: early stopping
# 2/2 [==============================] - 0s 9ms/step - loss: 3.5861 - nll_gaussian: 0.1453
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00031: early stopping
# 2/2 [==============================] - 0s 23ms/step - loss: 1.3391 - nll_gaussian: -0.0083
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00038: early stopping
# 2/2 [==============================] - 0s 9ms/step - loss: 4.4273 - nll_gaussian: 1.3253
# Loss: 0.42702696919441224
# Computation time: 58.3s
# New best hyperparameters
# Mean loss: 0.42702696919441224
# {'layers': 1, 'neurons': 16, 'dropout': 0.1336351359259331, 'noise_in': 0.39781740880884264, 'noise_sigma': 0.36773062127195333, 'noise_mu': 0.35104733256126897, 'l1_hidden': 0.07091748229033726, 'l2_hidden': 0.03499078562037146, 'l1_mu': 0.1022982957845275, 'l2_mu': 0.15466578532325717, 'l1_sigma': 0.14747910710499348, 'l2_sigma': 0.012023592656350113, 'lr': 0.008303467835761304, 'batch_size': 100, 'epochs': 500, 'n_segments': 5, 'n_members_segment': 1, 'patience': 30, 'verbose': 0, 'pdf': 'normal', 'activation': 'relu', 'n_members': 5}
# Search iteration Nr 2/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00123: early stopping
# 2/2 [==============================] - 0s 8ms/step - loss: 0.5716 - nll_gaussian: 0.3592
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00089: early stopping
# 2/2 [==============================] - 0s 6ms/step - loss: 2.1515 - nll_gaussian: 0.6584
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00081: early stopping
# 2/2 [==============================] - 0s 3ms/step - loss: 0.9181 - nll_gaussian: 0.2251
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00031: early stopping
# 2/2 [==============================] - 0s 3ms/step - loss: 4.7560 - nll_gaussian: -0.0088
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00250: early stopping
# 2/2 [==============================] - 0s 6ms/step - loss: 2.7887 - nll_gaussian: 0.9402
# Loss: 0.4348171852529049
# Computation time: 119.2s
# Search iteration Nr 3/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00058: early stopping
# 2/2 [==============================] - 0s 5ms/step - loss: 8.9931 - nll_gaussian: 0.2135
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00109: early stopping
# 2/2 [==============================] - 0s 4ms/step - loss: 10.5366 - nll_gaussian: 0.4712
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00074: early stopping
# 2/2 [==============================] - 0s 7ms/step - loss: 9.0968 - nll_gaussian: 0.1759
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00032: early stopping
# 2/2 [==============================] - 0s 4ms/step - loss: 5.8684 - nll_gaussian: -0.0231
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00076: early stopping
# 2/2 [==============================] - 0s 4ms/step - loss: 9.0924 - nll_gaussian: 0.7004
# Loss: 0.3075696092098951
# Computation time: 72.1s
# New best hyperparameters
# Mean loss: 0.3075696092098951
# {'layers': 1, 'neurons': 16, 'dropout': 0.16528839793944056, 'noise_in': 0.49095565611182923, 'noise_sigma': 0.44673102189723035, 'noise_mu': 0.4125768213897829, 'l1_hidden': 0.19737947368096756, 'l2_hidden': 0.11394214842024829, 'l1_mu': 0.06510681578445046, 'l2_mu': 0.16001818950995328, 'l1_sigma': 0.03393078330898452, 'l2_sigma': 0.005146172439175767, 'lr': 0.004286257944134344, 'batch_size': 100, 'epochs': 500, 'n_segments': 5, 'n_members_segment': 1, 'patience': 30, 'verbose': 0, 'pdf': 'normal', 'activation': 'relu', 'n_members': 5}
# Search iteration Nr 4/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00086: early stopping
# 2/2 [==============================] - 0s 3ms/step - loss: 7.4221 - nll_gaussian: 0.2247
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00130: early stopping
# 2/2 [==============================] - 0s 4ms/step - loss: 8.5063 - nll_gaussian: 0.5325
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00040: early stopping
# 2/2 [==============================] - 0s 4ms/step - loss: 1.7483 - nll_gaussian: 0.3248
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00052: early stopping
# 2/2 [==============================] - 0s 4ms/step - loss: 5.1053 - nll_gaussian: -0.0315
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00094: early stopping
# 2/2 [==============================] - 0s 5ms/step - loss: 6.7303 - nll_gaussian: 0.9475
# Loss: 0.39964313209056856
# Computation time: 89.6s
# Search iteration Nr 5/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00039: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 4.9605 - nll_gaussian: 0.4149
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00105: early stopping
# 2/2 [==============================] - 0s 3ms/step - loss: 6.5950 - nll_gaussian: 0.6529
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00031: early stopping
# 2/2 [==============================] - 0s 5ms/step - loss: 4.5452 - nll_gaussian: 0.3711
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00064: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 4.4666 - nll_gaussian: -0.0407
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00220: early stopping
# 2/2 [==============================] - 0s 11ms/step - loss: 7.1441 - nll_gaussian: 0.7800
# Loss: 0.43561479151248933
# Computation time: 109.4s
# Search iteration Nr 6/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00293: early stopping
# 2/2 [==============================] - 0s 9ms/step - loss: 1.0895 - nll_gaussian: 0.2915
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00419: early stopping
# 2/2 [==============================] - 0s 9ms/step - loss: 1.0598 - nll_gaussian: 0.6585
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# 2/2 [==============================] - 0s 11ms/step - loss: 0.4171 - nll_gaussian: 0.0634
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00031: early stopping
# 2/2 [==============================] - 0s 8ms/step - loss: 1.2106 - nll_gaussian: -0.0102
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00472: early stopping
# 2/2 [==============================] - 0s 11ms/step - loss: 1.6894 - nll_gaussian: 1.1736
# Loss: 0.43537072390317916
# Computation time: 329.4s
# Search iteration Nr 7/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00077: early stopping
# 2/2 [==============================] - 0s 4ms/step - loss: 1.5311 - nll_gaussian: 0.4018
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00031: early stopping
# 2/2 [==============================] - 0s 3ms/step - loss: 1.6449 - nll_gaussian: 0.8395
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00038: early stopping
# 2/2 [==============================] - 0s 10ms/step - loss: 1.1101 - nll_gaussian: 0.3622
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00031: early stopping
# 2/2 [==============================] - 0s 5ms/step - loss: 0.9020 - nll_gaussian: -1.9450e-04
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00089: early stopping
# 2/2 [==============================] - 0s 10ms/step - loss: 2.2738 - nll_gaussian: 1.0959
# Loss: 0.5398484922945499
# Computation time: 67.8s
# Search iteration Nr 8/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00037: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 6.2170 - nll_gaussian: 0.4630
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00078: early stopping
# 2/2 [==============================] - 0s 3ms/step - loss: 6.3710 - nll_gaussian: 0.8312
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00083: early stopping
# 2/2 [==============================] - 0s 12ms/step - loss: 6.1232 - nll_gaussian: 0.3579
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00056: early stopping
# 2/2 [==============================] - 0s 5ms/step - loss: 5.6933 - nll_gaussian: -0.0166
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00074: early stopping
# 2/2 [==============================] - 0s 3ms/step - loss: 7.2243 - nll_gaussian: 1.2797
# Loss: 0.5830400038510561
# Computation time: 78.9s
# Search iteration Nr 9/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00037: early stopping
# 2/2 [==============================] - 0s 10ms/step - loss: 4.6116 - nll_gaussian: 0.3918
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00038: early stopping
# 2/2 [==============================] - 0s 14ms/step - loss: 3.3846 - nll_gaussian: 0.7855
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00031: early stopping
# 2/2 [==============================] - 0s 7ms/step - loss: 4.4049 - nll_gaussian: 0.4075
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00031: early stopping
# 2/2 [==============================] - 0s 12ms/step - loss: 3.2917 - nll_gaussian: -0.0081
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00065: early stopping
# 2/2 [==============================] - 0s 10ms/step - loss: 8.6243 - nll_gaussian: 0.7086
# Loss: 0.45705443546175956
# Computation time: 53.3s
# Search iteration Nr 10/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00100: early stopping
# 2/2 [==============================] - 0s 19ms/step - loss: 0.5947 - nll_gaussian: 0.3878
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00155: early stopping
# 2/2 [==============================] - 0s 10ms/step - loss: 0.6581 - nll_gaussian: 0.5881
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00040: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 0.6997 - nll_gaussian: 0.3170
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00031: early stopping
# 2/2 [==============================] - 0s 4ms/step - loss: 3.6544 - nll_gaussian: -0.0019
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00160: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 1.0735 - nll_gaussian: 0.9139
# Loss: 0.4409869581460953
# Computation time: 98.1s
# Search iteration Nr 11/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00078: early stopping
# 2/2 [==============================] - 0s 11ms/step - loss: 2.4574 - nll_gaussian: 0.4601
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00060: early stopping
# 2/2 [==============================] - 0s 13ms/step - loss: 2.3423 - nll_gaussian: 0.7859
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00079: early stopping
# 2/2 [==============================] - 0s 11ms/step - loss: 2.1326 - nll_gaussian: 0.3296
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00031: early stopping
# 2/2 [==============================] - 0s 10ms/step - loss: 1.6714 - nll_gaussian: -0.0121
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00106: early stopping
# 2/2 [==============================] - 0s 13ms/step - loss: 3.2279 - nll_gaussian: 1.2303
# Loss: 0.5587826251983643
# Computation time: 78.0s
# Search iteration Nr 12/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00097: early stopping
# 2/2 [==============================] - 0s 9ms/step - loss: 0.7937 - nll_gaussian: 0.0584
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00137: early stopping
# 2/2 [==============================] - 0s 3ms/step - loss: 0.6014 - nll_gaussian: 0.2534
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00182: early stopping
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1923 - nll_gaussian: -0.0744
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00031: early stopping
# 2/2 [==============================] - 0s 3ms/step - loss: 1.7683 - nll_gaussian: -0.0150
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00188: early stopping
# 2/2 [==============================] - 0s 5ms/step - loss: 0.5786 - nll_gaussian: 0.2741
# Loss: 0.09927985146641731
# Computation time: 129.3s
# New best hyperparameters
# Mean loss: 0.09927985146641731
# {'layers': 1, 'neurons': 16, 'dropout': 0.135286256196394, 'noise_in': 0.31691385516947085, 'noise_sigma': 0.18754971843399637, 'noise_mu': 0.1447650329168637, 'l1_hidden': 0.07209411947997545, 'l2_hidden': 0.06927839325629004, 'l1_mu': 0.000675793958099602, 'l2_mu': 0.11216946173084955, 'l1_sigma': 0.009775002641473974, 'l2_sigma': 0.08021399552877151, 'lr': 0.0021589480276411168, 'batch_size': 100, 'epochs': 500, 'n_segments': 5, 'n_members_segment': 1, 'patience': 30, 'verbose': 0, 'pdf': 'normal', 'activation': 'relu', 'n_members': 5}
# Search iteration Nr 13/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00054: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 4.4708 - nll_gaussian: 0.2224
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00094: early stopping
# 2/2 [==============================] - 0s 5ms/step - loss: 5.6772 - nll_gaussian: 0.4328
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00086: early stopping
# 2/2 [==============================] - 0s 9ms/step - loss: 5.5248 - nll_gaussian: 0.0597
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00031: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 3.2839 - nll_gaussian: -0.0206
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00124: early stopping
# 2/2 [==============================] - 0s 4ms/step - loss: 8.1805 - nll_gaussian: 0.3575
# Loss: 0.21034814715385436
# Computation time: 82.3s
# Search iteration Nr 14/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00107: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 7.4382 - nll_gaussian: 0.1084
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00088: early stopping
# 2/2 [==============================] - 0s 9ms/step - loss: 6.7844 - nll_gaussian: 0.5745
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00031: early stopping
# 2/2 [==============================] - 0s 10ms/step - loss: 4.6671 - nll_gaussian: 0.3649
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00031: early stopping
# 2/2 [==============================] - 0s 6ms/step - loss: 4.8474 - nll_gaussian: -0.0221
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00031: early stopping
# 2/2 [==============================] - 0s 4ms/step - loss: 6.2614 - nll_gaussian: 1.3646
# Loss: 0.47807654477655886
# Computation time: 72.2s
# Search iteration Nr 15/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00056: early stopping
# 2/2 [==============================] - 0s 4ms/step - loss: 9.5328 - nll_gaussian: 0.3763
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00043: early stopping
# 2/2 [==============================] - 0s 4ms/step - loss: 7.3415 - nll_gaussian: 0.5050
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00047: early stopping
# 2/2 [==============================] - 0s 10ms/step - loss: 10.5231 - nll_gaussian: 0.1811
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00033: early stopping
# 2/2 [==============================] - 0s 9ms/step - loss: 6.1910 - nll_gaussian: -0.0298
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00083: early stopping
# 2/2 [==============================] - 0s 3ms/step - loss: 16.3250 - nll_gaussian: 0.6759
# Loss: 0.3417170211672783
# Computation time: 65.2s
# Search iteration Nr 16/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00062: early stopping
# 2/2 [==============================] - 0s 10ms/step - loss: 9.8526 - nll_gaussian: -0.1815
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00071: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 9.5946 - nll_gaussian: 0.4908
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00065: early stopping
# 2/2 [==============================] - 0s 9ms/step - loss: 10.8654 - nll_gaussian: -0.2852
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00033: early stopping
# 2/2 [==============================] - 0s 9ms/step - loss: 3.9115 - nll_gaussian: -0.0252
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00078: early stopping
# 2/2 [==============================] - 0s 7ms/step - loss: 11.8645 - nll_gaussian: 0.8407
# Loss: 0.16789642721414566
# Computation time: 73.0s
# Search iteration Nr 17/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00038: early stopping
# 2/2 [==============================] - 0s 3ms/step - loss: 1.9535 - nll_gaussian: 0.3036
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00047: early stopping
# 2/2 [==============================] - 0s 6ms/step - loss: 2.8842 - nll_gaussian: 0.3451
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00040: early stopping
# 2/2 [==============================] - 0s 3ms/step - loss: 1.3323 - nll_gaussian: 0.1326
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00031: early stopping
# 2/2 [==============================] - 0s 6ms/step - loss: 1.0035 - nll_gaussian: 1.4810e-04
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00046: early stopping
# 2/2 [==============================] - 0s 10ms/step - loss: 1.8477 - nll_gaussian: 0.6027
# Loss: 0.27681901678442955
# Computation time: 55.1s
# Search iteration Nr 18/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00072: early stopping
# 2/2 [==============================] - 0s 10ms/step - loss: 5.8064 - nll_gaussian: 0.4588
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00048: early stopping
# 2/2 [==============================] - 0s 7ms/step - loss: 5.7342 - nll_gaussian: 0.8331
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00150: early stopping
# 2/2 [==============================] - 0s 6ms/step - loss: 5.1867 - nll_gaussian: 0.3499
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00031: early stopping
# 2/2 [==============================] - 0s 9ms/step - loss: 5.1120 - nll_gaussian: -0.0037
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00119: early stopping
# 2/2 [==============================] - 0s 4ms/step - loss: 6.5112 - nll_gaussian: 1.2534
# Loss: 0.5783090867102146
# Computation time: 91.7s
# Search iteration Nr 19/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00063: early stopping
# 2/2 [==============================] - 0s 3ms/step - loss: 9.5231 - nll_gaussian: 0.3616
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00044: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 7.7689 - nll_gaussian: 0.4106
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00032: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 3.4354 - nll_gaussian: 0.2326
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00041: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 6.6055 - nll_gaussian: -0.0461
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00058: early stopping
# 2/2 [==============================] - 0s 5ms/step - loss: 8.7207 - nll_gaussian: 0.8744
# Loss: 0.36660889387130735
# Computation time: 52.6s
# Search iteration Nr 20/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00087: early stopping
# 2/2 [==============================] - 0s 3ms/step - loss: 7.6920 - nll_gaussian: 0.2003
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00052: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 5.7358 - nll_gaussian: 0.6434
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00055: early stopping
# 2/2 [==============================] - 0s 4ms/step - loss: 6.3856 - nll_gaussian: 0.1285
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00053: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 5.2235 - nll_gaussian: -0.0886
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00073: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 7.6326 - nll_gaussian: 0.7401
# Loss: 0.3247325912117958
# Computation time: 67.1s
# Refit the model with best hyperparamters
# {'layers': 1, 'neurons': 16, 'dropout': 0.135286256196394, 'noise_in': 0.31691385516947085, 'noise_sigma': 0.18754971843399637, 'noise_mu': 0.1447650329168637, 'l1_hidden': 0.07209411947997545, 'l2_hidden': 0.06927839325629004, 'l1_mu': 0.000675793958099602, 'l2_mu': 0.11216946173084955, 'l1_sigma': 0.009775002641473974, 'l2_sigma': 0.08021399552877151, 'lr': 0.0021589480276411168, 'batch_size': 100, 'epochs': 500, 'n_segments': 5, 'n_members_segment': 1, 'patience': 30, 'verbose': 0, 'pdf': 'normal', 'activation': 'relu', 'n_members': 5}
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00198: early stopping
# 2/2 [==============================] - 0s 6ms/step - loss: 0.4412 - nll_gaussian: -0.0511
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00123: early stopping
# 2/2 [==============================] - 0s 6ms/step - loss: 1.5073 - nll_gaussian: 0.3098
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00160: early stopping
# 2/2 [==============================] - 0s 3ms/step - loss: 0.2108 - nll_gaussian: -0.0400
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00031: early stopping
# 2/2 [==============================] - 0s 3ms/step - loss: 1.8494 - nll_gaussian: -0.0125
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00139: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 1.7620 - nll_gaussian: 0.9588
# Loss: 0.2330074429512024
# Computation time: 67.6s
# best loss search: 0.09927985146641731
# loss refitting : 0.2330074429512024

# %% [markdown]
# ## Make predictions for the test data set
# Now we can use the trained models to make predicitons on the test data set to evaluate how good the model perfoms on a data set that it never saw before.

# %%
pred_mean, pred_std = model.predict(testX)

# %% [markdown]
# ## Plot the prediction
# Let's see how the predicion is looking like

# %%
import matplotlib.pyplot as plt
from ninolearn.plot.prediction import plot_prediction
import pandas as pd

plt.subplots(figsize=(15,3.5))
plt.axhspan(-0.5,
            -6,
            facecolor='blue',
            alpha=0.1,zorder=0)

plt.axhspan(0.5,
            6,
            facecolor='red',
            alpha=0.1,zorder=0)

plt.xlim(testtimey[0], testtimey[-1])
plt.ylim(-3,3)

# plot the prediction
plot_prediction(testtimey, pred_mean, std=pred_std, facecolor='royalblue', line_color='navy')

# plot the observation
plt.plot(timey, y, "k")

plt.show()

# %% [markdown]
# ## Evaluate the model
#
# We can evaluate the model a bit more quantitatively using the loss function that was used to train the model, namely the negative-log-likelihood of the Gaussian and the correlation between the predicted mean and the observed ONI index.

# %%
from ninolearn.plot.evaluation import plot_correlation

loss = model.evaluate(testy, pred_mean, pred_std)
print(f"Loss (Negative-Log-Likelihood): {loss}")

# make a plot of the seasonal correaltion
# note: - pd.tseries.offsets.MonthBegin(1) appears to ensure that the correlations are plotted
# agains the correct season
plot_correlation(testy, pred_mean, testtimey - pd.tseries.offsets.MonthBegin(1), title="")
# Out:
# Loss (Negative-Log-Likelihood): 0.14684891546309065
