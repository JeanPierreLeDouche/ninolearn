# %% [markdown]
# # Deep ensemble for ENSO-forecasting
#
# In this tutorial you learn how to use a neural network model called Deep Ensemble (DE) for the ENSO forecasting. This network architecture was initially developed [Lakshminarayanan et al. (2017)](https://papers.nips.cc/paper/7219-simple-and-scalable-predictive-uncertainty-estimation-using-deep-ensembles.pdf).
#
# DEs are feed foreword neural networks that predict the mean and the standard deviation of a Gaussian. Hence, their predicion comes with an uncertainty estimation which is a valuable feature for ENSO-forecasting.

# %% [markdown]
# ## Create a data pipe line
#
# At first, we define a data pipeline. This is in general quite useful to keep your code clean and also to reuse the pipeline for later purpose.
#
# The data pipeline generates returns:
#
# 1. The feature array
#
# 2. The label array
#
# 3. The time  array corresponding to the time of the label
#
# NOTE (again): Lead time is defined as the time that passed between the last observed and the first date of the target season. Hence, negative appear, e.g. if you compare the DJF season with the target season JFM, you have a lead time of -2 month (Last observed date: Feburary 28/29, First date of the target season January 1).

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler

from ninolearn.utils import include_time_lag
from ninolearn.IO.read_processed import data_reader

def pipeline(lead_time):
    """
    Data pipeline for the processing of the data before the Deep Ensemble
    is trained.

    :type lead_time: int
    :param lead_time: The lead time in month.

    :returns: The feature "X" (at observation time), the label "y" (at lead
    time), the target season "timey" (least month)
    """
    reader = data_reader(startdate='1980-01', enddate='2018-12')

    # indeces
    oni = reader.read_csv('oni')
    iod = reader.read_csv('iod')
    wwv = reader.read_csv('wwv')
    # seasonal cycle
    sc = np.cos(np.arange(len(oni))/12*2*np.pi)

    
    # network metrics
    network_ssh = reader.read_statistic('network_metrics', variable='sst', dataset='ERSSTv5', processed="anom")
    c2 = network_ssh['fraction_clusters_size_2']
    H = network_ssh['corrected_hamming_distance']

    # time lag
    time_lag = 12

    # shift such that lead time corresponds to the definition of lead time
    shift = 3

    # process features
    feature_unscaled = np.stack((oni, sc, wwv, iod,
                                 c2, H), axis=1)

    # scale each feature
    scalerX = StandardScaler()
    Xorg = scalerX.fit_transform(feature_unscaled)

    # set nans to 0.
    Xorg = np.nan_to_num(Xorg)

    # arange the feature array
    X = Xorg[:-lead_time-shift,:]
#     X = include_time_lag(X, max_lag=time_lag)
    X = include_time_lag(X, n_lags =12) 


    # arange label
    yorg = oni.values
    y = yorg[lead_time + time_lag + shift:]

    # get the time axis of the label
    timey = oni.index[lead_time + time_lag + shift:]

    return X, y, timey

# %%
# Out:
# float64

# %% [markdown]
# ## Split the data set
#
# For the training and testing of machine learning models it is crucial to split the data set into:
#
# 1. __Train data set__ which is used to train the weights of the neural network
#
# 2. __Validation data set__ which is used to check for overfitting (e.g. when using early stopping) and to optimize the hyperparameters
#
# 3. __Test data set__ which is used to to evaluate the trained model.
#
# __NOTE:__ It is important to understand that hyperparamters must be tuned so that the result is best for the Validation data set and __not__ for the test data set. Otherwise you can not rule out the case that the specific hyperparameter setting just works good for the specific test data set but is not generally a good hyperparameter setting.
#
# In the following cell the train and the validation data set are still one data set, because this array will be later splitted into two arrays when th model is fitted.

# %%
import keras.backend as K
from ninolearn.learn.models.dem import DEM

# clear memory from previous sessions
K.clear_session()

# define the lead time
lead_time = 3

# get the features (X), the label (y) and 
# the time axis of the label (timey)
X, y, timey = pipeline(lead_time)

# split the data set into 
test_indeces = (timey>='2001-01-01') & (timey<='2018-12-01')
train_val_indeces = np.invert(test_indeces)

train_val_X, train_val_y, train_val_timey = X[train_val_indeces,:], y[train_val_indeces], timey[train_val_indeces]
testX, testy, testtimey = X[test_indeces,:], y[test_indeces], timey[test_indeces]

# %% [markdown]
# ## Fit the model
#
# Now it is time to train the model! For this a random search is used for all keyword arguments that are passed in a *list* to the DEM.set_parameters() method.

# %%
# initiated an instance of the DEM (Deep Ensemble Model) class
model = DEM()

# Set parameters
model.set_hyperparameters(searchtype='linear', layers=1, neurons=16, dropout=[0.1, 0.5], noise_in=[0.1,0.5], noise_sigma=[0.1,0.5],
                     noise_mu=[0.1,0.5], l1_hidden=[0.0, 0.2], l2_hidden=[0., 0.2],
                     l1_mu=[0.0, 0.2], l2_mu=[0.0, 0.2], l1_sigma=[0.0, 0.2],
                     l2_sigma=[0.0, 0.2], lr=[0.0001,0.01], batch_size=100, epochs=500, n_segments=5,
                     n_members_segment=1, patience=30, verbose=0, pdf='normal', activation = 'relu')

# Use a random search to find the optimal hyperparameters

model.fit_RandomizedSearch(train_val_X, train_val_y, train_val_timey, n_iter=20)
# Out:
# Search iteration Nr 1/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00059: early stopping
# 2/2 [==============================] - 0s 19ms/step - loss: 0.7054 - nll_gaussian: 0.3169
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00073: early stopping
# 2/2 [==============================] - 0s 17ms/step - loss: 0.6657 - nll_gaussian: 0.3547
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00090: early stopping
# 2/2 [==============================] - 0s 5ms/step - loss: 0.4261 - nll_gaussian: 0.0451
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00031: early stopping
# 2/2 [==============================] - 0s 12ms/step - loss: 1.3702 - nll_gaussian: -0.0108
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00112: early stopping
# 2/2 [==============================] - 0s 14ms/step - loss: 3.3627 - nll_gaussian: 0.5801
# Loss: 0.25720005929470063
# Computation time: 45.7s
# New best hyperparameters
# Mean loss: 0.25720005929470063
# {'layers': 1, 'neurons': 16, 'dropout': 0.32529333813965844, 'noise_in': 0.48012120350421816, 'noise_sigma': 0.17826607362317134, 'noise_mu': 0.15844037623407817, 'l1_hidden': 0.08176088020112326, 'l2_hidden': 0.1813497739864258, 'l1_mu': 0.08936473923433802, 'l2_mu': 0.18015374571558826, 'l1_sigma': 0.12988567110889807, 'l2_sigma': 0.12602891213180042, 'lr': 0.008094691201326316, 'batch_size': 100, 'epochs': 500, 'n_segments': 5, 'n_members_segment': 1, 'patience': 30, 'verbose': 0, 'pdf': 'normal', 'activation': 'relu', 'n_members': 5}
# Search iteration Nr 2/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00060: early stopping
# 2/2 [==============================] - 0s 4ms/step - loss: 9.2395 - nll_gaussian: 0.3481
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00130: early stopping
# 2/2 [==============================] - 0s 1ms/step - loss: 10.2749 - nll_gaussian: 0.3542
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00088: early stopping
# 2/2 [==============================] - 0s 12ms/step - loss: 11.3150 - nll_gaussian: 0.1087
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00082: early stopping
# 2/2 [==============================] - 0s 5ms/step - loss: 12.6161 - nll_gaussian: -0.1348
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00115: early stopping
# 2/2 [==============================] - 0s 6ms/step - loss: 10.9446 - nll_gaussian: 0.8288
# Loss: 0.301009801030159
# Computation time: 46.4s
# Search iteration Nr 3/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00104: early stopping
# 2/2 [==============================] - 0s 12ms/step - loss: 2.2782 - nll_gaussian: 0.3713
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00060: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 2.1924 - nll_gaussian: 0.7748
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00057: early stopping
# 2/2 [==============================] - 0s 13ms/step - loss: 1.8054 - nll_gaussian: 0.3429
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00031: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 1.3619 - nll_gaussian: -0.0063
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00118: early stopping
# 2/2 [==============================] - 0s 10ms/step - loss: 3.2444 - nll_gaussian: 1.1478
# Loss: 0.5261291541159153
# Computation time: 34.3s
# Search iteration Nr 4/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00071: early stopping
# 2/2 [==============================] - 0s 8ms/step - loss: 2.2929 - nll_gaussian: 0.3869
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00078: early stopping
# 2/2 [==============================] - 0s 10ms/step - loss: 2.8807 - nll_gaussian: 0.4003
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00043: early stopping
# 2/2 [==============================] - 0s 7ms/step - loss: 1.7367 - nll_gaussian: 0.5534
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00033: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 0.9946 - nll_gaussian: 0.0061
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00046: early stopping
# 2/2 [==============================] - 0s 3ms/step - loss: 2.2445 - nll_gaussian: 0.5737
# Loss: 0.38407032042741773
# Computation time: 26.7s
# Search iteration Nr 5/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00059: early stopping
# 2/2 [==============================] - 0s 3ms/step - loss: 3.4160 - nll_gaussian: 0.4595
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00048: early stopping
# 2/2 [==============================] - 0s 5ms/step - loss: 3.4961 - nll_gaussian: 0.8214
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00043: early stopping
# 2/2 [==============================] - 0s 1ms/step - loss: 2.8962 - nll_gaussian: 0.3545
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00054: early stopping
# 2/2 [==============================] - 0s 10ms/step - loss: 2.7461 - nll_gaussian: -9.6177e-04
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00155: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 4.1823 - nll_gaussian: 1.1081
# Loss: 0.548501767218113
# Computation time: 33.7s
# Search iteration Nr 6/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00125: early stopping
# 2/2 [==============================] - 0s 16ms/step - loss: 0.4382 - nll_gaussian: 0.1433
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00078: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 0.5610 - nll_gaussian: 0.4793
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00110: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2377 - nll_gaussian: 0.1341
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00031: early stopping
# 2/2 [==============================] - 0s 4ms/step - loss: 0.7638 - nll_gaussian: -0.0103
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00144: early stopping
# 2/2 [==============================] - 0s 9ms/step - loss: 1.0389 - nll_gaussian: 0.9883
# Loss: 0.3469220593571663
# Computation time: 46.0s
# Search iteration Nr 7/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00048: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 0.8118 - nll_gaussian: 0.3827
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00183: early stopping
# 2/2 [==============================] - 0s 6ms/step - loss: 0.7191 - nll_gaussian: 0.5924
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00035: early stopping
# 2/2 [==============================] - 0s 1ms/step - loss: 1.5020 - nll_gaussian: 0.3072
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00031: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 3.0108 - nll_gaussian: -0.0078
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00072: early stopping
# 2/2 [==============================] - 0s 6ms/step - loss: 1.2516 - nll_gaussian: 0.9956
# Loss: 0.45403613373637197
# Computation time: 37.4s
# Search iteration Nr 8/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00056: early stopping
# 2/2 [==============================] - 0s 6ms/step - loss: 1.0889 - nll_gaussian: 0.3195
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00052: early stopping
# 2/2 [==============================] - 0s 5ms/step - loss: 0.7933 - nll_gaussian: 0.5913
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00031: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 1.3928 - nll_gaussian: 0.3557
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00031: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 1.5210 - nll_gaussian: -0.0104
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00210: early stopping
# 2/2 [==============================] - 0s 6ms/step - loss: 0.9672 - nll_gaussian: 0.8326
# Loss: 0.41772830933332444
# Computation time: 40.2s
# Search iteration Nr 9/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00072: early stopping
# 2/2 [==============================] - 0s 8ms/step - loss: 0.4763 - nll_gaussian: 0.0972
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00068: early stopping
# 2/2 [==============================] - 0s 6ms/step - loss: 0.5962 - nll_gaussian: 0.3514
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00082: early stopping
# 2/2 [==============================] - 0s 3ms/step - loss: 0.2729 - nll_gaussian: 0.0887
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00031: early stopping
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6403 - nll_gaussian: 7.2674e-04
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00207: early stopping
# 2/2 [==============================] - 0s 9ms/step - loss: 0.9280 - nll_gaussian: 0.8771
# Loss: 0.2830210693180561
# Computation time: 43.9s
# Search iteration Nr 10/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00051: early stopping
# 2/2 [==============================] - 0s 8ms/step - loss: 1.8493 - nll_gaussian: 0.1829
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00049: early stopping
# 2/2 [==============================] - 0s 7ms/step - loss: 0.9432 - nll_gaussian: 0.5489
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00057: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 2.6032 - nll_gaussian: 0.0180
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00039: early stopping
# 2/2 [==============================] - 0s 9ms/step - loss: 0.8304 - nll_gaussian: -0.0279
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00078: early stopping
# 2/2 [==============================] - 0s 9ms/step - loss: 1.9702 - nll_gaussian: 0.6548
# Loss: 0.2753323528915644
# Computation time: 27.0s
# Search iteration Nr 11/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00161: early stopping
# 2/2 [==============================] - 0s 11ms/step - loss: 3.3864 - nll_gaussian: 0.4095
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00032: early stopping
# 2/2 [==============================] - 0s 7ms/step - loss: 3.4522 - nll_gaussian: 0.8236
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00117: early stopping
# 2/2 [==============================] - 0s 1ms/step - loss: 3.0024 - nll_gaussian: 0.3381
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00035: early stopping
# 2/2 [==============================] - 0s 10ms/step - loss: 2.6308 - nll_gaussian: -0.0104
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00149: early stopping
# 2/2 [==============================] - 0s 1ms/step - loss: 4.1060 - nll_gaussian: 1.2896
# Loss: 0.5700713150203228
# Computation time: 44.9s
# Search iteration Nr 12/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00072: early stopping
# 2/2 [==============================] - 0s 1ms/step - loss: 4.2062 - nll_gaussian: 0.3308
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00101: early stopping
# 2/2 [==============================] - 0s 9ms/step - loss: 4.3818 - nll_gaussian: 0.5182
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00122: early stopping
# 2/2 [==============================] - 0s 3ms/step - loss: 5.6134 - nll_gaussian: -0.2229
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00031: early stopping
# 2/2 [==============================] - 0s 1ms/step - loss: 2.0761 - nll_gaussian: 0.0038
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00069: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 5.0638 - nll_gaussian: 0.8539
# Loss: 0.29674202427268026
# Computation time: 35.6s
# Search iteration Nr 13/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00056: early stopping
# 2/2 [==============================] - 0s 7ms/step - loss: 4.8155 - nll_gaussian: 0.3120
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00071: early stopping
# 2/2 [==============================] - 0s 6ms/step - loss: 4.8907 - nll_gaussian: 0.5396
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00034: early stopping
# 2/2 [==============================] - 0s 6ms/step - loss: 3.1190 - nll_gaussian: 0.3336
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00031: early stopping
# 2/2 [==============================] - 0s 7ms/step - loss: 2.8531 - nll_gaussian: -0.0194
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00308: early stopping
# 2/2 [==============================] - 0s 3ms/step - loss: 5.7730 - nll_gaussian: 0.7022
# Loss: 0.37358901649713516
# Computation time: 46.5s
# Search iteration Nr 14/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00088: early stopping
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6502 - nll_gaussian: 0.3896
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00156: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 0.7180 - nll_gaussian: 0.5894
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00031: early stopping
# 2/2 [==============================] - 0s 3ms/step - loss: 3.2537 - nll_gaussian: 0.3437
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00031: early stopping
# 2/2 [==============================] - 0s 6ms/step - loss: 3.0534 - nll_gaussian: -0.0046
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00140: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 1.1749 - nll_gaussian: 0.9393
# Loss: 0.4514970876276493
# Computation time: 45.3s
# Search iteration Nr 15/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00057: early stopping
# 2/2 [==============================] - 0s 3ms/step - loss: 0.6588 - nll_gaussian: 0.3738
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00170: early stopping
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6699 - nll_gaussian: 0.5884
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00103: early stopping
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3863 - nll_gaussian: -0.0585
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00031: early stopping
# 2/2 [==============================] - 0s 6ms/step - loss: 2.0516 - nll_gaussian: -0.0011
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00171: early stopping
# 2/2 [==============================] - 0s 1ms/step - loss: 1.2862 - nll_gaussian: 0.9189
# Loss: 0.364304806292057
# Computation time: 44.8s
# Search iteration Nr 16/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00194: early stopping
# 2/2 [==============================] - 0s 1ms/step - loss: 1.9394 - nll_gaussian: 0.3034
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00048: early stopping
# 2/2 [==============================] - 0s 7ms/step - loss: 1.8007 - nll_gaussian: 0.8152
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00031: early stopping
# 2/2 [==============================] - 0s 3ms/step - loss: 1.2725 - nll_gaussian: 0.3338
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00031: early stopping
# 2/2 [==============================] - 0s 8ms/step - loss: 1.0140 - nll_gaussian: -0.0066
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00110: early stopping
# 2/2 [==============================] - 0s 8ms/step - loss: 2.4796 - nll_gaussian: 1.1944
# Loss: 0.5280373886227607
# Computation time: 38.5s
# Search iteration Nr 17/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00192: early stopping
# 2/2 [==============================] - 0s 8ms/step - loss: 3.8328 - nll_gaussian: 0.0237
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00106: early stopping
# 2/2 [==============================] - 0s 6ms/step - loss: 2.8978 - nll_gaussian: 0.3734
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00035: early stopping
# 2/2 [==============================] - 0s 8ms/step - loss: 1.3456 - nll_gaussian: 0.3754
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00040: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 1.4471 - nll_gaussian: -0.0934
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00162: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 3.3858 - nll_gaussian: 0.5957
# Loss: 0.2549759164452553
# Computation time: 48.5s
# New best hyperparameters
# Mean loss: 0.2549759164452553
# {'layers': 1, 'neurons': 16, 'dropout': 0.4519854735632679, 'noise_in': 0.4567093507112657, 'noise_sigma': 0.3418586463920653, 'noise_mu': 0.17903340939532428, 'l1_hidden': 0.04552224743283911, 'l2_hidden': 0.022959077728009116, 'l1_mu': 0.08124650915078087, 'l2_mu': 0.01882319791480376, 'l1_sigma': 0.05004090141161843, 'l2_sigma': 0.021221723922835944, 'lr': 0.004059646466666987, 'batch_size': 100, 'epochs': 500, 'n_segments': 5, 'n_members_segment': 1, 'patience': 30, 'verbose': 0, 'pdf': 'normal', 'activation': 'relu', 'n_members': 5}
# Search iteration Nr 18/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00092: early stopping
# 2/2 [==============================] - 0s 6ms/step - loss: 1.7770 - nll_gaussian: 0.3924
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00232: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 2.2430 - nll_gaussian: 0.4079
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00143: early stopping
# 2/2 [==============================] - 0s 9ms/step - loss: 1.7241 - nll_gaussian: 0.2318
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00031: early stopping
# 2/2 [==============================] - 0s 7ms/step - loss: 2.9251 - nll_gaussian: -0.0154
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00087: early stopping
# 2/2 [==============================] - 0s 8ms/step - loss: 1.9158 - nll_gaussian: 1.0204
# Loss: 0.4074111744761467
# Computation time: 46.5s
# Search iteration Nr 19/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00061: early stopping
# 2/2 [==============================] - 0s 6ms/step - loss: 5.1010 - nll_gaussian: 0.2693
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00106: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 7.0965 - nll_gaussian: 0.3515
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00047: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 3.7828 - nll_gaussian: 0.1665
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00031: early stopping
# 2/2 [==============================] - 0s 10ms/step - loss: 4.5120 - nll_gaussian: -0.0133
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00064: early stopping
# 2/2 [==============================] - 0s 5ms/step - loss: 3.7468 - nll_gaussian: 0.6012
# Loss: 0.2750476349145174
# Computation time: 30.9s
# Search iteration Nr 20/20
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00070: early stopping
# 2/2 [==============================] - 0s 6ms/step - loss: 2.3167 - nll_gaussian: 0.4538
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00073: early stopping
# 2/2 [==============================] - 0s 2ms/step - loss: 2.4328 - nll_gaussian: 0.8350
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00226: early stopping
# 2/2 [==============================] - 0s 7ms/step - loss: 1.9179 - nll_gaussian: 0.3344
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00047: early stopping
# 2/2 [==============================] - 0s 7ms/step - loss: 1.6087 - nll_gaussian: -0.0087
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00038: early stopping
# 2/2 [==============================] - 0s 7ms/step - loss: 3.1260 - nll_gaussian: 1.2747
# Loss: 0.5778107553720474
# Computation time: 43.9s
# Refit the model with best hyperparamters
# {'layers': 1, 'neurons': 16, 'dropout': 0.4519854735632679, 'noise_in': 0.4567093507112657, 'noise_sigma': 0.3418586463920653, 'noise_mu': 0.17903340939532428, 'l1_hidden': 0.04552224743283911, 'l2_hidden': 0.022959077728009116, 'l1_mu': 0.08124650915078087, 'l2_mu': 0.01882319791480376, 'l1_sigma': 0.05004090141161843, 'l2_sigma': 0.021221723922835944, 'lr': 0.004059646466666987, 'batch_size': 100, 'epochs': 500, 'n_segments': 5, 'n_members_segment': 1, 'patience': 30, 'verbose': 0, 'pdf': 'normal', 'activation': 'relu', 'n_members': 5}
# build
# Train member Nr 1/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00102: early stopping
# 2/2 [==============================] - 0s 3ms/step - loss: 2.9037 - nll_gaussian: 0.2482
# build
# Train member Nr 2/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00073: early stopping
# 2/2 [==============================] - 0s 3ms/step - loss: 2.3043 - nll_gaussian: 0.5528
# build
# Train member Nr 3/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00042: early stopping
# 2/2 [==============================] - 0s 3ms/step - loss: 1.5570 - nll_gaussian: 0.2398
# build
# Train member Nr 4/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00031: early stopping
# 2/2 [==============================] - 0s 1ms/step - loss: 1.2763 - nll_gaussian: -0.0169
# build
# Train member Nr 5/5
# --------------------------------------
# compile
# Restoring model weights from the end of the best epoch.
# Epoch 00194: early stopping
# 2/2 [==============================] - 0s 3ms/step - loss: 3.1791 - nll_gaussian: 0.4650
# Loss: 0.2977748513221741
# Computation time: 43.8s
# best loss search: 0.2549759164452553
# loss refitting : 0.2977748513221741

# %% [markdown]
# ## Make predictions for the test data set
# Now we can use the trained models to make predicitons on the test data set to evaluate how good the model perfoms on a data set that it never saw before.

# %%
pred_mean, pred_std = model.predict(testX)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-79f7c372ada1> in <module>
# ----> 1 pred_mean, pred_std = model.predict(testX)
#
# NameError: name 'model' is not defined

# %% [markdown]
# ## Plot the prediction
# Let's see how the predicion is looking like

# %%
import matplotlib.pyplot as plt
from ninolearn.plot.prediction import plot_prediction
import pandas as pd

plt.subplots(figsize=(15,3.5))
plt.axhspan(-0.5,
            -6,
            facecolor='blue',
            alpha=0.1,zorder=0)

plt.axhspan(0.5,
            6,
            facecolor='red',
            alpha=0.1,zorder=0)

plt.xlim(testtimey[0], testtimey[-1])
plt.ylim(-3,3)

# plot the prediction
plot_prediction(testtimey, pred_mean, std=pred_std, facecolor='royalblue', line_color='navy')

# plot the observation
plt.plot(timey, y, "k")

plt.show()

# %% [markdown]
# ## Evaluate the model
#
# We can evaluate the model a bit more quantitatively using the loss function that was used to train the model, namely the negative-log-likelihood of the Gaussian and the correlation between the predicted mean and the observed ONI index.

# %%
from ninolearn.plot.evaluation import plot_correlation

loss = model.evaluate(testy, pred_mean, pred_std)
print(f"Loss (Negative-Log-Likelihood): {loss}")

# make a plot of the seasonal correaltion
# note: - pd.tseries.offsets.MonthBegin(1) appears to ensure that the correlations are plotted
# agains the correct season
plot_correlation(testy, pred_mean, testtimey - pd.tseries.offsets.MonthBegin(1), title="")
